# %%
import pandas as pd
import requests
import re
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
pd.set_option('display.max_columns', None)

# %%
# Nota sobre rutas relativaa
# Asi buscariamos datos en la carpeta data si lo buscamos desde notebooks, que es donde tenemos el archivo en el que estamos
#pd.read_json("../data/nombrearchivo.json")

# %%
def llamar_api(url, headers):
    """
    Realiza una llamada a una API utilizando la URL proporcionada.
    Parameters:
    -----------
    url (str): La URL de la API que se va a llamar.
    Returns:
    --------
    dict or None: Un diccionario con los datos de respuesta de la API si la llamada fue exitosa (código de estado 200).
                  None si la llamada falló o no se pudo autenticar correctamente.
    """
    llamada = requests.get(url, headers=headers)  # Realiza una solicitud GET a la URL proporcionada y almacena la respuesta en 'llamada'.
    print(f"La llamada a la API nos ha dado una respuesta de tipo: {llamada.status_code}")  # Imprime el código de estado de la respuesta.
    if llamada.status_code != 200:  # Comprueba si la respuesta no fue exitosa (código de estado distinto de 200).
        print(f"El motivo por el que la llamada falló es {llamada.reason}")  # Imprime la razón de la falla.
    else:
        return llamada.json()  # Si la llamada fue exitosa, devuelve los datos de respuesta en formato JSON.

# %%
# definir la url o endpoint a la que ha haremos la llamada
access_token = "09ea95de5a904a15978cf708f15ce912"
headers = {"Authorization": f"Fiona {access_token}"}
url_SP = f"https://api.spotify.com/v1/search"
resultados_SP = llamar_api(url_SP, headers)
# Out:
# La llamada a la API nos ha dado una respuesta de tipo: 400
# El motivo por el que la llamada falló es Bad Request

# %%
# Esto esta comentado porque solo hay que instalarlo 1 vez
#%pip install spotipy

# %%
# Coloca tus credenciales aquí
CLIENT_ID = "297ba434b7cd4d018865ba4ef2b81c77"
CLIENT_SECRET = "09ea95de5a904a15978cf708f15ce912"

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos = sp.search(q="genre:electronic year:2023", type='track', limit=50, offset=0)

# %%
# Esto es para ver que devuelve datos["tracks"]
datos["tracks"]
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=genre%3Aelectronic+year%3A2023&type=track&offset=0&limit=50',
#  'items': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/67qogtRNI0GjUr8PlaG6Zh'},
#       'href': 'https://api.spotify.com/v1/artists/67qogtRNI0GjUr8PlaG6Zh',
#       'id': '67qogtRNI0GjUr8PlaG6Zh',
#       'name': 'Zeds Dead',
#       'type': 'artist',
#       'uri': 'spotify:artist:67qogtRNI0GjUr8PlaG6Zh'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
# ...

# %%
# Esto es para ver que devuelve datos["tracks"]["items"]
datos["tracks"]["items"]
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/67qogtRNI0GjUr8PlaG6Zh'},
#      'href': 'https://api.spotify.com/v1/artists/67qogtRNI0GjUr8PlaG6Zh',
#      'id': '67qogtRNI0GjUr8PlaG6Zh',
#      'name': 'Zeds Dead',
#      'type': 'artist',
#      'uri': 'spotify:artist:67qogtRNI0GjUr8PlaG6Zh'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
#Objetivo : sacar las primeras 50 canciones del genero genre:electronic year:2023 con nombre del artista y su cancion

# Este es el json con todos los valores que nos da spoti entrando en tracks - items
json_sp = datos["tracks"]["items"]

# Este es el dict donde queremos almacenar la info
dic_canciones = {"song_name": [], "artist_name": []}

for elemento in json_sp:
    for dato in elemento["album"]["artists"]:
    
        # Añadimos el nombre de la cancion en el primer bucle for
        dic_canciones["song_name"].append(elemento["name"])
        # Añadimos el nombre del artista con el segundo bucle for -> 🚩 este bucle for se aplica a elemento, no a  json_sp
        dic_canciones["artist_name"].append(dato["name"])
        
        # Estos print se pueden borrar, es para ver que devuelve elemento y dato
        print(f"Elemento es {elemento}")
        print(f"Dato es {dato}")
        # Este break se puede borrar, es para ver que se devuelve para 1 solo valor, porque 50 es mucho
        break 
        
# Mostramos los datos en el dataframe        
df_dic_canciones = pd.DataFrame(dic_canciones) 
df_dic_canciones
# Out:
# Elemento es {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/67qogtRNI0GjUr8PlaG6Zh'}, 'href': 'https://api.spotify.com/v1/artists/67qogtRNI0GjUr8PlaG6Zh', 'id': '67qogtRNI0GjUr8PlaG6Zh', 'name': 'Zeds Dead', 'type': 'artist', 'uri': 'spotify:artist:67qogtRNI0GjUr8PlaG6Zh'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'B
# ...
