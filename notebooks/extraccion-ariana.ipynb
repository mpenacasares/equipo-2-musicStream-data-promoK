# %%
import pandas as pd
import requests
import re

# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
pd.set_option('display.max_columns', None)

# %%
# Coloca tus credenciales aquí
CLIENT_ID = "fbebe461d0154abf898e3edc195b45a0" # tu identificador de la api
CLIENT_SECRET = "17d5e64384624517b40ebcb28c4ca986"# tu api key

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos = sp.search(q="genre:electronica year:2022", type='track', limit=50, offset=0)

# %%
for i in datos["tracks"]["items"][0]["album"]["artists"]:
    print (i["name"])
# Out:
# Ladytron

# %%
datos
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=genre%3Aelectronica+year%3A2022&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ucLPotcQNI7AViFytdhBz'},
#        'href': 'https://api.spotify.com/v1/artists/0ucLPotcQNI7AViFytdhBz',
#        'id': '0ucLPotcQNI7AViFytdhBz',
#        'name': 'Ladytron',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ucLPotcQNI7AViFytdhBz'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
# ...

# %%
for i in datos["tracks"]["items"][0]["album"]["artists"]:
    print (i["name"])
# Out:
# Ladytron

# %%
#Electrónica 2021: 301 - 350

datos = sp.search(q="genre:electronica year:2021", type='track', limit=50, offset=301)

json_sp = datos["tracks"]["items"]

# Este es el dict donde queremos almacenar la info
dic_canciones1 = {"song_name": [], "artist_name": [], "type" : [], "release_date" : []}

for elemento in json_sp:
    dic_canciones1["song_name"].append(elemento["name"]) #Añade nombre cancion
    dic_canciones1["type"].append(elemento["album"]["album_type"]) #Añade si es album o single
    release_date = elemento['album']["release_date"] #Define fecha de lanzamiento
    year = release_date.split("-")[0] #Divide la fecha
    dic_canciones1["release_date"].append(year) #Append solo el año de lanzamiento

    for dato in elemento["album"]["artists"]: 
        dic_canciones1["artist_name"].append(dato["name"]) #Añade nombre de artista

# %%
#Electrónica 2021: 351 - 400: 

datos = sp.search(q="genre:electronica year:2021", type='track', limit=50, offset=351)

json_sp = datos["tracks"]["items"]

# Este es el dict donde queremos almacenar la info
dic_canciones2 = {"song_name": [], "artist_name": [], "type" : [], "release_date" : []}

for elemento in json_sp:
    dic_canciones2["song_name"].append(elemento["name"]) #Añade nombre cancion
    dic_canciones2["type"].append(elemento["album"]["album_type"])
    release_date = elemento['album']["release_date"]
    year = release_date.split("-")[0]
    dic_canciones2["release_date"].append(year)
    for dato in elemento["album"]["artists"]: 
        dic_canciones2["artist_name"].append(dato["name"])

# %%
for key, value in dic_canciones1.items():
    print(f"{key}: {len(value)}")
# Out:
# song_name: 50
# artist_name: 55
# type: 50
# release_date: 50

# %%
#Electrónica 2022: 1 - 50

datos = sp.search(q="genre:electronica year:2022", type='track', limit=50, offset=0)

json_sp = datos["tracks"]["items"]

# Este es el dict donde queremos almacenar la info
dic_canciones3 = {"song_name": [], "artist_name": [], "type" : [], "release_date" : []}

for elemento in json_sp:
    dic_canciones3["song_name"].append(elemento["name"]) #Añade nombre cancion
    dic_canciones3["type"].append(elemento["album"]["album_type"])
    release_date = elemento['album']["release_date"]
    year = release_date.split("-")[0]
    dic_canciones3["release_date"].append(year)

    for dato in elemento["album"]["artists"]: 
        dic_canciones3["artist_name"].append(dato["name"])

# %%
#Electrónica 2022: 51 - 100

datos = sp.search(q="genre:electronica year:2022", type='track', limit=50, offset=51)

json_sp = datos["tracks"]["items"]

# Este es el dict donde queremos almacenar la info
dic_canciones4 = {"song_name": [], "artist_name": [], "type" : [], "release_date" : []}

for elemento in json_sp:
    dic_canciones4["song_name"].append(elemento["name"]) #Añade nombre cancion
    dic_canciones4["type"].append(elemento["album"]["album_type"])
    release_date = elemento['album']["release_date"]
    year = release_date.split("-")[0]
    dic_canciones4["release_date"].append(year)

    for dato in elemento["album"]["artists"]: 
        dic_canciones4["artist_name"].append(dato["name"])

# %%
dic_canciones4
# Out:
# {'song_name': ['Carrusel - Radio Mix',
#   'Blind Date',
#   'Send Nudes',
#   'Closer',
#   'Day by Day',
#   'To Feel Again / Trois',
#   'Counterpart',
#   'f1 racer (ft. KUČKA)',
#   'Problems',
#   'Ovule',
#   'Me&Youphoria',
#   'Sapien',
#   'World Turns',
#   'Fossora',
#   'Quiet Corners Of My Mind',
#   'TTHHEE PPAARRTTYY',
#   'Swimmer',
#   'If You Want Me',
#   'Condition',
#   'He Took Her to a Movie',
#   "This Is Not Our World - Ce n'est pas notre monde",
#   'Hard To Tell You',
#   'Meli (II)',
#   'Sapo',
#   'ATK',
#   'Planisphere Part. II',
#   'Be with You',
#   'Little Man (Tycho Remix) - Mixed',
#   'Frisco',
#   'You Don’t Know',
#   'Karst - Vegyn Remix',
#   'Mind Dimension - Tiësto Remix',
#   'It Was A Good Thing',
#   'B.E.A.T - Instrumental',
#   'Donna - Outtake',
#   'Blue Jeans',
#   'Bye Bye',
#   'Stressed Out',
#   'Spectre (Bibio Remix) - Mixed',
#   'Hips',
#   'pinky ring',
#   'MORE LOVE',
#   'Can Can Techno',
#   'TOUCH IT',
#   'Genesis',
# ...

# %%
for key, value in dic_canciones4.items():
    print(f"{key}: {len(value)}")
# Out:
# song_name: 50
# artist_name: 59
# type: 50
# release_date: 50

# %%
max_length = max(len(v) for v in dic_canciones4.values())

for key, value in dic_canciones4.items():
    while len(value) < max_length:
        value.append(None)

# %%
datos
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=genre%3Aelectronica+year%3A2022&type=track&offset=51&limit=50',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3j1xVZx3m3UPoREAQ8depP'},
#        'href': 'https://api.spotify.com/v1/artists/3j1xVZx3m3UPoREAQ8depP',
#        'id': '3j1xVZx3m3UPoREAQ8depP',
#        'name': 'Jimmix',
#        'type': 'artist',
#        'uri': 'spotify:artist:3j1xVZx3m3UPoREAQ8depP'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
# ...

# %%
df_dic_canciones4 = pd.DataFrame(dic_canciones4) 
df_dic_canciones4
# Out:
#                                             song_name  \
# 0                                Carrusel - Radio Mix
# 1                                          Blind Date
# 2                                          Send Nudes
# 3                                              Closer
# 4                                          Day by Day
# 5                               To Feel Again / Trois
# 6                                         Counterpart
# 7                                f1 racer (ft. KUČKA)
# 8                                            Problems
# 9                                               Ovule
# 10                                       Me&Youphoria
# 11                                             Sapien
# 12                                        World Turns
# 13                                            Fossora
# 14                           Quiet Corners Of My Mind
# 15                                  TTHHEE PPAARRTTYY
# ...

# %%
datos

# %%
#Album or Single (TYPE) :
datos["tracks"]["items"][0]['album']['album_type']
# Out:
# 'album'

# %%
#Release_date: 

datos["tracks"]["items"][0]['album']["release_date"]
# Out:
# '2022-10-20'

# %%
df_dic_canciones = pd.DataFrame(dic_canciones) 
df_dic_canciones
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df_dic_canciones = pd.DataFrame(dic_canciones)
#       2 df_dic_canciones
#
# NameError: name 'dic_canciones' is not defined

# %%
dic_canciones1 = {"song_name": [], "artist_name": [], "type" : [], "release_date" : []}

for ind in range(0,501,50):
    
    datos = sp.search(q="genre:electronica year:2021", type='track', limit=50, offset=ind)

    json_sp = datos["tracks"]["items"]

    for elemento in json_sp:
        dic_canciones1["song_name"].append(elemento["name"]) #Añade nombre cancion
        dic_canciones1["type"].append(elemento["album"]["album_type"]) #Añade si es album o single
        release_date = elemento['album']["release_date"] #Define fecha de lanzamiento
        year = release_date.split("-")[0] #Divide la fecha
        dic_canciones1["release_date"].append(year) #Append solo el año de lanzamiento

        for dato in elemento["album"]["artists"]: 
            dic_canciones1["artist_name"].append(dato["name"]) #Añade nombre de artista

# %%
for key, value in dic_canciones1.items():
    print(f"{key}: {len(value)}")
# Out:
# song_name: 550
# artist_name: 671
# type: 550
# release_date: 550

# %%
for i in range(0,200, 25):
  params = {“cursor”: i}

NUEVO

Nuevo
12:45
players_final = {“first_name”: [], “last_name”: [], “team”: []}
for i in range(0,200, 25):
    params = {“cursor”: i}
    res_jugadores = requests.get(f”https://api.balldontlie.io/v1/players”, params=params, headers = {‘Authorization’: ‘594dd4ac-d5b3-4254-b658-3c636349ca7e’} )
    res_jugadores = res_jugadores.json()
    for jugador in res_jugadores[“data”]:
        players_final[“first_name”].append(jugador[“first_name”])
        players_final[“last_name”].append(jugador[“last_name”])
        players_final[“team”].append(jugador[“team”][“full_name”])
df_jugadores = pd.DataFrame(jugador)
df_jugadores
# Out:
#   Cell In[9], line 2
#     params = {“cursor”: i}
#               ^
# SyntaxError: invalid character '“' (U+201C)

# %%
dic_canciones1
# Out:
# {'song_name': ['Crust',
#   'Abu Simbel',
#   'Apricots',
#   'Using What You Got',
#   'Lido',
#   '405 - Metronomy x Biig Piig',
#   'Black Gold',
#   'better',
#   'Come In Closer',
#   'Uneasy - Metronomy x spill tab',
#   'Black Rain',
#   'Imagineering',
#   'A Brand New Start',
#   'Atlas',
#   'African Samurai',
#   'Love Divide',
#   'You Can Do It',
#   'Shadows',
#   'Lambent Rag',
#   'Pain and Blood',
#   'God is A DJ',
#   'Tides',
#   'Only Love (with Brijean)',
#   'Between Memories',
#   'Movement 5',
#   'Sounds Of Blue',
#   'Ritchie Sacramento',
#   'in drink',
#   'Safeword',
#   'The Daisy',
#   'Siena',
#   'Impressions',
#   'Pray - Chris Malinchak Mix',
#   'The Lonely Night - Reprise Version',
#   'Rosewood',
#   'Nefertari',
#   'Innadadance (feat. Suli Breaks & Jazzie B) (Meduza Remix) (Edit)',
#   'Saku',
#   'Caracas Way',
#   'Survivors',
#   'War at the Door',
#   'Your Lord',
#   "Sot-l'y-laisse",
#   'Beautiful',
#   'This Cursed Life',
# ...

# %%
df_dic_canciones1 = pd.DataFrame(dic_canciones1) 
df_dic_canciones1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_dic_canciones1 = pd.DataFrame(dic_canciones1)
#       2 df_dic_canciones1
#
# File ~/anaconda4/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~/anaconda4/lib/python3.12/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...
