# %%
import pandas as pd
import requests
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import os
from dotenv import load_dotenv 

import csv
import json

# %%
import time #para el time sleep

# %%
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# %% [markdown]
# Ejemplo de endpoint: "https://musicbrainz.org/ws/2/artist/?query=artist:XXXXXXXXX&fmt=json"

# %% [markdown]
# Función llamar api

# %%
def llamar_api(url):

    llamada = requests.get(url)  # Realiza una solicitud GET a la URL proporcionada y almacena la respuesta en 'llamada'.
    print(f"La llamada a la API nos ha dado una respuesta de tipo: {llamada.status_code}")  # Imprime el código de estado de la respuesta.
    if llamada.status_code != 200:  # Comprueba si la respuesta no fue exitosa (código de estado distinto de 200).
        print(f"El motivo por el que la llamada falló es {llamada.reason}")  # Imprime la razón de la falla.
    else:
        return llamada.json()  # Si la llamada fue exitosa, devuelve los datos de respuesta en formato JSON.

# %% [markdown]
# Sacar los artistas de Spotify:

# %%
# Paso 1: Leer el archivo CSV
spoti_csv_file = "../data/dataframes_combinados.csv" # nombre de tu archivo Spoti CSV
spoti_json_file = "dataframes_combinados.json"  # nombre del archivo Spoti de salida JSON

# Paso 2: Abrir el CSV y convertir a formato JSON
with open(spoti_csv_file, mode='r', encoding='utf-8') as file:
    # Leer el contenido CSV
    csv_reader = csv.DictReader(file)
    
    # Convertir cada fila a diccionario y agregarla a una lista
    data = [row for row in csv_reader]

# Paso 3: Escribir los datos en un archivo JSON
with open(spoti_json_file, mode='w', encoding='utf-8') as file:
    json.dump(data, file, indent=4)  # Guarda el JSON con formato legible (indent=4)

print(f'Archivo {spoti_json_file} creado con éxito.')
# Out:
# Archivo dataframes_combinados.json creado con éxito.

# %%
#Traemos el archivo a json
with open("dataframes_combinados.json","r") as f:
    result_spoti = json.load(f)

# %% [markdown]
# #Sacar los artistas de MB:

# %%
# Paso 1: Leer el archivo CSV
MB_csv_file = "../data/dataframe_MB.csv" # nombre de tu archivo Spoti CSV
MB_json_file = "dataframe_MB.json"  # nombre del archivo Spoti de salida JSON

# Paso 2: Abrir el CSV y convertir a formato JSON
with open(MB_csv_file, mode='r', encoding='utf-8') as file:
    # Leer el contenido CSV
    csv_reader = csv.DictReader(file)
    
    # Convertir cada fila a diccionario y agregarla a una lista
    data = [row for row in csv_reader]

# Paso 3: Escribir los datos en un archivo JSON
with open(MB_json_file, mode='w', encoding='utf-8') as file:
    json.dump(data, file, indent=4)  # Guarda el JSON con formato legible (indent=4)

print(f'Archivo {MB_json_file} creado con éxito.')
# Out:
# Archivo dataframe_MB.json creado con éxito.

# %%
#Traemos el archivo a json
with open("dataframe_MB.json","r") as f: 
    result_MB = json.load(f)

# %%
result_MB[0]
# Out:
# {'artista': 'Noah Gundersen',
#  'pais_de_origen': 'United States',
#  'area_de_origen': 'Olympia',
#  'fecha_nacimiento': '1989-05-31',
#  'fecha_inicio_actividad': 'NULL',
#  'fecha_fin_actividad': 'Actualidad'}

# %%
#Creamos lista vacia para que se complete con los artistas
artist = []

for item in result_spoti: 
    artist.append(item['artista'])

# %%
#Convertimos en set para eliminar artistas duplicados (hay artistas con mas de una canción en el mismo año)
set_artist = set(artist)
set_artist
# Out:
# {'AMBKOR',
#  'Abraham Mateo',
#  'Abäk',
#  'Accion Sanchez',
#  'Adam Jensen',
#  'Adventus',
#  'Aimer',
#  'Air',
#  'Aitana',
#  'Ak4:20',
#  'Alberto Dimeo',
#  'Aldo Cadiz',
#  'Alejo',
#  'Aleksander Debicz',
#  'Alex G',
#  'Alex Gargolas',
#  'Alex Rose',
#  'Alex Ubago',
#  'Alice Wonder',
#  'All Time Low',
#  'Almighty',
#  'Alvaro Diaz',
#  'Alvvays',
#  'Amadeüs',
#  'Amarion',
#  'Amenazzy',
#  'Amistades Peligrosas',
#  'Amon Tobin',
#  'Ana Mena',
#  'Andrea Sertori',
#  'Andrés Madariaga',
#  'Andrés Suárez',
#  'Andy & Lucas',
#  'Andy Frasco & The U.N.',
#  'Andy Rivera',
#  'Andy Stott',
#  'Angela Hewitt',
#  'Angelos',
#  'Angelus Apatrida',
#  'Ankhal',
#  'Ankor',
#  'Antonio José',
#  'Antonio Orozco',
#  'Antonio Ruiz Pipó',
#  'Anubiis',
#  'Anuel AA',
#  'Anıl Emre Daldal',
#  'Arcane',
#  'Arce',
#  'Arctic Monkeys',
#  'Arcy Drive',
#  'Arcángel',
#  'Arde Bogotá',
#  'Arnau Griso',
#  'Arrested Youth',
#  'Art Lown',
#  'Artury Pepper',
#  'Austin French',
#  'Aventura',
#  'Axel Boman',
#  'Ayax y Prok',
#  'Azucar Moreno',
#  'BICEP',
#  'BOUE',
#  'BUMP OF CHICKEN',
#  'Babasonicos',
#  'Bad Bunny',
#  'Bad Gyal',
#  'Bad Suns',
#  'Badflower',
#  'Bala',
#  'Band of Horses',
#  'Band&dos',
#  'Barns Courtney',
#  'Basement Jaxx',
#  'Beach House',
#  'Bear McCreary',
#  'Beatriz Luengo',
#  'Becky G',
#  'Bee Gees',
#  'Bejo',
#  'Belén Aguilera',
#  'Ben Rector',
#  'Beret',
#  'Beéle',
#  'Bibio',
#  'Big Thief',
#  'Billy Idol',
#  'Bizarrap',
#  'Björk',
#  'Black Country, New Road',
#  'Black Label Society',
#  'Blake',
#  'Blanco Palamera',
#  'Blas Cantó',
#  'Bleachers',
#  'Blessd',
#  'Blockhead',
#  'Bomba Estéreo',
#  'Bombai',
#  'Bonnie Raitt',
#  'Bonobo',
#  'Booka Shade',
#  'Boza',
#  'Brandi Carlile',
#  'Brandon Heath',
#  'Brantley Gilbert',
#  'Brent Cobb',
#  'Brett Eldredge',
#  'Bring Me The Horizon',
#  'Brittany Howard',
#  'Broken Lip',
#  'Brothers Osborne',
#  'Brray',
#  'Bryant Myers',
#  'Bryce Fox',
#  'Brytiago',
#  'Burial',
#  'CA7RIEL',
#  'CNCO',
#  'Café Quijano',
#  'Calero LDN',
#  'Cali Y El Dandee',
#  'Califato ¾',
#  'Camilo',
#  'Caribou',
#  'Carlos Baute',
#  'Carlos Herrera Music',
#  'Carlos Sadness',
#  'Carolina Durante',
#  'Casper Magico',
#  'Casting Crowns',
#  'Catalyna',
#  'Cazzu',
#  'Cecilia Krull',
#  'Celtian',
#  'Cerebral Effusion',
#  'Chandler Moore',
#  'Chanell',
#  'Chase Rice',
#  'Chencho Corleone',
#  'Chenoa',
#  'Chevelle',
#  'Chris Jedi',
#  'Chris Lane',
#  'Chris Tomlin',
#  'Christian Löffler',
#  'Cidergirl',
#  'City of the Sun',
#  'Clap! Clap!',
#  'Clara Cava',
#  'Clark',
#  'Cody Jinks',
#  'Coheed and Cambria',
#  'Cole Swindell',
#  'Colorblind',
#  'Colton Dixon',
#  'Comandante Twin',
#  'Conchita',
#  'Corina Smith',
#  'Courtney Barnett',
#  'Crazy P',
#  'Cris Mj',
#  'Crisix',
#  'Crowder',
#  'Cyclo',
#  'DARKSIDE',
#  'DECO*27',
#  'DEKKO',
#  'DENM',
#  'DICE',
#  'DJ Koze',
#  'DJ Tennis',
#  'DJs Pareja',
#  'DREAMERS',
#  'Daddy Yankee',
#  'Dalex',
#  'Dan Bremnes',
#  'Dani Fernández',
#  'Dani Martín',
#  'Daniel Avery',
#  'Daniel Barenboim',
#  'Daniel Zueras',
#  'Danny Gokey',
#  'Danny Ocean',
#  'Dante',
#  'Danza Invisible',
#  'Daphni',
#  'Dardust',
#  'Darell',
#  'Dark Moor',
#  'Daughtry',
#  'Dauwd',
#  'David Bisbal',
#  'David Cordero',
#  'David Otero',
#  'Dayglow',
#  'De La Ghetto',
#  'De La Rose',
#  'DePol',
#  'Dead Poet Society',
#  'Death Cab for Cutie',
#  'Decai',
#  'Dei V',
#  'Delaossa',
#  'Delta Sleep',
#  'Denom',
#  'Depeche Mode',
#  'Depresión Sonora',
#  'Diego Martín',
#  'Digitalism',
#  'Dillon Carmichael',
#  'Dirty Heads',
#  'Disney',
#  'Dok & Martin',
#  'Dollar Selmouni',
#  'Dominic Fike',
#  'Don Omar',
#  'Dorothy',
#  'Drake White',
#  'Drew Parker',
#  'Droow',
#  'Drugdealer',
#  'Dua Lipa',
#  'Duki',
#  'Duo Multicorde',
#  'Duran Duran',
#  'Dustin Lynch',
#  'Dvicio',
#  'Dylan Schneider',
#  'Dylan Scott',
#  'Dímelo Flow',
#  'E.VAX',
#  'ELVIS (Original Motion Picture Soundtrack)',
#  'ELYELLA',
#  'Edu Imbernon',
#  'Edu Linares',
#  'Edurne',
#  'Efecto Pasillo',
#  'El Alfa',
#  'El Arrebato',
#  'El Barrio',
#  'El Chojin',
#  'El Clooy',
#  'Eladio Carrion',
#  'Ele A El Dominio',
#  'Elefantes',
#  'Elena Ortega',
#  'Eli Young Band',
#  'Ella Baila Sola',
#  'Elle King',
#  'Elton John',
#  'Elvis Presley',
#  'Emisound',
#  'Esteman',
#  'Estopa',
#  'Eve',
#  'Exxasens',
#  'F.S.Blumm',
#  'FERNANDOCOSTA',
#  'Faithless',
#  'Fallen Roses',
#  'Fangoria',
#  'Fantastic Negrito',
#  'Farruko',
#  'Father John Misty',
#  'Fatima Hajji',
#  'Federico Mompou',
#  'Feid',
#  'Fever Ray',
#  'Fit For A King',
#  'Fito y Fitipaldis',
#  'Fleet Foxes',
#  'Floating Points',
#  'Florence + The Machine',
#  'Florida Georgia Line',
#  'Flying Lotus',
#  'Fondo Flamenco',
#  'Fontaines D.C.',
#  'Foo Fighters',
#  'Foreign Teck',
#  'Fortunate Youth',
#  'Four Tet',
#  'Foyone',
#  'Francesca Battistelli',
#  'Francisco Tárrega',
#  'Friday Pilots Club',
#  'Fruit Bats',
#  'Fuego',
#  'Fuel Fandango',
#  'Funambulista',
#  'Fyahbwoy',
#  'Gabriel Dominguez',
#  'Generación 12',
#  'Genio Producer',
#  'Gente De Zona',
#  'George FitzGerald',
#  'Georgie Dann',
#  'Ghost',
#  'Gidge',
#  'Glass Animals',
#  'Global Underground',
#  'Gold Panda',
#  'Good Morning',
#  'Goodbye June',
#  'Gorillaz',
#  'Gospel of Dance',
#  'Goth Babe',
#  'Greeicy',
#  'Green Valley',
#  'Greta Van Fleet',
#  'Groove Armada',
#  'Guaynaa',
#  'Guitarricadelafuente',
#  "Guns N' Roses",
#  'GusGus',
#  'Guts',
#  'HARRY WAS HERE',
#  'HEALTH',
#  'HVOB',
#  'Hadadanza',
#  'Hades66',
#  'Hannah Murphy',
#  'Hanzel La H',
#  'Hard GZ',
#  'Hector Rios Vnzl',
#  'Heitor Pereira',
#  'Henry Mendez',
#  'Hercules & Love Affair',
#  'Heroes Del Silencio',
#  'Highly Suspect',
#  'Hilary Hahn',
#  'Hippo Campus',
#  'Hiss Golden Messenger',
#  'Hoke',
#  'Hollywood Undead',
#  'Hombres G',
#  'HoneyWorks',
#  'Hooverphonic',
#  'Hot Chip',
#  'Houndmouth',
#  'House Of Pain',
#  'Hozier',
#  'I AM THEY',
#  'IDLES',
#  'IZAL',
#  'Ill Pekeño',
#  'Imagine Dragons',
#  'India Martinez',
#  'Inner Wave',
#  'Insane Clown Posse',
#  'Iration',
#  'Iron Maiden',
#  'Isaac Albéniz',
#  'Israel B',
#  'J Abdiel',
#  'J Alvarez',
#  'J Balvin',
#  'JHAYCO',
#  'JOLLY (PE)',
#  'Jacques Greene',
#  'James McMurtry',
#  'Jameson Rodgers',
#  'Jamie xx',
#  'Jane Remover',
#  'Janine Jansen',
#  'Japanese Breakfast',
#  'Jasmon',
#  'Jason Aldean',
#  'Jason Kolàr',
#  'Javiera Mena',
#  'Javiielo',
#  'Jay Menez',
#  'Jay Wheeler',
#  'Jeff Danna',
#  'Jefferson Airplane',
#  'Jens Buchert',
#  'Jeremy Camp',
#  'Jerry Di',
#  'Jerry Lee Lewis',
#  'Jesse Roper',
#  'Jesús Adrián Romero',
#  'Jimmie Allen',
#  'Jimmix',
#  'Joaquín Sabina',
#  'Joaquín Turina',
#  'Joe Goddard',
#  'Joey Valence & Brae',
#  'John Debney',
#  'John Fulford Music',
#  'John Hiatt',
#  'Jon Hopkins',
#  'Jon Pardi',
#  'Jon Z',
#  'Josiah and the Bonnevilles',
#  'Jossef',
#  'Jotaerre',
#  'Journey',
#  'Jowell & Randy',
#  'Joy Orbison',
#  'Joyce Santana',
#  'Juan Magán',
#  'Juan del Encina',
#  'Juana Molina',
#  'Juhn',
#  'Justice',
#  'Justin Quiles',
#  'K.Flay',
#  'KALEO',
#  'KANA-BOON',
#  'KAROL G',
#  'KHEA',
#  'KLANGSTEIN',
#  'Kairikibear',
#  'Karbeats',
#  'Kase.O',
#  'Kaze',
#  'Khaled',
#  'Kidd Keo',
#  'Kiko y Shara',
#  'King Clave',
#  'Kings of Leon',
#  'Kip Moore',
#  'Kixnare',
#  'Kodak Black',
#  'Korn',
#  'Kovács Beatrix',
#  'LCD Soundsystem',
#  'LEGEND EFFECT',
#  'LIT killah',
#  'LOUTA',
#  'La Bien Querida',
#  'La Casa Azul',
#  'La Culpa',
#  'La La Love You',
#  'La Maravillosa Orquesta del Alcohol',
#  'La Oreja de Van Gogh',
#  'La Paloma',
#  'La Pegatina',
#  'Ladilla Rusa',
#  'Lady Gaga',
#  'Ladytron',
#  'Lake Street Dive',
#  'Lasai',
#  'Lauren Daigle',
#  'Lee Brice',
#  'Leiva',
#  'Lenny Tavárez',
#  'Leon Vynehall',
#  'Lepoka',
#  'Level 42',
#  'Limp Bizkit',
#  'Little Dragon',
#  'Little Stranger',
#  'Locus',
#  'Logan Mize',
#  'Lola Indigo',
#  'Lone Ark',
#  'Lorenzo Soria',
#  'Lori Meyers',
#  'Los Angeles Negros',
#  'Los Bravos',
#  'Los Fabulosos Cadillacs',
#  'Los Rebujitos',
#  'Love of Lesbian',
#  'Luar La L',
#  'Luke Bryan',
#  'Luna Li',
#  'Lunay',
#  'Lyanno',
#  'Lytos',
#  'Lérica',
#  'MAN WITH A MISSION',
#  'MARLENA',
#  'MASS OF THE FERMENTING DREGS',
#  'MJ Lenderman',
#  'MORVN',
#  'Mac Powell',
#  'Maga',
#  'Maki',
#  'Maluma',
#  'Malú',
#  'Mammoth WVH',
#  'Manchester Orchestra',
#  'Mano Le Tough',
#  'Manu Dia',
#  'Manu Manzo',
#  'Manuel Barrueco',
#  'Manuel Carrasco',
#  'Manuel Turizo',
#  'Manybeat',
#  'Maná',
#  'Marc Seguí',
#  'Marco Tegui',
#  'Marcus King',
#  'Marea',
#  'Maretu',
#  'Maria Becerra',
#  'Marlon',
#  'Mastodon',
#  'Maston',
#  'Matt Maher',
#  'Matthew West',
#  'Mau y Ricky',
#  'Max Cooper',
#  'Megadeth',
#  'Melendi',
#  'MercyMe',
#  'Meredith Andrews',
#  'Metallica',
#  'Metronomy',
#  'Micah Tyler',
#  'Michael Ray',
#  'Micro TDH',
#  'Midrift',
#  'Miguel Bastida',
#  'Mihali',
#  'Mike Bahía',
#  'Mikel Erentxun',
#  'Miky Woodz',
#  'Milky Chance',
#  'Milly',
#  'Milo j',
#  'Miranda!',
#  'Miss Kittin',
#  'Mistah Godeh',
#  'Mitchell Tenpenny',
#  'Moby',
#  'Moderat',
#  'Modeselektor',
#  'Mogwai',
#  'Momma',
#  'Monica Naranjo',
#  'Mora',
#  'Morcheeba',
#  'Morphium',
#  'Mother Mother',
#  'Motörhead',
#  'Mount Kimbie',
#  'Mujeres',
#  'Muse',
#  'My Chemical Romance',
#  'Myke Towers',
#  'MËSTIZA',
#  'Mägo de Oz',
#  'Måneskin',
#  'NATTI NATASHA',
#  'NEEDTOBREATHE',
#  'Nach',
#  'Natalia Jiménez',
#  'Natalia Lafourcade',
#  'Natalie Grant',
#  'Nathaniel Rateliff & The Night Sweats',
#  'Natos y Waor',
#  'Neutro Shorty',
#  'Newsboys',
#  'Nickelback',
#  'Nicki Nicole',
#  'Nicky Jam',
#  'Nightmares On Wax',
#  'Nikone',
#  'Nil Moliner',
#  'Nils Frahm',
#  'Nio Garcia',
#  'Nirvana',
#  'Niña Polaca',
#  'Niño de Elche',
#  'No Vacation',
#  'Noah Gundersen',
#  'Noriel',
#  'Nosaj Thing',
#  'Nueen',
#  'Nunatak',
#  'Nylonwings',
#  'Nyno Vargas',
#  'OFFICIAL HIGE DANDISM',
#  'ONE OK ROCK',
#  'OTA El Hipopotamo',
#  'Ocer y Rade',
#  'Of Monsters and Men',
#  'Old Dominion',
#  'Old Mervs',
#  'Olivia Newton-John',
#  'Omar Courtz',
#  'Omy de Oro',
#  'OneRepublic',
#  'Opera Magna',
#  'Orbital',
#  'Original Juan',
#  'Ovi',
#  'Ovy On The Drums',
#  'Ozuna',
#  'Ozzy Osbourne',
#  'P.A.F.F.',
#  'PELICAN FANCLUB',
#  'Pablo Alborán',
#  'Pablo Ferrandez',
#  'Pablo López',
#  'Pablo Say',
#  'Pablo de Sarasate',
#  'Pacho El Antifeka',
#  'Pacific Roots',
#  'Pailita',
#  'Palace',
#  'Palaye Royale',
#  'Papa Roach',
#  'Papi Sousa',
#  'Parmalee',
#  'Passafire',
#  'Paul Kalkbrenner',
#  'Paul McCartney',
#  'Paula Mattheus',
#  'Paulo Londra',
#  'Peces Raros',
#  'Pejzaż',
#  'Pequeño Pez',
#  'Petey',
#  'Phil Wickham',
#  'Phoenix',
#  'Pig&Dan',
#  'PinocchioP',
#  'Piso 21',
#  'Pixies',
#  'Plaid',
#  'Pol 3.14',
#  'Pol Granch',
#  'Pole.',
#  'Polyphia',
#  'Populous',
#  'Porta',
#  'Portico Quartet',
#  'Portugal. The Man',
#  'Prince Royce',
#  'Proyecto Gomez Casa',
#  'Pusho',
#  'Quantic',
#  'Quarters of Change',
#  'Queen',
#  'Quevedo',
#  'RADWIMPS',
#  'ROA',
#  'RYSY',
#  'Rachael Lampa',
#  'Radiohead',
#  'Rafa Espino',
#  'Rammstein',
#  'Randy',
#  'Rapsusklei',
#  'Rata Negra',
#  'Rauw Alejandro',
#  'Rawayana',
#  'Ray MD',
#  'Rayden',
#  'Rebecca St. James',
#  'Rebelution',
#  'Recondite',
#  'Recycled J',
#  'Red Hot Chili Peppers',
#  'RedHook',
#  'Reik',
#  'Rels B',
#  'Rend Collective',
#  'Reykjavik606',
#  'Reykon',
#  'Rhett Walker',
#  'Rhye',
#  'Richy Mitch & The Coal Miners',
#  'Rigoberta Bandini',
#  'Rise Against',
#  'Rival Consoles',
#  'Rob Zombie',
#  'Robert Plant',
#  'Rochy RD',
#  'Rojo',
#  'Rokero',
#  'Romare',
#  'Romeo Santos',
#  'Rone',
#  'Rosalie.',
#  'Rosario',
#  'Ross from Friends',
#  'Royal Blood',
#  'Royel Otis',
#  'Rozalén',
#  'Russell Dickerson',
#  'Rvfv',
#  'Rvssian',
#  'Ryan Castro',
#  'Ryan Hurd',
#  'Ryan Stevenson',
#  'Róisín Murphy',
#  'Röyksopp',
#  'SAIKO',
#  'SBTRKT',
#  'STARSET',
#  'SWIT EME',
#  'Saint Motel',
#  'Salduie',
#  'Sam Fender',
#  'Sam Hunt',
#  'Sanctus Real',
#  'Santana',
#  'Saratoga',
#  'Saurom',
#  'Scotty McCreery',
#  'Sebastian Yatra',
#  'Sech',
#  'Sergio Contreras',
#  'Sergio Dalma',
#  'Sexy Zebras',
#  'Shaila Dúrcal',
#  'Shane & Shane',
#  'Sharif',
#  'Sharon Van Etten',
#  'Shinova',
#  'Shinsei Kamattechan',
#  'Sho-Hai',
#  'Shotta',
#  'Shé',
#  'Siddhartha',
#  'Siggy',
#  'Sigur Rós',
#  'Siloé',
#  'Simple Plan',
#  'Ska-P',
#  'Skalpel',
#  'Skillet',
#  'Skylar Grey',
#  'Slayter',
#  'Slipknot',
#  'Sneaker Pimps',
#  'Sniper Gang',
#  'Soccer Mommy',
#  'Sofia Ellar',
#  'Soge Culebra',
#  'Sohodolls',
#  'Soleá Morente',
#  'Sophie Powers',
#  'Soraya',
#  'Spacey Jane',
#  'Spoon',
#  'St Germain',
#  'Stars Go Dim',
#  'Stephen Bishop',
#  'Stick Figure',
#  'Sufjan Stevens',
#  'SunKissed Lola',
#  'Sunday Noise',
#  'Surfer Girl',
#  'Suso Saiz',
#  'Synlakross',
#  'Sébastien Tellier',
#  'Sôber',
#  'THE DRIVER ERA',
#  'TK from Ling tosite sigure',
#  'TOOL',
#  'Taburete',
#  'Tainy',
#  'Talisto',
#  'Tamara',
#  'Tame Impala',
#  'Tauren Wells',
#  'Tedeschi Trucks Band',
#  'Tempo',
#  'The 1975',
#  'The Beths',
#  'The Black Keys',
#  'The Blue Stones',
#  'The Bones of J.R. Jones',
#  'The Chemical Brothers',
#  'The Crystal Method',
#  'The Del-Vikings',
#  'The Elovaters',
#  'The Ghost Club',
#  'The Goo Goo Dolls',
#  'The Green',
#  'The Happy Fits',
#  'The Hip Abduction',
#  'The Killers',
#  'The Knife',
#  'The Lumineers',
#  'The Movement',
#  'The Neighbourhood',
#  'The Offspring',
#  'The Poles',
#  'The Red Pears',
#  'The Rolling Stones',
#  'The Rudeboyz',
#  'The Score',
#  'The Struts',
#  'The Unlikely Candidates',
#  'The War On Drugs',
#  'The White Stripes',
#  'The Who',
#  'The Wombats',
#  'Thom Yorke',
#  'Thomas Rhett',
#  'Three Days Grace',
#  'Tiago PZK',
#  'Tierra Santa',
#  'Tiga',
#  'TobyMac',
#  'Toda la Vida',
#  'Tom Morello',
#  'Tom Petty and the Heartbreakers',
#  'Tommy James & The Shondells',
#  'Tony Guerra',
#  'Toro',
#  'Tosca',
#  'Totally Enormous Extinct Dinosaurs',
#  'ToteKing',
#  'Toundra',
#  'Travis Denning',
#  'Tregua',
#  'Tricky',
#  'Tropidelic',
#  'Trueno',
#  'Twenty One Pilots',
#  'Two Feet',
#  'Tycho',
#  'Tyler Booth',
#  'Tyler Rich',
#  'Télépopmusik',
#  'UNISON SQUARE GARDEN',
#  'UNKLE',
#  'Ulrich Schnauss',
#  'Underworld',
#  'Valeria Castro',
#  'Vana Liya',
#  'Vance Joy',
#  'Vanesa Martín',
#  'Various Artists',
#  'Veintiuno',
#  'Vendex',
#  'Vetusta Morla',
#  'Victor Porfidio',
#  'Vitalic',
#  'Viuda',
#  'Viva Suecia',
#  'Volbeat',
#  'Vulfpeck',
#  'Walker Hayes',
#  'Warcry',
#  'Warmth',
#  'Warpaint',
#  'Wax Tailor',
#  'We Are Messengers',
#  'We Came As Romans',
#  'Weezer',
#  'Wet Leg',
#  'Weval',
#  'Whiskey Myers',
#  'WhoMadeWho',
#  'Wild Honey',
#  'Will C',
#  'Wine Lips',
#  'Wisin',
#  'Wisin & Yandel',
#  'Wolf Alice',
#  'YONAKA',
#  'YOVNGCHIMI',
#  'YUNGBLUD',
#  'Yakamoto Kotzuga',
#  'Yamila',
#  'Yampi',
#  'Yan Block',
#  'Yandel',
#  'Yeah Yeah Yeahs',
#  'Yeruza',
#  'Young Miko',
#  'Young the Giant',
#  'Yunchan Lim',
#  'Yung Beef',
#  'Zac Brown Band',
#  'Zahara',
#  'Zaidbreak',
#  'Zero 7',
#  'Zetazen',
#  'Zion & Lennox',
#  'Zoé',
#  'alt-J',
#  'black midi',
#  'coldrain',
#  'feeble little horse',
#  'for KING & COUNTRY',
#  'from',
#  'grandson',
#  'if i die in mississippi',
#  'ivri',
#  'lovelytheband',
#  'quannnic',
#  'trentemøller',
#  'vf7',
#  'Álvaro De Luna',
#  'Âme',
#  'Ñejo',
#  'Ñengo Flow',
#  '✝✝✝ (Crosses)',
#  '花冷え。'}

# %%
list_artistas = list(set_artist)
len(list_artistas)
# Out:
# 899

# %%
list_artistas
# Out:
# ['Arcy Drive',
#  'Portugal. The Man',
#  'Talisto',
#  'Rayden',
#  'No Vacation',
#  'Jesús Adrián Romero',
#  'Moderat',
#  'Yung Beef',
#  'Sohodolls',
#  'Chris Lane',
#  'Broken Lip',
#  'Ryan Castro',
#  'Myke Towers',
#  'La Pegatina',
#  'Four Tet',
#  'Georgie Dann',
#  'YUNGBLUD',
#  'STARSET',
#  'ivri',
#  'Black Label Society',
#  'Belén Aguilera',
#  'LCD Soundsystem',
#  'Antonio José',
#  'Fortunate Youth',
#  'Ben Rector',
#  'La Culpa',
#  'Japanese Breakfast',
#  'Dillon Carmichael',
#  'Booka Shade',
#  'J Alvarez',
#  'Bejo',
#  'Lunay',
#  'Conchita',
#  'Hozier',
#  'Malú',
#  'Tempo',
#  'Lepoka',
#  'Richy Mitch & The Coal Miners',
#  'Tycho',
#  'Milo j',
#  'Metallica',
#  'Maga',
#  'Rauw Alejandro',
#  'Natalia Jiménez',
#  'Heroes Del Silencio',
#  'Bizarrap',
#  'Hades66',
#  'Pablo Say',
#  'Arcane',
#  'My Chemical Romance',
#  'Phoenix',
#  'Sofia Ellar',
#  'Tauren Wells',
#  'Rosario',
#  'Lenny Tavárez',
#  'Shotta',
#  'Siggy',
#  'Marco Tegui',
#  'Cole Swindell',
#  'Anıl Emre Daldal',
#  'Randy',
#  'Big Thief',
#  'Saint Motel',
#  'Travis Denning',
#  'Bad Suns',
#  'Nicky Jam',
#  'Marlon',
#  'Ana Mena',
#  'Brytiago',
#  'Exxasens',
#  'Phil Wickham',
#  'SBTRKT',
#  'Droow',
#  'Sniper Gang',
#  'Eli Young Band',
#  'La Casa Azul',
#  'Chase Rice',
#  'UNKLE',
#  'Jamie xx',
#  'Pacho El Antifeka',
#  'La Maravillosa Orquesta del Alcohol',
#  'SWIT EME',
#  'Nosaj Thing',
#  'Amarion',
#  'Artury Pepper',
#  'The Killers',
#  'Miranda!',
#  'MARLENA',
#  'Pablo Ferrandez',
#  'Gidge',
#  'Miss Kittin',
#  'ONE OK ROCK',
#  'Moby',
#  'Air',
#  'Andy Frasco & The U.N.',
#  'Justice',
#  'Taburete',
#  'Glass Animals',
#  'Jeremy Camp',
#  'Brandon Heath',
#  'Bonobo',
#  'Brantley Gilbert',
#  'Anubiis',
#  'RedHook',
#  'Jane Remover',
#  'Cecilia Krull',
#  'Janine Jansen',
#  'Jay Menez',
#  'Francesca Battistelli',
#  'Paula Mattheus',
#  'Röyksopp',
#  'Fondo Flamenco',
#  'La Paloma',
#  'Leiva',
#  'Arnau Griso',
#  'Joey Valence & Brae',
#  'Green Valley',
#  'Dark Moor',
#  'Yandel',
#  'Delaossa',
#  'Mikel Erentxun',
#  'Faithless',
#  'Antonio Ruiz Pipó',
#  'RYSY',
#  'Viuda',
#  'ELVIS (Original Motion Picture Soundtrack)',
#  'Generación 12',
#  'black midi',
#  'Foo Fighters',
#  'Quevedo',
#  'Corina Smith',
#  'Tom Petty and the Heartbreakers',
#  'Rival Consoles',
#  'Edurne',
#  'Gorillaz',
#  'Fever Ray',
#  'Fatima Hajji',
#  'WhoMadeWho',
#  'Blessd',
#  'Danny Gokey',
#  'ELYELLA',
#  'Tiago PZK',
#  'Café Quijano',
#  'Arde Bogotá',
#  'Ryan Stevenson',
#  'Jerry Lee Lewis',
#  'Noriel',
#  'Slipknot',
#  'Inner Wave',
#  'Jefferson Airplane',
#  'Orbital',
#  'Manchester Orchestra',
#  'Cody Jinks',
#  'Goodbye June',
#  'Dalex',
#  'Fyahbwoy',
#  'Marcus King',
#  'OTA El Hipopotamo',
#  'Olivia Newton-John',
#  'Proyecto Gomez Casa',
#  'Groove Armada',
#  'Jon Pardi',
#  'Melendi',
#  'Darell',
#  'Mammoth WVH',
#  'Band of Horses',
#  'Jon Z',
#  'Cali Y El Dandee',
#  'Elton John',
#  'Bad Bunny',
#  'KLANGSTEIN',
#  'Nylonwings',
#  'Skalpel',
#  'Mihali',
#  'Mistah Godeh',
#  'We Came As Romans',
#  'Dauwd',
#  'The Score',
#  'Modeselektor',
#  'Vendex',
#  'Morcheeba',
#  'Sigur Rós',
#  'Clap! Clap!',
#  'Opera Magna',
#  'Ocer y Rade',
#  'Warcry',
#  'Fangoria',
#  'Beach House',
#  'Foreign Teck',
#  'Antonio Orozco',
#  'IZAL',
#  'HARRY WAS HERE',
#  'Megadeth',
#  'SAIKO',
#  'Foyone',
#  'Joaquín Sabina',
#  'Father John Misty',
#  'DREAMERS',
#  'Fruit Bats',
#  'The 1975',
#  'Manuel Barrueco',
#  'TK from Ling tosite sigure',
#  'Justin Quiles',
#  'Marea',
#  'Greta Van Fleet',
#  'Bleachers',
#  'Motörhead',
#  'Pequeño Pez',
#  'Blockhead',
#  'India Martinez',
#  'Kaze',
#  'Pusho',
#  'Mike Bahía',
#  'Old Dominion',
#  'Fallen Roses',
#  'HVOB',
#  'Three Days Grace',
#  'Zahara',
#  'Maki',
#  'Arctic Monkeys',
#  'Mägo de Oz',
#  'Amistades Peligrosas',
#  'Tropidelic',
#  'City of the Sun',
#  'Pol 3.14',
#  'Ray MD',
#  'Rhye',
#  'LOUTA',
#  'Maná',
#  'Polyphia',
#  'Plaid',
#  'Digitalism',
#  'Alvvays',
#  "Guns N' Roses",
#  'Nils Frahm',
#  'Lola Indigo',
#  'E.VAX',
#  'Soleá Morente',
#  'DEKKO',
#  'Farruko',
#  'Jowell & Randy',
#  'John Fulford Music',
#  'Mastodon',
#  'Hooverphonic',
#  'El Chojin',
#  'PELICAN FANCLUB',
#  'Ele A El Dominio',
#  'Los Fabulosos Cadillacs',
#  'Spacey Jane',
#  'Jens Buchert',
#  'Austin French',
#  'Rata Negra',
#  'Arce',
#  'Comandante Twin',
#  'Guts',
#  'Bombai',
#  'Arcángel',
#  'Toundra',
#  'Death Cab for Cutie',
#  'OFFICIAL HIGE DANDISM',
#  'Shinova',
#  'Manu Dia',
#  'Spoon',
#  'Totally Enormous Extinct Dinosaurs',
#  'Ryan Hurd',
#  'Fontaines D.C.',
#  'Rokero',
#  'Shinsei Kamattechan',
#  'Zion & Lennox',
#  'El Clooy',
#  'Will C',
#  'Los Bravos',
#  'Mac Powell',
#  'UNISON SQUARE GARDEN',
#  'Alice Wonder',
#  'Neutro Shorty',
#  'Friday Pilots Club',
#  'Fleet Foxes',
#  'Jerry Di',
#  'The Del-Vikings',
#  'Nathaniel Rateliff & The Night Sweats',
#  'Trueno',
#  'Dorothy',
#  'Ladytron',
#  'Tedeschi Trucks Band',
#  'Zaidbreak',
#  'Rawayana',
#  'Skylar Grey',
#  'Christian Löffler',
#  'The Rudeboyz',
#  'Jason Kolàr',
#  'Brittany Howard',
#  'El Arrebato',
#  'Duo Multicorde',
#  'Nyno Vargas',
#  'Róisín Murphy',
#  'Camilo',
#  'Ñengo Flow',
#  'Wisin',
#  'Pol Granch',
#  'Juan Magán',
#  'Sufjan Stevens',
#  'Little Stranger',
#  'Parmalee',
#  'Ozuna',
#  'Axel Boman',
#  'Colton Dixon',
#  'Pablo de Sarasate',
#  'RADWIMPS',
#  'Jon Hopkins',
#  'Walker Hayes',
#  'Limp Bizkit',
#  'Lake Street Dive',
#  'THE DRIVER ERA',
#  'Dominic Fike',
#  'Badflower',
#  'Jesse Roper',
#  'Blanco Palamera',
#  'Soccer Mommy',
#  'Rojo',
#  'Jossef',
#  'Ross from Friends',
#  'Abäk',
#  'YONAKA',
#  'Catalyna',
#  'Rafa Espino',
#  'Wisin & Yandel',
#  'Queen',
#  'Zoé',
#  'Bring Me The Horizon',
#  'Yan Block',
#  'Luke Bryan',
#  'The Knife',
#  'LEGEND EFFECT',
#  'Álvaro De Luna',
#  'The Who',
#  'Rozalén',
#  'Wolf Alice',
#  'The Offspring',
#  'Tricky',
#  'Hadadanza',
#  'Måneskin',
#  'Scotty McCreery',
#  'Federico Mompou',
#  'Danny Ocean',
#  'Crisix',
#  'Rend Collective',
#  'Toro',
#  'Aleksander Debicz',
#  'Beéle',
#  'David Cordero',
#  'Zac Brown Band',
#  'The Beths',
#  'Genio Producer',
#  'Adam Jensen',
#  'Javiielo',
#  'Romeo Santos',
#  'Andy Rivera',
#  'Hanzel La H',
#  'Mother Mother',
#  'MËSTIZA',
#  'Mora',
#  'Rosalie.',
#  'BUMP OF CHICKEN',
#  'Jotaerre',
#  'Shane & Shane',
#  'Dani Fernández',
#  'Rammstein',
#  'Greeicy',
#  '✝✝✝ (Crosses)',
#  'Nil Moliner',
#  'Dei V',
#  'Carolina Durante',
#  'Daniel Avery',
#  'Sanctus Real',
#  'Locus',
#  'Caribou',
#  'Thomas Rhett',
#  'Kiko y Shara',
#  'Alex Ubago',
#  'Petey',
#  'CA7RIEL',
#  'JOLLY (PE)',
#  'Mau y Ricky',
#  'De La Rose',
#  'Carlos Sadness',
#  'Shaila Dúrcal',
#  'Amon Tobin',
#  'quannnic',
#  'Veintiuno',
#  'Leon Vynehall',
#  'Ella Baila Sola',
#  'Warpaint',
#  'Chevelle',
#  'Milly',
#  'Gold Panda',
#  'Crazy P',
#  'FERNANDOCOSTA',
#  'Califato ¾',
#  'SunKissed Lola',
#  'Palace',
#  'Metronomy',
#  'St Germain',
#  'Feid',
#  'Dímelo Flow',
#  'Wild Honey',
#  'The Goo Goo Dolls',
#  'Art Lown',
#  'Pacific Roots',
#  'Bee Gees',
#  'Iron Maiden',
#  'Dan Bremnes',
#  'Niña Polaca',
#  'Stars Go Dim',
#  'Heitor Pereira',
#  'Jacques Greene',
#  'The Unlikely Candidates',
#  'Duran Duran',
#  'Fuego',
#  'Lauren Daigle',
#  'Natalie Grant',
#  'JHAYCO',
#  'F.S.Blumm',
#  'Rapsusklei',
#  'Prince Royce',
#  'Cerebral Effusion',
#  'All Time Low',
#  'Mitchell Tenpenny',
#  'Elena Ortega',
#  'Pole.',
#  'The Wombats',
#  'Drugdealer',
#  'Paul McCartney',
#  'YOVNGCHIMI',
#  'Porta',
#  'Juan del Encina',
#  'Red Hot Chili Peppers',
#  'Alvaro Diaz',
#  'Casper Magico',
#  'Midrift',
#  'Nicki Nicole',
#  'Ozzy Osbourne',
#  'Recondite',
#  'AMBKOR',
#  'The War On Drugs',
#  'Insane Clown Posse',
#  'PinocchioP',
#  'Dante',
#  'Hombres G',
#  'Yampi',
#  'Gente De Zona',
#  'Houndmouth',
#  'J Balvin',
#  'Adventus',
#  'George FitzGerald',
#  'Amadeüs',
#  'Momma',
#  'Nach',
#  'Siddhartha',
#  'Rebelution',
#  'Robert Plant',
#  'Juana Molina',
#  'Manybeat',
#  'Ska-P',
#  'Dustin Lynch',
#  'Synlakross',
#  'Télépopmusik',
#  'lovelytheband',
#  'Hector Rios Vnzl',
#  'Vetusta Morla',
#  'Tregua',
#  'Ill Pekeño',
#  'El Barrio',
#  '花冷え。',
#  'Ulrich Schnauss',
#  'Aimer',
#  'Billy Idol',
#  'Joe Goddard',
#  'Angelus Apatrida',
#  'Vitalic',
#  'Dardust',
#  'BOUE',
#  'Santana',
#  'Rels B',
#  'Barns Courtney',
#  'David Otero',
#  'Azucar Moreno',
#  'Hannah Murphy',
#  'if i die in mississippi',
#  'Luna Li',
#  'Karbeats',
#  'Sam Hunt',
#  'Ñejo',
#  'Daphni',
#  'Cidergirl',
#  'alt-J',
#  'Kovács Beatrix',
#  'Eve',
#  'Underworld',
#  'Chris Jedi',
#  'Lone Ark',
#  'The White Stripes',
#  'Of Monsters and Men',
#  'Young Miko',
#  'Weezer',
#  'Wax Tailor',
#  'Piso 21',
#  'Rochy RD',
#  'Little Dragon',
#  'Crowder',
#  'Black Country, New Road',
#  'La Oreja de Van Gogh',
#  'P.A.F.F.',
#  'Aldo Cadiz',
#  'Goth Babe',
#  'Global Underground',
#  'Almighty',
#  'Mano Le Tough',
#  'DECO*27',
#  'Max Cooper',
#  'Manuel Turizo',
#  'Vanesa Martín',
#  'Andrés Madariaga',
#  'Kidd Keo',
#  'Sech',
#  'Sophie Powers',
#  'The Ghost Club',
#  'Yakamoto Kotzuga',
#  'Soge Culebra',
#  'Fito y Fitipaldis',
#  'Victor Porfidio',
#  'IDLES',
#  'Hot Chip',
#  'Suso Saiz',
#  'Surfer Girl',
#  'Marc Seguí',
#  'Israel B',
#  'Aitana',
#  'Russell Dickerson',
#  'Fuel Fandango',
#  'Kodak Black',
#  'Flying Lotus',
#  'Bomba Estéreo',
#  'Quantic',
#  'Meredith Andrews',
#  'Chanell',
#  'The Crystal Method',
#  'Joyce Santana',
#  'Sergio Dalma',
#  'Mujeres',
#  'House Of Pain',
#  'Natalia Lafourcade',
#  'for KING & COUNTRY',
#  'Noah Gundersen',
#  'Alex G',
#  'Lyanno',
#  'Morphium',
#  'grandson',
#  'Pejzaż',
#  'Aventura',
#  'Cazzu',
#  'Andy & Lucas',
#  'Dua Lipa',
#  'Joaquín Turina',
#  'Recycled J',
#  'Kings of Leon',
#  'Vana Liya',
#  'Matthew West',
#  'Korn',
#  'Royal Blood',
#  'Burial',
#  'DJs Pareja',
#  'Saratoga',
#  'Hippo Campus',
#  'Nio Garcia',
#  'Decai',
#  'KAROL G',
#  'Viva Suecia',
#  'Micah Tyler',
#  'De La Ghetto',
#  'Francisco Tárrega',
#  'Love of Lesbian',
#  'Bibio',
#  'Chencho Corleone',
#  'Becky G',
#  'Drew Parker',
#  'Lérica',
#  'Bryant Myers',
#  'DJ Tennis',
#  'Hercules & Love Affair',
#  'The Bones of J.R. Jones',
#  'Beret',
#  'Sneaker Pimps',
#  'Los Rebujitos',
#  'Lee Brice',
#  'Tiga',
#  'Andrea Sertori',
#  'Jason Aldean',
#  'Weval',
#  'Henry Mendez',
#  'MJ Lenderman',
#  'Dollar Selmouni',
#  'Jasmon',
#  'Maluma',
#  'Bear McCreary',
#  'Two Feet',
#  'K.Flay',
#  'Rise Against',
#  'Royel Otis',
#  'TOOL',
#  'Emisound',
#  'Valeria Castro',
#  'Sexy Zebras',
#  'Dvicio',
#  'Elle King',
#  'Vulfpeck',
#  'Papi Sousa',
#  'TobyMac',
#  'Josiah and the Bonnevilles',
#  'Chandler Moore',
#  'Various Artists',
#  'Rhett Walker',
#  'Kixnare',
#  'Angelos',
#  'Lorenzo Soria',
#  'Tainy',
#  'Guaynaa',
#  'Micro TDH',
#  'Warmth',
#  'Clark',
#  'DENM',
#  'Tosca',
#  'Gospel of Dance',
#  'NATTI NATASHA',
#  'Guitarricadelafuente',
#  'Reykjavik606',
#  'Jameson Rodgers',
#  'Arrested Youth',
#  'Pailita',
#  'Khaled',
#  'Joy Orbison',
#  'Sunday Noise',
#  'Nueen',
#  'Dirty Heads',
#  'Niño de Elche',
#  'Kip Moore',
#  'Coheed and Cambria',
#  'Ladilla Rusa',
#  'Salduie',
#  'The Happy Fits',
#  'Sergio Contreras',
#  'MORVN',
#  'Peces Raros',
#  'KHEA',
#  'Paulo Londra',
#  'Mount Kimbie',
#  'Monica Naranjo',
#  'Brandi Carlile',
#  'Rachael Lampa',
#  'Tommy James & The Shondells',
#  'Âme',
#  'Tierra Santa',
#  'Saurom',
#  'James McMurtry',
#  'Funambulista',
#  'coldrain',
#  'David Bisbal',
#  'vf7',
#  'Daniel Zueras',
#  'Hoke',
#  'Don Omar',
#  'Alex Gargolas',
#  'Kairikibear',
#  'Wine Lips',
#  'Daughtry',
#  'Mogwai',
#  'I AM THEY',
#  'Stephen Bishop',
#  'Volbeat',
#  'Journey',
#  'Fantastic Negrito',
#  'Maria Becerra',
#  'Babasonicos',
#  'Sébastien Tellier',
#  'Jimmie Allen',
#  'Tame Impala',
#  'trentemøller',
#  'Matt Maher',
#  'Brett Eldredge',
#  'Alejo',
#  'Milky Chance',
#  'Sho-Hai',
#  'Dayglow',
#  'from',
#  'Ovi',
#  'Boza',
#  'Yamila',
#  'Basement Jaxx',
#  'Denom',
#  'Slayter',
#  'Imagine Dragons',
#  'Romare',
#  'MercyMe',
#  'The Green',
#  'Bonnie Raitt',
#  'Sharon Van Etten',
#  'Tony Guerra',
#  'Zetazen',
#  'Dani Martín',
#  'DePol',
#  'Logan Mize',
#  'Level 42',
#  'We Are Messengers',
#  'Alberto Dimeo',
#  'Papa Roach',
#  'Elvis Presley',
#  'Miguel Bastida',
#  'Tyler Rich',
#  'Nikone',
#  'Yeruza',
#  'J Abdiel',
#  'MAN WITH A MISSION',
#  'Pablo López',
#  'Sam Fender',
#  'The Elovaters',
#  'Sharif',
#  'Natos y Waor',
#  'The Movement',
#  'DICE',
#  'DJ Koze',
#  'Fit For A King',
#  'Old Mervs',
#  'Maretu',
#  'Daniel Barenboim',
#  'Manuel Carrasco',
#  'The Poles',
#  'Twenty One Pilots',
#  'Björk',
#  'Soraya',
#  'Danza Invisible',
#  'Hiss Golden Messenger',
#  'Nightmares On Wax',
#  'John Hiatt',
#  'Clara Cava',
#  'Pablo Alborán',
#  'Chenoa',
#  'Highly Suspect',
#  'Portico Quartet',
#  'Elefantes',
#  'Dead Poet Society',
#  'Andrés Suárez',
#  'Tamara',
#  'Reik',
#  'La Bien Querida',
#  'Quarters of Change',
#  'Iration',
#  'Pixies',
#  'Brent Cobb',
#  'Casting Crowns',
#  'Siloé',
#  'Ghost',
#  'Bryce Fox',
#  'Sôber',
#  'Brothers Osborne',
#  'Paul Kalkbrenner',
#  'John Debney',
#  'The Blue Stones',
#  'BICEP',
#  'Abraham Mateo',
#  'Rvfv',
#  'Lytos',
#  'Cris Mj',
#  'Isaac Albéniz',
#  'Simple Plan',
#  'Tyler Booth',
#  'Florida Georgia Line',
#  'Stick Figure',
#  'Los Angeles Negros',
#  'El Alfa',
#  'Rebecca St. James',
#  'Original Juan',
#  'Blake',
#  'The Black Keys',
#  'Celtian',
#  'Estopa',
#  'DARKSIDE',
#  'Alex Rose',
#  'Carlos Baute',
#  'Whiskey Myers',
#  'Skillet',
#  'ROA',
#  'Nickelback',
#  'Nunatak',
#  'Lasai',
#  'Band&dos',
#  'Diego Martín',
#  'Javiera Mena',
#  'Dylan Scott',
#  'Disney',
#  'Yeah Yeah Yeahs',
#  'Blas Cantó',
#  'The Red Pears',
#  'King Clave',
#  'Andy Stott',
#  'Courtney Barnett',
#  'Radiohead',
#  'Good Morning',
#  'The Chemical Brothers',
#  'Kase.O',
#  'Esteman',
#  'Depeche Mode',
#  'Daddy Yankee',
#  'Colorblind',
#  'Populous',
#  'Vance Joy',
#  'Jay Wheeler',
#  'Carlos Herrera Music',
#  'Gabriel Dominguez',
#  'Maston',
#  'La La Love You',
#  'Young the Giant',
#  'Sebastian Yatra',
#  'Bala',
#  'Ankhal',
#  'Nirvana',
#  'Ayax y Prok',
#  'Juhn',
#  'KALEO',
#  'Accion Sanchez',
#  'Edu Imbernon',
#  'Michael Ray',
#  'Lady Gaga',
#  'CNCO',
#  'ToteKing',
#  'Calero LDN',
#  'Jimmix',
#  'Ovy On The Drums',
#  'Tom Morello',
#  'Amenazzy',
#  'Rone',
#  'Ankor',
#  'KANA-BOON',
#  'Cyclo',
#  'The Hip Abduction',
#  'Delta Sleep',
#  'Rob Zombie',
#  'Eladio Carrion',
#  'Yunchan Lim',
#  'Hollywood Undead',
#  'HEALTH',
#  'Chris Tomlin',
#  'Manu Manzo',
#  'Palaye Royale',
#  'Rvssian',
#  'Muse',
#  'Dylan Schneider',
#  'The Lumineers',
#  'Shé',
#  'Reykon',
#  'Miky Woodz',
#  'Dok & Martin',
#  'HoneyWorks',
#  'Angela Hewitt',
#  'Bad Gyal',
#  'Floating Points',
#  'OneRepublic',
#  'Brray',
#  'Luar La L',
#  'Drake White',
#  'Lori Meyers',
#  'GusGus',
#  'Thom Yorke',
#  'NEEDTOBREATHE',
#  'Beatriz Luengo',
#  'The Struts',
#  'Hard GZ',
#  'feeble little horse',
#  'Edu Linares',
#  'Rigoberta Bandini',
#  'Toda la Vida',
#  'Depresión Sonora',
#  'The Neighbourhood',
#  'Hilary Hahn',
#  'The Rolling Stones',
#  'MASS OF THE FERMENTING DREGS',
#  'Anuel AA',
#  'Zero 7',
#  'Omar Courtz',
#  'Pig&Dan',
#  'Passafire',
#  'Newsboys',
#  'Ak4:20',
#  'Duki',
#  'Omy de Oro',
#  'Jeff Danna',
#  'Florence + The Machine',
#  'LIT killah',
#  'Wet Leg',
#  'Efecto Pasillo']

# %%
##Corroborar que no haya duplicados: 

if len(list_artistas) != len(set(list_artistas)):
    print("Hay duplicados")
else:
    print("No hay duplicados")

    ##Si hubiera duplicados:
# Out:
# No hay duplicados

# %%
list_artistas
# Out:
# ['Clara Cava',
#  'KAROL G',
#  'The Black Keys',
#  'Jon Z',
#  'Esteman',
#  'PinocchioP',
#  'MORVN',
#  'Vetusta Morla',
#  'Sigur Rós',
#  'Ozzy Osbourne',
#  'Zion & Lennox',
#  'Accion Sanchez',
#  'if i die in mississippi',
#  'Original Juan',
#  'Carlos Sadness',
#  'Simple Plan',
#  'La Pegatina',
#  'The Elovaters',
#  'Arcy Drive',
#  'Rafa Espino',
#  'Three Days Grace',
#  'The Beths',
#  'Tyler Booth',
#  'PELICAN FANCLUB',
#  'Javiielo',
#  'La La Love You',
#  'Twenty One Pilots',
#  'Recycled J',
#  'Maretu',
#  'lovelytheband',
#  'Darell',
#  'Lone Ark',
#  'Skillet',
#  'Dvicio',
#  'Max Cooper',
#  'Manybeat',
#  'Angela Hewitt',
#  'Recondite',
#  'Fontaines D.C.',
#  'Burial',
#  'Emisound',
#  'Tiago PZK',
#  'Heroes Del Silencio',
#  'Sergio Dalma',
#  'MAN WITH A MISSION',
#  'Andrés Suárez',
#  'Moby',
#  'Efecto Pasillo',
#  'Juan del Encina',
#  'Tom Morello',
#  'Scotty McCreery',
#  'Alex Rose',
#  'Jason Kolàr',
#  'Leiva',
#  'Zoé',
#  'feeble little horse',
#  'Amarion',
#  'Spoon',
#  'The Offspring',
#  'Walker Hayes',
#  'Ray MD',
#  'Alice Wonder',
#  'Iron Maiden',
#  'Eli Young Band',
#  'Rosario',
#  'Shotta',
#  'Wet Leg',
#  'Old Dominion',
#  'Rhye',
#  'Lady Gaga',
#  'Bala',
#  'Insane Clown Posse',
#  'Bear McCreary',
#  'Rhett Walker',
#  'DICE',
#  'Brandon Heath',
#  'Sofia Ellar',
#  'Tosca',
#  'Kaze',
#  'Nathaniel Rateliff & The Night Sweats',
#  'Matthew West',
#  'Pailita',
#  'Danza Invisible',
#  'Suso Saiz',
#  'John Fulford Music',
#  'DECO*27',
#  'Rawayana',
#  'Mogwai',
#  'Duki',
#  'Wild Honey',
#  'Drew Parker',
#  'Jowell & Randy',
#  'The Chemical Brothers',
#  'Hozier',
#  'Nunatak',
#  'Niña Polaca',
#  'Royel Otis',
#  'Rauw Alejandro',
#  'Orbital',
#  'Edurne',
#  'Cody Jinks',
#  'Palace',
#  'MASS OF THE FERMENTING DREGS',
#  'Toda la Vida',
#  'Don Omar',
#  'Basement Jaxx',
#  'Love of Lesbian',
#  'Brray',
#  'Viva Suecia',
#  'Good Morning',
#  'Locus',
#  'Jens Buchert',
#  'Droow',
#  'Imagine Dragons',
#  'Russell Dickerson',
#  'KANA-BOON',
#  'TK from Ling tosite sigure',
#  'La Oreja de Van Gogh',
#  'from',
#  'Quevedo',
#  'Peces Raros',
#  'Edu Imbernon',
#  'Sneaker Pimps',
#  'Lorenzo Soria',
#  'The Killers',
#  'Zahara',
#  'Los Angeles Negros',
#  'Goodbye June',
#  'Manuel Barrueco',
#  'Quantic',
#  'Little Dragon',
#  'Vulfpeck',
#  'P.A.F.F.',
#  'Francisco Tárrega',
#  'Populous',
#  'Salduie',
#  'Lori Meyers',
#  'Blake',
#  'Santana',
#  'Nicky Jam',
#  'Florida Georgia Line',
#  'Delta Sleep',
#  'Bring Me The Horizon',
#  'Âme',
#  'Azucar Moreno',
#  'Japanese Breakfast',
#  'Omy de Oro',
#  'Houndmouth',
#  'Rachael Lampa',
#  'Warpaint',
#  'Joyce Santana',
#  'Pablo de Sarasate',
#  'Maston',
#  'Miranda!',
#  'Mikel Erentxun',
#  'Saratoga',
#  'The Happy Fits',
#  'Alvvays',
#  'Rayden',
#  'Nils Frahm',
#  'Tiga',
#  'The Crystal Method',
#  'coldrain',
#  'Colorblind',
#  'Adam Jensen',
#  'Tauren Wells',
#  'Dirty Heads',
#  'Veintiuno',
#  'David Cordero',
#  'Lake Street Dive',
#  'Sharif',
#  'We Came As Romans',
#  'Daddy Yankee',
#  'Belén Aguilera',
#  'KLANGSTEIN',
#  'ELYELLA',
#  'Juan Magán',
#  'Hades66',
#  'Ayax y Prok',
#  'Miguel Bastida',
#  'Beéle',
#  'Piso 21',
#  'DJ Tennis',
#  'Tricky',
#  'Crisix',
#  'NATTI NATASHA',
#  'Sunday Noise',
#  'Petey',
#  'Modeselektor',
#  'Jossef',
#  'Yan Block',
#  'Chandler Moore',
#  'Various Artists',
#  'Black Label Society',
#  'Gente De Zona',
#  'Motörhead',
#  'Bizarrap',
#  'Tropidelic',
#  'OFFICIAL HIGE DANDISM',
#  'Dylan Scott',
#  'Rosalie.',
#  'Pablo Ferrandez',
#  'Jon Pardi',
#  'Dustin Lynch',
#  'Stephen Bishop',
#  'Floating Points',
#  'Elton John',
#  'Lauren Daigle',
#  'Ryan Hurd',
#  'Dani Martín',
#  'Mujeres',
#  'Hollywood Undead',
#  'Rise Against',
#  'Rvfv',
#  'Babasonicos',
#  'Fever Ray',
#  'Brett Eldredge',
#  'Pol 3.14',
#  'Nickelback',
#  'Tony Guerra',
#  'Joey Valence & Brae',
#  'Bryce Fox',
#  'Sôber',
#  'Metronomy',
#  'El Clooy',
#  'Bonobo',
#  'Becky G',
#  'Paula Mattheus',
#  'Amenazzy',
#  'Kase.O',
#  'Stars Go Dim',
#  'Daniel Avery',
#  'Myke Towers',
#  'Daphni',
#  'FERNANDOCOSTA',
#  'Sophie Powers',
#  'Brittany Howard',
#  'Bryant Myers',
#  'Mau y Ricky',
#  'Andrés Madariaga',
#  'Delaossa',
#  'El Alfa',
#  'Bejo',
#  'Milo j',
#  'The Bones of J.R. Jones',
#  'Broken Lip',
#  'Blanco Palamera',
#  'Sexy Zebras',
#  'Skylar Grey',
#  'IZAL',
#  'Dei V',
#  'Noriel',
#  'Télépopmusik',
#  'La Culpa',
#  'Ghost',
#  'The Wombats',
#  'Shaila Dúrcal',
#  'Papi Sousa',
#  'Father John Misty',
#  'Richy Mitch & The Coal Miners',
#  'Comandante Twin',
#  'Weezer',
#  'Fit For A King',
#  'City of the Sun',
#  'John Hiatt',
#  'Elena Ortega',
#  'Vana Liya',
#  'Jasmon',
#  'Porta',
#  'Yeruza',
#  'Surfer Girl',
#  'Manuel Turizo',
#  'Ankor',
#  'Mike Bahía',
#  'Whiskey Myers',
#  'Alex G',
#  'Glass Animals',
#  'Little Stranger',
#  'HEALTH',
#  'Joaquín Sabina',
#  'Pejzaż',
#  'Soccer Mommy',
#  'Arnau Griso',
#  'TobyMac',
#  'Soleá Morente',
#  'Karbeats',
#  'Air',
#  'Rob Zombie',
#  'Cole Swindell',
#  'Malú',
#  'Zac Brown Band',
#  'J Abdiel',
#  'Elle King',
#  'Jesús Adrián Romero',
#  'Fondo Flamenco',
#  'George FitzGerald',
#  'Dauwd',
#  'Pablo Alborán',
#  'Abraham Mateo',
#  'Hadadanza',
#  'Spacey Jane',
#  'Foo Fighters',
#  'Siloé',
#  'Siddhartha',
#  'K.Flay',
#  'I AM THEY',
#  'Israel B',
#  'alt-J',
#  'Almighty',
#  'Cecilia Krull',
#  'Danny Gokey',
#  'Hooverphonic',
#  'Crowder',
#  'Farruko',
#  'Lérica',
#  'Fallen Roses',
#  'Zero 7',
#  'Ele A El Dominio',
#  'HoneyWorks',
#  'My Chemical Romance',
#  'Chenoa',
#  'Groove Armada',
#  'Ñejo',
#  'Trueno',
#  'Chencho Corleone',
#  'Vanesa Martín',
#  'Anuel AA',
#  'Marlon',
#  'Calero LDN',
#  'Ana Mena',
#  'Dardust',
#  'Rata Negra',
#  'Aitana',
#  'Romeo Santos',
#  'Taburete',
#  'CA7RIEL',
#  'Arrested Youth',
#  'The Who',
#  'Dan Bremnes',
#  'Depeche Mode',
#  'Duo Multicorde',
#  'Pablo López',
#  'Dante',
#  'Andy Rivera',
#  'Caribou',
#  'Nirvana',
#  'Rigoberta Bandini',
#  'Angelus Apatrida',
#  'Travis Denning',
#  'Natalia Jiménez',
#  'Rival Consoles',
#  'Ryan Stevenson',
#  'Denom',
#  'Khaled',
#  'LCD Soundsystem',
#  'Four Tet',
#  'Elvis Presley',
#  'The Neighbourhood',
#  'Sébastien Tellier',
#  'Ocer y Rade',
#  'Guts',
#  'Los Bravos',
#  'Dillon Carmichael',
#  'Papa Roach',
#  'Fyahbwoy',
#  'Heitor Pereira',
#  'Federico Mompou',
#  'James McMurtry',
#  'Ozuna',
#  'Ella Baila Sola',
#  'We Are Messengers',
#  'Thomas Rhett',
#  'DJ Koze',
#  'Dorothy',
#  'Javiera Mena',
#  'KHEA',
#  'Parmalee',
#  'Aldo Cadiz',
#  'Badflower',
#  'HARRY WAS HERE',
#  'Róisín Murphy',
#  'Big Thief',
#  'No Vacation',
#  'Kings of Leon',
#  'Dua Lipa',
#  'Carlos Baute',
#  'Arctic Monkeys',
#  'KALEO',
#  'Antonio José',
#  'Sohodolls',
#  'Tom Petty and the Heartbreakers',
#  'Fantastic Negrito',
#  'Crazy P',
#  'Manu Dia',
#  'Exxasens',
#  'Yakamoto Kotzuga',
#  'La Paloma',
#  'Daniel Zueras',
#  'Dayglow',
#  'ROA',
#  'Mammoth WVH',
#  'Jameson Rodgers',
#  'Maluma',
#  'Maga',
#  'Fortunate Youth',
#  'Midrift',
#  'SWIT EME',
#  'Noah Gundersen',
#  'Cerebral Effusion',
#  'Cyclo',
#  'Highly Suspect',
#  'Thom Yorke',
#  'Jon Hopkins',
#  'Melendi',
#  'Band of Horses',
#  'Bad Suns',
#  'Mitchell Tenpenny',
#  'The Movement',
#  'Gabriel Dominguez',
#  'Niño de Elche',
#  'LIT killah',
#  'Gorillaz',
#  'Funambulista',
#  'Jimmie Allen',
#  'Hercules & Love Affair',
#  'Café Quijano',
#  'Ben Rector',
#  'Pusho',
#  'Leon Vynehall',
#  'Hippo Campus',
#  'Alberto Dimeo',
#  'Paulo Londra',
#  'Anıl Emre Daldal',
#  'NEEDTOBREATHE',
#  'Paul Kalkbrenner',
#  'The Hip Abduction',
#  'Bomba Estéreo',
#  'Digitalism',
#  'Ladilla Rusa',
#  'Rozalén',
#  'Shinova',
#  'Ovi',
#  'Tommy James & The Shondells',
#  'Ak4:20',
#  'Miss Kittin',
#  'Adventus',
#  'YUNGBLUD',
#  'Amistades Peligrosas',
#  'Josiah and the Bonnevilles',
#  'Chris Jedi',
#  'Marc Seguí',
#  'La Maravillosa Orquesta del Alcohol',
#  'UNKLE',
#  'Newsboys',
#  'Ñengo Flow',
#  'Blas Cantó',
#  'BICEP',
#  'Passafire',
#  'Moderat',
#  'black midi',
#  'MJ Lenderman',
#  'The Struts',
#  'Iration',
#  'trentemøller',
#  'The Unlikely Candidates',
#  'Of Monsters and Men',
#  'El Barrio',
#  'Saint Motel',
#  'Kairikibear',
#  'Reik',
#  'Jesse Roper',
#  'Vance Joy',
#  'Guitarricadelafuente',
#  'Pole.',
#  'LOUTA',
#  'MËSTIZA',
#  'Álvaro De Luna',
#  'Bombai',
#  'The Red Pears',
#  'Joy Orbison',
#  'HVOB',
#  'Beret',
#  'Sufjan Stevens',
#  'All Time Low',
#  'Kixnare',
#  'Casting Crowns',
#  'Andy Frasco & The U.N.',
#  'The Knife',
#  'Arce',
#  'Micah Tyler',
#  'Quarters of Change',
#  'GusGus',
#  'J Balvin',
#  'Chanell',
#  'Dominic Fike',
#  'Axel Boman',
#  'The War On Drugs',
#  'Rojo',
#  'Yandel',
#  'Arcane',
#  'ELVIS (Original Motion Picture Soundtrack)',
#  'Foreign Teck',
#  'Celtian',
#  'Reykon',
#  'Totally Enormous Extinct Dinosaurs',
#  'WhoMadeWho',
#  'AMBKOR',
#  'Mac Powell',
#  'Camilo',
#  'Kodak Black',
#  'Paul McCartney',
#  'Metallica',
#  'Jefferson Airplane',
#  'Eve',
#  'Korn',
#  'Courtney Barnett',
#  'Booka Shade',
#  'Carlos Herrera Music',
#  'Alex Gargolas',
#  'Kidd Keo',
#  'Lasai',
#  'Jay Wheeler',
#  'Sam Fender',
#  'Maria Becerra',
#  'CNCO',
#  'Sharon Van Etten',
#  'Soraya',
#  'Sniper Gang',
#  'Romare',
#  'Georgie Dann',
#  'The White Stripes',
#  'Generación 12',
#  'Morcheeba',
#  'Art Lown',
#  'Young the Giant',
#  'Greeicy',
#  'Conchita',
#  'Phil Wickham',
#  'Foyone',
#  'Disney',
#  'Olivia Newton-John',
#  'Gospel of Dance',
#  'Billy Idol',
#  'Synlakross',
#  'Jane Remover',
#  'Matt Maher',
#  'Zetazen',
#  'Janine Jansen',
#  'Maná',
#  'Juhn',
#  'Natos y Waor',
#  'Toundra',
#  'Anubiis',
#  'El Chojin',
#  'Two Feet',
#  'Blockhead',
#  'LEGEND EFFECT',
#  'Hannah Murphy',
#  'The Rolling Stones',
#  'Hard GZ',
#  'House Of Pain',
#  'Pixies',
#  'Catalyna',
#  'Pol Granch',
#  'The Lumineers',
#  'Neutro Shorty',
#  'Aleksander Debicz',
#  'Yung Beef',
#  'Jamie xx',
#  'YOVNGCHIMI',
#  'Slipknot',
#  'Hiss Golden Messenger',
#  'Ross from Friends',
#  'Lytos',
#  'Wisin & Yandel',
#  'Mother Mother',
#  'SBTRKT',
#  'Lepoka',
#  'Luke Bryan',
#  'Austin French',
#  'Califato ¾',
#  'Brandi Carlile',
#  'Lunay',
#  'DePol',
#  'Luna Li',
#  'Tedeschi Trucks Band',
#  'Brent Cobb',
#  'Rone',
#  'Coheed and Cambria',
#  'F.S.Blumm',
#  'Gidge',
#  'Jerry Di',
#  'Muse',
#  'Alex Ubago',
#  'Kovács Beatrix',
#  'Greta Van Fleet',
#  'Tame Impala',
#  'Aventura',
#  'Nach',
#  'OneRepublic',
#  'King Clave',
#  'Logan Mize',
#  'The Rudeboyz',
#  'STARSET',
#  'Tycho',
#  'Old Mervs',
#  'Christian Löffler',
#  'Ankhal',
#  'Jacques Greene',
#  'Arcángel',
#  'Duran Duran',
#  'DREAMERS',
#  'Guaynaa',
#  'Röyksopp',
#  'Marcus King',
#  'Genio Producer',
#  'Bleachers',
#  'MercyMe',
#  "Guns N' Roses",
#  'La Casa Azul',
#  'El Arrebato',
#  'Nylonwings',
#  'TOOL',
#  'Beach House',
#  'Milly',
#  'Jeff Danna',
#  'Florence + The Machine',
#  'Band&dos',
#  'Diego Martín',
#  'Morphium',
#  'Victor Porfidio',
#  'Warcry',
#  'Phoenix',
#  'Alejo',
#  'Dímelo Flow',
#  'Radiohead',
#  'Monica Naranjo',
#  'Rammstein',
#  'Mount Kimbie',
#  'Faithless',
#  'DJs Pareja',
#  'Mastodon',
#  'Dollar Selmouni',
#  'grandson',
#  'Nio Garcia',
#  'Los Fabulosos Cadillacs',
#  'Underworld',
#  'David Bisbal',
#  'Sech',
#  'Pacho El Antifeka',
#  'MARLENA',
#  'Omar Courtz',
#  'Marea',
#  'Los Rebujitos',
#  'Rend Collective',
#  'Bad Bunny',
#  'Tierra Santa',
#  'Inner Wave',
#  'JHAYCO',
#  'Justin Quiles',
#  'Chris Lane',
#  'Yunchan Lim',
#  'Kip Moore',
#  'SunKissed Lola',
#  'Limp Bizkit',
#  'The Score',
#  'Alvaro Diaz',
#  'Nightmares On Wax',
#  'Opera Magna',
#  'Fuego',
#  'Elefantes',
#  'Megadeth',
#  'Jimmix',
#  'Ryan Castro',
#  'Måneskin',
#  'Yeah Yeah Yeahs',
#  'Aimer',
#  'De La Rose',
#  'Sebastian Yatra',
#  'Manuel Carrasco',
#  'Black Country, New Road',
#  'ToteKing',
#  'Toro',
#  'Stick Figure',
#  'Cali Y El Dandee',
#  'Jerry Lee Lewis',
#  'Rokero',
#  'Andy Stott',
#  'Hilary Hahn',
#  'Friday Pilots Club',
#  'IDLES',
#  'Slayter',
#  'Maki',
#  'Portugal. The Man',
#  'David Otero',
#  'Artury Pepper',
#  'JOLLY (PE)',
#  'Eladio Carrion',
#  'Death Cab for Cutie',
#  'Rochy RD',
#  'Skalpel',
#  'Casper Magico',
#  'Valeria Castro',
#  'Yampi',
#  'Daniel Barenboim',
#  'Will C',
#  'Warmth',
#  'Yamila',
#  'Daughtry',
#  'UNISON SQUARE GARDEN',
#  'Sergio Contreras',
#  'Reykjavik606',
#  'Fito y Fitipaldis',
#  'Sanctus Real',
#  'Colton Dixon',
#  'Hanzel La H',
#  'Amon Tobin',
#  'Isaac Albéniz',
#  'Arde Bogotá',
#  'Jason Aldean',
#  'Rebelution',
#  'Antonio Orozco',
#  'Manu Manzo',
#  'Polyphia',
#  'Young Miko',
#  'YONAKA',
#  'Hombres G',
#  'Proyecto Gomez Casa',
#  'Tempo',
#  'Rvssian',
#  'Lenny Tavárez',
#  'Jay Menez',
#  'Nil Moliner',
#  'OTA El Hipopotamo',
#  'Wolf Alice',
#  'Chris Tomlin',
#  'Dark Moor',
#  'De La Ghetto',
#  'Red Hot Chili Peppers',
#  'Abäk',
#  'Tyler Rich',
#  'Ska-P',
#  'THE DRIVER ERA',
#  'Volbeat',
#  'for KING & COUNTRY',
#  'Shane & Shane',
#  'Natalie Grant',
#  'Nueen',
#  'Green Valley',
#  'Edu Linares',
#  'Michael Ray',
#  'ONE OK ROCK',
#  'Rebecca St. James',
#  'DEKKO',
#  'Cidergirl',
#  'Global Underground',
#  'La Bien Querida',
#  'Nikone',
#  'Nyno Vargas',
#  'Talisto',
#  'Rels B',
#  'Justice',
#  'Brytiago',
#  'Andrea Sertori',
#  'Randy',
#  'Miky Woodz',
#  'Fuel Fandango',
#  'Weval',
#  'Gold Panda',
#  'Palaye Royale',
#  'Cris Mj',
#  'Milky Chance',
#  'Queen',
#  'RADWIMPS',
#  'Beatriz Luengo',
#  'Tainy',
#  'Saurom',
#  'Bad Gyal',
#  'Henry Mendez',
#  'Brothers Osborne',
#  'Pacific Roots',
#  'Marco Tegui',
#  'DENM',
#  'Angelos',
#  'Chase Rice',
#  'The Blue Stones',
#  'Andy & Lucas',
#  'Journey',
#  'Carolina Durante',
#  'Ill Pekeño',
#  'Joe Goddard',
#  'Fatima Hajji',
#  'Fleet Foxes',
#  'Bee Gees',
#  '花冷え。',
#  'Robert Plant',
#  'Mano Le Tough',
#  'Shinsei Kamattechan',
#  'Lyanno',
#  'Brantley Gilbert',
#  'Wisin',
#  'Sam Hunt',
#  'Wine Lips',
#  'Feid',
#  'BUMP OF CHICKEN',
#  '✝✝✝ (Crosses)',
#  'Pablo Say',
#  'Clap! Clap!',
#  'Vendex',
#  'Bonnie Raitt',
#  'Sho-Hai',
#  'Ulrich Schnauss',
#  'Momma',
#  'Barns Courtney',
#  'Portico Quartet',
#  'Nicki Nicole',
#  'Hoke',
#  'BOUE',
#  'Dead Poet Society',
#  'Chevelle',
#  'Rapsusklei',
#  'Antonio Ruiz Pipó',
#  'Manchester Orchestra',
#  'John Debney',
#  'Mihali',
#  'Mägo de Oz',
#  'Francesca Battistelli',
#  'Tamara',
#  'Decai',
#  'Flying Lotus',
#  'Estopa',
#  'Shé',
#  'The Goo Goo Dolls',
#  'Plaid',
#  'Level 42',
#  'J Alvarez',
#  'The Del-Vikings',
#  'The 1975',
#  'quannnic',
#  'St Germain',
#  'Mistah Godeh',
#  'Prince Royce',
#  'Siggy',
#  'Soge Culebra',
#  'Corina Smith',
#  'Danny Ocean',
#  'Fangoria',
#  'ivri',
#  'Viuda',
#  'Drugdealer',
#  'Blessd',
#  'Kiko y Shara',
#  'Dalex',
#  'Boza',
#  'E.VAX',
#  'Meredith Andrews',
#  'Cazzu',
#  'The Green',
#  'DARKSIDE',
#  'SAIKO',
#  'The Ghost Club',
#  'Lee Brice',
#  'Lola Indigo',
#  'Jeremy Camp',
#  'Clark',
#  'Björk',
#  'Dok & Martin',
#  'vf7',
#  'Zaidbreak',
#  'Nosaj Thing',
#  'Jotaerre',
#  'Dani Fernández',
#  'Juana Molina',
#  'Ovy On The Drums',
#  'Bibio',
#  'Luar La L',
#  'Hector Rios Vnzl',
#  'Vitalic',
#  'Pequeño Pez',
#  'Fruit Bats',
#  'Tregua',
#  'Dylan Schneider',
#  'Wax Tailor',
#  'Royal Blood',
#  'Drake White',
#  'Micro TDH',
#  'Joaquín Turina',
#  'Depresión Sonora',
#  'Goth Babe',
#  'India Martinez',
#  'Amadeüs',
#  'RYSY',
#  'Mora',
#  'Hot Chip',
#  'RedHook',
#  'Natalia Lafourcade',
#  'The Poles',
#  'Pig&Dan',
#  'Ladytron']

# %%
#dict_artistas['artista'] 

duplicados = set() 
unicos = set() 

for item in dict_artistas['artista']: 
    if item in unicos: 
        duplicados.add(item) 
    else: 
        unicos.add(item) 
        
print("Duplicados encontrados:", list(duplicados))

# %% [markdown]
# ## Diccionario final (llamada a la API aprox 20 min)

# %%
 

# Lista de artistas de spotify despues de eliminar duplicados
list_artistas

# Dict donde se almacenara la info de los artistas de la API musicBrainz
dict_artistas = {"artista" : [], "pais_de_origen" : [], "area_de_origen" : [], "fecha_nacimiento" : [], "fecha_inicio_actividad" : [], "fecha_fin_actividad" :[]}

for artista in list_artistas:
    
    # Protegemos posibles errores al hacer la llamada a la URL para cada artista
    try:
        # Construir la URL con el nombre del artista
        url = f"https://musicbrainz.org/ws/2/artist/?query=artist:\"{artista}\"&fmt=json"
        # Petición a la API con funcion llamar_api definida anteriormente -> devuelve resultado en JSON
        result = llamar_api(url)
            
        # Comprobamos que en el dict que nos da la URL por cada artista tiene el key artist y que el nombre del primer artista de la lista no esta vacio  
        if result.get("artists") and result["artists"][0].get("name") is not None:
        
            # Cogemos el primer dict de la lista artists porque hemos hecho la hipotesis de que es el mas correcto
            primer_artista_dict = result["artists"][0]    
            
            # Rellenamos el dict general con toda la info de los artistas
            try:
                dict_artistas["artista"].append(primer_artista_dict["name"])
            except KeyError:
                dict_artistas["artista"].append("NULL")
                
            try:
                dict_artistas["pais_de_origen"].append(primer_artista_dict["area"]["name"])
            except KeyError:
                dict_artistas["pais_de_origen"].append("NULL")  
                
            try:
                dict_artistas["area_de_origen"].append(primer_artista_dict["begin-area"]["name"])
            except KeyError:
                dict_artistas["area_de_origen"].append("NULL")  
        
            # Aqui ponemos un get para los casos en los que falte el life-span (que devuelva un diccionario vacio en caso que no esté presente)
           
            try:
                if primer_artista_dict.get("type") == "Person":
                    fecha_nacimiento = primer_artista_dict.get("life-span", {}).get("begin", "NULL")
                    dict_artistas["fecha_nacimiento"].append(fecha_nacimiento)
                    dict_artistas["fecha_inicio_actividad"].append("NULL")
                elif primer_artista_dict.get("type") == "Group":
                    dict_artistas["fecha_nacimiento"].append("NULL")
                    fecha_inicio = primer_artista_dict.get("life-span", {}).get("begin", "NULL")
                    dict_artistas["fecha_inicio_actividad"].append(fecha_inicio)
                else:
                    dict_artistas["fecha_nacimiento"].append("NULL")
                    dict_artistas["fecha_inicio_actividad"].append("NULL")  # Agregar NULL si es otro tipo
            except KeyError:
                dict_artistas["fecha_nacimiento"].append("NULL")
                dict_artistas["fecha_inicio_actividad"].append("NULL")
            
            try:
                if primer_artista_dict["life-span"].get("ended") is not None: #ver que ended este presente
                    if primer_artista_dict["life-span"]["ended"]: #Verificar si ended es True
                        fecha_fin = primer_artista_dict["life-span"].get("end", "No activo") #creamos variable para luego imprimir fecha fin
                        dict_artistas["fecha_fin_actividad"].append(fecha_fin)     
                    else: 
                        dict_artistas["fecha_fin_actividad"].append("Actualidad") 
                else:
                    dict_artistas["fecha_fin_actividad"].append("Actualidad")
            except KeyError:
                dict_artistas["fecha_fin_actividad"].append("NULL")
                         
    except requests.exceptions.RequestException as e:
        # Capturar errores de red (e.g., problemas con la conexión)
        print(f"Error al hacer la solicitud para {artista}: {e}")
    
    except ValueError as e:
        # Capturar errores de JSON (si la respuesta no es JSON válido)
        print(f"Error al procesar la respuesta JSON para {artista}: {e}")
    
    except Exception as e:
        # Capturar cualquier otro tipo de error no esperado
        print(f"Algo salió mal con {artista}: {e}")

    # Pausar de 1 segundos entre cada solicitud para evitar ser bloqueado por la API
    time.sleep(1)
# Out:
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200

# %%
#Comprobamos que las longitudes sean similares: 

for key, value in dict_artistas.items():
    print(f"{key}: {len(value)}")
# Out:
# artista: 865
# pais_de_origen: 865
# area_de_origen: 865
# fecha_nacimiento: 865
# fecha_inicio_actividad: 865
# fecha_fin_actividad: 865

# %%
dataframe_MB1 = pd.DataFrame(dict_artistas) 
dataframe_MB1
# Out:
#                                  artista        pais_de_origen  \
# 0                             Arcy Drive              New York
# 1                      Portugal. The Man         United States
# 2                                Talisto             Stockholm
# 3                                 Rayden                 Spain
# 4                            No Vacation         United States
# 5                    Jesús Adrián Romero                Mexico
# 6                                Moderat               Germany
# 7                              Yung Beef                 Spain
# 8                              Sohodolls        United Kingdom
# 9                             Chris Lane        North Carolina
# 10                            Broken Lip                 Spain
# 11                           Ryan Castro              Colombia
# 12                           Myke Towers           Puerto Rico
# 13                           La Pegatina                 Spain
# 14                              Four Tet        United Kingdom
# 15                          Georgie Dann                 Spain
# 16                              YUNGBLUD        West Yorkshire
# 17                               Starset         United States
# 18                                  ivri                  NULL
# 19                   Black Label Society         United States
# 20                        Belén Aguilera                 Spain
# 21                       LCD Soundsystem         United States
# 22                          Antonio José                 Spain
# 23                       Fortunate Youth         United States
# 24                            Ben Rector         United States
# 25                              La Culpa  Comunidad Valenciana
# 26                    Japanese Breakfast         United States
# 27                     Dillon Carmichael         United States
# 28                           Booka Shade               Germany
# 29                             J Álvarez           Puerto Rico
# 30                                  Bejo                 Spain
# 31                                 Lunay           Puerto Rico
# 32                              Conchita                 Spain
# 33                                Hozier               Ireland
# 34                                  Malú                 Spain
# 35                           Night Tempo           South Korea
# 36                                Lèpoka                 Spain
# 37                         Mitch Coodley                  NULL
# 38                                 Tycho         United States
# 39                                Milo j             Argentina
# 40                             Metallica         United States
# 41                                  maga                 Spain
# 42                        Rauw Alejandro           Puerto Rico
# 43                       Natalia Jiménez                 Spain
# 44                   Héroes del Silencio                 Spain
# 45                              Bizarrap             Argentina
# 46                               Hades66                  NULL
# 47                             Pablo Say                  NULL
# 48                                Arcane        United Kingdom
# 49                   My Chemical Romance         United States
# 50                          Nick Phoenix        United Kingdom
# 51                           Sofia Ellar                 Spain
# 52                          Tauren Wells         United States
# 53                               Rosario                 Spain
# 54                         Lenny Tavárez           Puerto Rico
# 55                                Shotta                 Spain
# 56                             Siggy Kim                  NULL
# 57                           Marco Tegui                  NULL
# 58                         Cole Swindell         United States
# 59                          Randy Newman         United States
# 60                             Big Thief         United States
# 61                           Saint Motel         United States
# 62                        Travis Denning         United States
# 63                              Bad Suns         United States
# 64                             Nicky Jam           Puerto Rico
# 65                          Marlon James               Jamaica
# 66                              Ana Mena                 Spain
# 67                              Brytiago           Puerto Rico
# 68                              Exxasens                 Spain
# 69                          Phil Wickham         United States
# 70                                SBTRKT        United Kingdom
# 71                                 Droow                  NULL
# 72                           Sniper Gang                  NULL
# 73                        Eli Young Band         United States
# 74                          La Casa Azul                 Spain
# 75                            Chase Rice         United States
# 76                                 UNKLE        United Kingdom
# 77                              Jamie xx        United Kingdom
# 78                     Pacho el Antifeka           Puerto Rico
# 79   La Maravillosa Orquesta del Alcohol                Burgos
# 80                              Swit Eme                  NULL
# 81                           Nosaj Thing         United States
# 82                               Amarion           Puerto Rico
# 83                           The Killers         United States
# 84                              Miranda!             Argentina
# 85                          Marlena Shaw         United States
# 86                       Pablo Ferrández                 Spain
# 87                                 Gidge                  Umeå
# 88                           Miss Kittin                France
# 89                           ONE OK ROCK                 Japan
# 90                                  Moby         United States
# 91                                   Air                France
# 92                                frasco                 Japan
# 93                               Justice                France
# 94                              Taburete                Madrid
# 95                         Glass Animals        United Kingdom
# 96                           Jeremy Camp         United States
# 97                         Brandon Heath         United States
# 98                                Bonobo        United Kingdom
# 99                      Brantley Gilbert         United States
# 100                              Anubiis                  NULL
# 101                              RedHook             Australia
# 102                         Jane Remover               Chicago
# 103                        Cecilia Krull                 Spain
# 104                        Janine Jansen           Netherlands
# 105                            Jay Menez                  NULL
# 106                Francesca Battistelli         United States
# 107                       Paula Mattheus                 Spain
# 108                             Röyksopp                Norway
# 109                       Fondo Flamenco                 Spain
# 110                            La Paloma                Madrid
# 111                                Leiva                 Spain
# 112                          Arnau Griso                  NULL
# 113                              valence                  NULL
# 114                         Green Valley                 Spain
# 115                            Dark Moor                 Spain
# 116                               Yandel           Puerto Rico
# 117                             Delaossa                 Spain
# 118                       Mikel Erentxun                 Spain
# 119                            Faithless        United Kingdom
# 120                    Antonio Ruiz‐Pipó                 Spain
# 121                                 Rysy                Poland
# 122                                Viuda                  NULL
# 123                        Generación 12              Colombia
# 124                           black midi                London
# 125                         Foo Fighters         United States
# 126                    Gabriella Quevedo                Sweden
# 127                         Corina Smith             Venezuela
# 128      Tom Petty and the Heartbreakers         United States
# 129                       Rival Consoles        United Kingdom
# 130                               Edurne                 Spain
# 131                             Gorillaz               England
# 132                            Fever Ray                Sweden
# 133                         Fatima Hajji                 Spain
# 134                           WhoMadeWho               Denmark
# 135                               Blessd              Colombia
# 136                          Danny Gokey         United States
# 137                              ELYELLA                Madrid
# 138                            Tiago PZK             Argentina
# 139                         Café Quijano                 Spain
# 140                          Arde Bogotá                 Spain
# 141                       Ryan Stevenson         United States
# 142                      Jerry Lee Lewis         United States
# 143                               Noriel           Puerto Rico
# 144                             Slipknot         United States
# 145                           Inner Wave           Los Angeles
# 146                   Jefferson Airplane         United States
# 147                              Orbital        United Kingdom
# 148                 Manchester Orchestra         United States
# 149                           Cody Jinks                  NULL
# 150                         Goodbye June                  NULL
# 151                                Dalex           Puerto Rico
# 152                             Fyahbwoy                 Spain
# 153                          Marcus King         United States
# 154                   Olivia Newton‐John             Australia
# 155                  Proyecto Gomez Casa          Buenos Aires
# 156                        Groove Armada        United Kingdom
# 157                            Jon Pardi         United States
# 158                              Melendi                 Spain
# 159                               Darell           Puerto Rico
# 160                          Mammoth WVH         United States
# 161                       Band of Horses         United States
# 162                                Jon Z           Puerto Rico
# 163                     Cali y El Dandee              Colombia
# 164                           Elton John        United Kingdom
# 165                            Bad Bunny           Puerto Rico
# 166                           Klangstein                  NULL
# 167                              Skalpel                Poland
# 168                               Mihali               Vermont
# 169                         Mistah Godeh                  NULL
# 170                    We Came as Romans         United States
# 171                                Dauwd                London
# 172                            The Score         United States
# 173                         Modeselektor               Germany
# 174                               Vendex                 Spain
# 175                            Morcheeba        United Kingdom
# 176                            Sigur Rós               Iceland
# 177                          Clap! Clap!                 Italy
# 178                          Opera Magna                 Spain
# 179                          Ocer y Rade                 Spain
# 180                               WarCry                 Spain
# 181                             Fangoria                 Spain
# 182                          Beach House         United States
# 183                         Foreign Teck                  NULL
# 184                       Antonio Orozco                 Spain
# 185                                 Izal                 Spain
# 186                       Harry Was Here         United States
# 187                             Megadeth         United States
# 188                                Saiko                 Chile
# 189                               Foyone                 Spain
# 190                       Joaquín Sabina                 Spain
# 191                    Father John Misty         United States
# 192                       Piano Dreamers                  NULL
# 193                           Fruit Bats         United States
# 194                             The 1975        United Kingdom
# 195                      Manuel Barrueco                  Cuba
# 196                        Justin Quiles           Puerto Rico
# 197                                Marea                 Spain
# 198                      Greta Van Fleet         United States
# 199                            Bleachers         United States
# 200                            Motörhead        United Kingdom
# 201                          Pequeño Pez             Argentina
# 202                            Blockhead         United States
# 203                       India Martínez                 Spain
# 204                                 Kaze         United States
# 205                                Pusho           Puerto Rico
# 206                           Mike Bahía              Colombia
# 207                         Old Dominion         United States
# 208                         Fallen Roses                  NULL
# 209                                 HVOB               Austria
# 210                     Three Days Grace                Canada
# 211                               Zahara                 Spain
# 212                                 MAKI                 Japan
# 213                       Arctic Monkeys        United Kingdom
# 214                           Mägo de Oz                 Spain
# 215                 Amistades Peligrosas                 Spain
# 216                           Tropidelic         United States
# 217                      City of the Sun         United States
# 218                             Pol 3.14                Madrid
# 219                               Ray MD                  NULL
# 220                                 Rhye         United States
# 221                                LOUTA             Argentina
# 222                                 Maná                Mexico
# 223                             Polyphia         United States
# 224                                Plaid        United Kingdom
# 225                           Digitalism               Germany
# 226                              Alvvays                Canada
# 227                        Guns N’ Roses         United States
# 228                           Nils Frahm               Germany
# 229                          Lola Índigo                 Spain
# 230                                E.VAX                  NULL
# 231                        Soleá Morente                 Spain
# 232                                Dekko                  NULL
# 233                              Farruko           Puerto Rico
# 234                               Jowell           Puerto Rico
# 235                             Mastodon         United States
# 236                         Hooverphonic               Belgium
# 237                            El Chojin                 Spain
# 238                      PELICAN FANCLUB                 Japan
# 239                     Ele A el Dominio           Puerto Rico
# 240              Los Fabulosos Cadillacs             Argentina
# 241                          Spacey Jane                 Perth
# 242                         Jens Buchert               Germany
# 243                        Austin French                  NULL
# 244                           Rata Negra                 Spain
# 245                                 Arce                 Chile
# 246                      Comandante Twin                  NULL
# 247                                 Guts                France
# 248                               Bombai                  NULL
# 249                             Arcángel           Puerto Rico
# 250                              Toundra                 Spain
# 251                  Death Cab for Cutie         United States
# 252                              Shinova                 Spain
# 253                             Manu Dia                  NULL
# 254                                Spoon         United States
# 255   Totally Enormous Extinct Dinosaurs        United Kingdom
# 256                            Ryan Hurd         United States
# 257                       Fontaines D.C.               Ireland
# 258                               Rokero                  NULL
# 259                               Zion I         United States
# 260                              Will C.          Fort Collins
# 261                           Los Bravos                 Spain
# 262                           Mac Powell         United States
# 263                 UNISON SQUARE GARDEN                 Japan
# 264                         Alice Wonder                 Spain
# 265                        Neutro Shorty             Venezuela
# 266                   Friday Pilots Club         United States
# 267                          Fleet Foxes         United States
# 268                             Jerry Di             Venezuela
# 269                      The Del‐Vikings         United States
# 270                   Nathaniel Rateliff         United States
# 271                               Trueno             Argentina
# 272                        Dorothy Moore         United States
# 273                             Ladytron        United Kingdom
# 274                 Tedeschi Trucks Band         United States
# 275                            Zaidbreak                  NULL
# 276                             Rawayana             Venezuela
# 277                          Skylar Grey         United States
# 278                    Christian Löffler               Germany
# 279                         The Rudeboyz              Colombia
# 280                          Jason Kolàr                  NULL
# 281                      Brittany Howard                Athens
# 282                          El Arrebato                 Spain
# 283                          Nyno Vargas                 Spain
# 284                        Róisín Murphy               Ireland
# 285                         Camilo Sesto                 Spain
# 286                           Ñengo Flow           Puerto Rico
# 287                                Wisin           Puerto Rico
# 288                           Pol Granch                  NULL
# 289                           Juan Magán                 Spain
# 290                       Sufjan Stevens         United States
# 291                      Little Stranger            Charleston
# 292                             Parmalee         United States
# 293                                Ozuna           Puerto Rico
# 294                           Axel Boman                Sweden
# 295                         Colton Dixon         United States
# 296                    Pablo de Sarasate                 Spain
# 297                             RADWIMPS                 Japan
# 298                          Jon Hopkins        United Kingdom
# 299                         Walker Hayes         United States
# 300                          Limp Bizkit         United States
# 301                     Lake Street Dive         United States
# 302                       THE DRIVER ERA         United States
# 303                         Dominic Fike               Florida
# 304                            Badflower           Los Angeles
# 305                          Jesse Roper                Canada
# 306                      Blanco Palamera                  NULL
# 307                         Soccer Mommy         United States
# 308                                 Rojo                Mexico
# 309                           Avi Jossef                  NULL
# 310                    Ross From Friends        United Kingdom
# 311                                 Abäk            Costa Rica
# 312                               Yonaka              Brighton
# 313                             Catalyna                  NULL
# 314                          Rafa Espino                 Spain
# 315                                Wisin           Puerto Rico
# 316                                Queen        United Kingdom
# 317                                  Zoé                Mexico
# 318                 Bring Me the Horizon        United Kingdom
# 319                            Yan Block                  NULL
# 320                           Luke Bryan         United States
# 321                            The Knife                Sweden
# 322                       Álvaro de Luna               Sevilla
# 323                              The Who        United Kingdom
# 324                              Rozalén                 Spain
# 325                           Wolf Alice        United Kingdom
# 326                        The Offspring         United States
# 327                               Tricky        United Kingdom
# 328                            Hadadanza                 Spain
# 329                             Måneskin                 Italy
# 330                      Scotty McCreery         United States
# 331                      Federico Mompou                 Spain
# 332                          Danny Ocean         United States
# 333                               Crisix                 Spain
# 334                      Rend Collective      Northern Ireland
# 335                           Toro y Moi         United States
# 336                    Aleksander Dębicz                Poland
# 337                                Beéle              Colombia
# 338                        David Cordero                 Cádiz
# 339                       Zac Brown Band         United States
# 340                            The Beths           New Zealand
# 341                          Adam Jensen                Boston
# 342                             Javiielo                  NULL
# 343                         Romeo Santos         United States
# 344                          Andy Rivera              Colombia
# 345                        Mother Mother                Canada
# 346                              Mestiza                  NULL
# 347                           Mora Träsk                Sweden
# 348                      Rosalie Sorrels         United States
# 349                      BUMP OF CHICKEN                 Japan
# 350                             Jotaerre                  NULL
# 351                        Shane & Shane         United States
# 352                       Dani Fernández                 Spain
# 353                            Rammstein               Germany
# 354                              Greeicy              Colombia
# 355                          Nil Moliner                 Spain
# 356                                Dei V                  NULL
# 357                     Carolina Durante                 Spain
# 358                         Daniel Avery                London
# 359                         Sanctus Real         United States
# 360                                Locus                  NULL
# 361                              Caribou                Canada
# 362                         Thomas Rhett         United States
# 363                           Álex Ubago                 Spain
# 364                          Petey Pablo         United States
# 365                              Ca7riel             Argentina
# 366                          Mau y Ricky             Venezuela
# 367                           De La Rose           Puerto Rico
# 368                       Carlos Sadness                 Spain
# 369                        Shaila Dúrcal                 Spain
# 370                           Amon Tobin                Brazil
# 371                             quannnic               Florida
# 372                            Veintiuno                  NULL
# 373                        Leon Vynehall        United Kingdom
# 374                      Ella Baila Sola                 Spain
# 375                             Warpaint         United States
# 376                             Chevelle         United States
# 377                                Milly                 Italy
# 378                           Gold Panda        United Kingdom
# 379                              Crazy P        United Kingdom
# 380                        FERNANDOCOSTA                 Spain
# 381                           Califato ¾               Sevilla
# 382                       SunKissed Lola           Philippines
# 383                               Palace              Kentucky
# 384                            Metronomy        United Kingdom
# 385                           St Germain                France
# 386                                 Feid              Colombia
# 387                          Dímelo Flow                Panama
# 388                           Wild Honey                 Spain
# 389                    The Goo Goo Dolls         United States
# 390                             Art Lown                  NULL
# 391                        Pacific Roots                  NULL
# 392                             Bee Gees        United Kingdom
# 393                          Iron Maiden        United Kingdom
# 394                          Dan Bremnes                Canada
# 395                          Niña Polaca                 Spain
# 396                         Stars Go Dim                  NULL
# 397                       Heitor Pereira                Brazil
# 398                       Jacques Greene                Canada
# 399              The Unlikely Candidates         United States
# 400                          Duran Duran        United Kingdom
# 401                                Fuego         United States
# 402                        Lauren Daigle         United States
# 403                        Natalie Grant         United States
# 404                               Jhayco           Puerto Rico
# 405                           Rapsusklei                 Spain
# 406                         Prince Royce         United States
# 407                    Cerebral Effusion                 Spain
# 408                         All Time Low         United States
# 409                    Mitchell Tenpenny         United States
# 410                                 Pole               Germany
# 411                          The Wombats        United Kingdom
# 412                           Drugdealer           Los Angeles
# 413                       Paul McCartney        United Kingdom
# 414                           YOVNGCHIMI                  NULL
# 415                                Porta                 Spain
# 416                      Juan del Encina                 Spain
# 417                Red Hot Chili Peppers         United States
# 418                          Álvaro Díaz           Puerto Rico
# 419                        Casper Mágico           Puerto Rico
# 420                              Midrift                  NULL
# 421                         Nicki Nicole             Argentina
# 422                        Ozzy Osbourne           Los Angeles
# 423                            Recondite                Berlin
# 424                               Ambkor                 Spain
# 425                     The War on Drugs         United States
# 426                   Insane Clown Posse         United States
# 427                      Dante Alighieri                 Italy
# 428                            Hombres G                 Spain
# 429                                Yampi           Puerto Rico
# 430                        Gente de Zona                  Cuba
# 431                           Houndmouth         United States
# 432                             J Balvin              Colombia
# 433                             Adventus                 Spain
# 434                    George FitzGerald        United Kingdom
# 435              Wolfgang Amadeus Mozart               Austria
# 436                                Momma         United States
# 437                                 Nach                 Spain
# 438                           Siddhartha                Mexico
# 439                           Rebelution         United States
# 440                         Robert Plant        United Kingdom
# 441                         Juana Molina             Argentina
# 442                                Ska-P                 Spain
# 443                         Dustin Lynch         United States
# 444                           Synlakross                  NULL
# 445                         Télépopmusik                France
# 446                        lovelytheband         United States
# 447                        Vetusta Morla                 Spain
# 448                               Tregua                  NULL
# 449                           Ill Pekeño                 Spain
# 450                            El Barrio                 Spain
# 451                                 花冷え。                 Japan
# 452                      Ulrich Schnauss               Germany
# 453                                Aimer                 Japan
# 454                           Billy Idol        United Kingdom
# 455                          Joe Goddard        United Kingdom
# 456                     Angelus Apatrida                 Spain
# 457                              Vitalic                France
# 458                              Dardust                 Italy
# 459                                 BOUE                  NULL
# 460                              Santana         United States
# 461                               Rels B                 Spain
# 462                       Barns Courtney        United Kingdom
# 463                          David Otero                 Spain
# 464                        Azúcar Moreno                 Spain
# 465                        Hannah Murphy                  NULL
# 466              if i die in mississippi              Gulfport
# 467                              Luna Li                Canada
# 468                             KARBeats           Puerto Rico
# 469                             Sam Hunt         United States
# 470                                 Ñejo           Puerto Rico
# 471                               Daphni                Canada
# 472                                alt‐J        United Kingdom
# 473                                  Eve         United States
# 474                           Underworld        United Kingdom
# 475                           Chris Jedi           Puerto Rico
# 476                             Lone Ark                 Spain
# 477                    The White Stripes         United States
# 478                  Of Monsters and Men               Iceland
# 479                           Young Miko           Puerto Rico
# 480                               Weezer         United States
# 481                           Wax Tailor                France
# 482                              Piso 21              Colombia
# 483                             Rochy RD    Dominican Republic
# 484                        Little Dragon                Sweden
# 485                              Crowder         United States
# 486              Black Country, New Road        United Kingdom
# 487                 La Oreja de Van Gogh                 Spain
# 488                             P.A.F.F.                Poland
# 489                           Aldo Cadiz                  NULL
# 490                            Goth Babe                  NULL
# 491                   Global Underground                  NULL
# 492                         The Almighty        United Kingdom
# 493                        Mano Le Tough                  NULL
# 494                              DECO*27                 Japan
# 495                           Max Cooper        United Kingdom
# 496                        Manuel Turizo              Colombia
# 497                        Vanesa Martín                 Spain
# 498                             Kidd Keo                 Spain
# 499                                 Sech                Panama
# 500                        Sophie Powers                  NULL
# 501                       The Ghost Club            Pittsburgh
# 502                     Yakamoto Kotzuga               Venezia
# 503                         Soge Culebra                 Spain
# 504                      Víctor Porfidio                  NULL
# 505                                IDLES        United Kingdom
# 506                             Hot Chip        United Kingdom
# 507                            Suso Sáiz                 Spain
# 508                          Surfer Girl                  NULL
# 509                           Marc Seguí                 Spain
# 510                             Israel B                 Spain
# 511                               Aitana                 Spain
# 512                    Russell Dickerson         United States
# 513                        Fuel Fandango                 Spain
# 514                          Kodak Black         United States
# 515                         Flying Lotus         United States
# 516                        Bomba Estéreo              Colombia
# 517                              Quantic                Bogotá
# 518                     Meredith Andrews         United States
# 519                              Chanell                  NULL
# 520                   The Crystal Method           Los Angeles
# 521                        Joyce Santana           Puerto Rico
# 522                         Sergio Dalma                 Spain
# 523                              Mujeres                 Spain
# 524                        House of Pain         United States
# 525                   Natalia Lafourcade                Mexico
# 526                         Stephen King         United States
# 527                       Noah Gundersen         United States
# 528                               Alex G         United States
# 529                               Lyanno           Puerto Rico
# 530                             MorphiuM                Girona
# 531                             grandson                Canada
# 532                               Pejzaż                Warsaw
# 533                             Aventura         United States
# 534                                Cazzu             Argentina
# 535                        Andy Williams         United States
# 536                             Dua Lipa               England
# 537                       Joaquín Turina                 Spain
# 538                           Recycled J                 Spain
# 539                        Kings of Leon         United States
# 540                            Vana Liya         United States
# 541                         Matthew West         United States
# 542                                 Korn         United States
# 543                          Royal Blood        United Kingdom
# 544                               Burial        United Kingdom
# 545                           DJs Pareja          Buenos Aires
# 546                             Saratoga                 Spain
# 547                         Hippo Campus         United States
# 548                           Nio García           Puerto Rico
# 549                                Decai                 Spain
# 550                              KAROL G              Colombia
# 551                          Viva Suecia                 Spain
# 552                          Micah Tyler         United States
# 553                         De La Ghetto           Puerto Rico
# 554                    Francisco Tárrega                 Spain
# 555                      Love of Lesbian                 Spain
# 556                                Bibio        United Kingdom
# 557                     Chencho Corleone           Puerto Rico
# 558                              Becky G         United States
# 559                          Drew Parker                  NULL
# 560                               Lérica                 Spain
# 561                         Bryant Myers           Puerto Rico
# 562                            DJ Tennis                 Italy
# 563                             Hercules                Athens
# 564              The Bones of J.R. Jones              New York
# 565                                Beret                 Spain
# 566                        Sneaker Pimps        United Kingdom
# 567                        Los Rebujitos                 Spain
# 568                            Lee Brice         United States
# 569                                 Tiga                Canada
# 570                       Andrea Sertori                 Italy
# 571                         Jason Aldean         United States
# 572                                Weval           Netherlands
# 573                         Henry Méndez                 Spain
# 574                         MJ Lenderman             Asheville
# 575                      Dollar Selmouni                 Spain
# 576                               Jasmon                  NULL
# 577                               Maluma              Colombia
# 578                        Bear McCreary         United States
# 579                             Two Feet         United States
# 580                               K.Flay         United States
# 581                         Rise Against         United States
# 582                           Royel Otis                Sydney
# 583                                 Tool         United States
# 584                       Valeria Castro            Las Palmas
# 585                          Sexy Zebras                 Spain
# 586                               DVICIO                Madrid
# 587                            Elle King         United States
# 588                             Vulfpeck         United States
# 589                              tobyMac         United States
# 590           Josiah and the Bonnevilles                  NULL
# 591                       Chandler Moore               Atlanta
# 592                      Various Artists                  NULL
# 593                         Rhett Walker                  NULL
# 594                              Kixnare                Poland
# 595                              Angelos                  NULL
# 596                                Tainy           Puerto Rico
# 597                              Guaynaa           Puerto Rico
# 598                            Micro TDH             Venezuela
# 599                               Warmth                 Spain
# 600                         Petula Clark        United Kingdom
# 601                                 DENM         United States
# 602                                Tosca               Austria
# 603                        Natti Natasha    Dominican Republic
# 604                 Guitarricadelafuente                 Spain
# 605                         Reykjavik606                 Spain
# 606                      Jameson Rodgers         United States
# 607                       Arrested Youth         United States
# 608                              Pailita              Santiago
# 609                               Khaled               Algeria
# 610                          Joy Orbison        United Kingdom
# 611                         Sunday Noise                  NULL
# 612                                Nueen             Barcelona
# 613                          Dirty Heads         United States
# 614                        Niño de Elche                 Elche
# 615                            Kip Moore         United States
# 616                   Coheed and Cambria         United States
# 617                         Ladilla Rusa                 Spain
# 618                              Salduie                  NULL
# 619                       The Happy Fits            New Jersey
# 620                     Sergio Contreras                 Spain
# 621                          Peces Raros              La Plata
# 622                                 KHEA             Argentina
# 623                         Paulo Londra             Argentina
# 624                         Mount Kimbie               England
# 625                       Mónica Naranjo                 Spain
# 626                       Brandi Carlile         United States
# 627                        Rachael Lampa         United States
# 628                          James Brown         United States
# 629                                  Âme               Germany
# 630                         Tierra Santa                 Spain
# 631                               Saurom                 Spain
# 632                       James McMurtry         United States
# 633                         Funambulista                 Spain
# 634                             coldrain                 Japan
# 635                         David Bisbal                 Spain
# 636                                  vf7                  NULL
# 637                        Daniel Zueras                 Spain
# 638                                 Hoke                 Spain
# 639                             Don Omar           Puerto Rico
# 640                        Alex Gárgolas           Puerto Rico
# 641                          Kairikibear                  NULL
# 642                            Wine Lips               Toronto
# 643                             Daughtry         United States
# 644                               Mogwai        United Kingdom
# 645                            I Am They           Carson City
# 646                       Stephen Bishop         United States
# 647                              Volbeat               Denmark
# 648                              Journey         United States
# 649                    Fantastic Negrito               Oakland
# 650                        María Becerra             Argentina
# 651                          Babasónicos             Argentina
# 652                    Sébastien Tellier                France
# 653                         Jimmie Allen         United States
# 654                          Tame Impala             Australia
# 655                         Trentemøller               Denmark
# 656                           Matt Maher         United States
# 657                       Brett Eldredge         United States
# 658                                Alejo                  NULL
# 659                         Milky Chance               Germany
# 660                              Sho-Hai                 Spain
# 661                              Dayglow         United States
# 662               from tokyo to honolulu                Russia
# 663                                  Ovi         United States
# 664                                 Boza                Panama
# 665                               Yamila               Belgium
# 666                        Basement Jaxx        United Kingdom
# 667                                Denom                 Spain
# 668                              Slayter              New York
# 669                      Imagine Dragons         United States
# 670                               Romare        United Kingdom
# 671                              MercyMe         United States
# 672                    The Green Pajamas         United States
# 673                         Bonnie Raitt         United States
# 674                     Sharon Van Etten         United States
# 675                          Tony Guerra                Brazil
# 676                              Zetazen                 Spain
# 677                          Dani Martín                 Spain
# 678                                Depol                  NULL
# 679                           Logan Mize         United States
# 680                             Level 42        United Kingdom
# 681                    We Are Messengers         United States
# 682                        Alberto Dimeo               Maracay
# 683                           Papa Roach         United States
# 684                        Elvis Presley         United States
# 685                       Miguel Bastida                  NULL
# 686                           Tyler Rich         United States
# 687                               Nikone                 Spain
# 688                               Yeruza                  NULL
# 689                   MAN WITH A MISSION                 Japan
# 690                          Pablo López                 Spain
# 691                           Sam Fender        United Kingdom
# 692                        The Elovaters                Boston
# 693                               Sharif                 Spain
# 694                         Natos y Waor                 Spain
# 695                         The Movement         United States
# 696                                 Dice                  NULL
# 697                              DJ Koze               Germany
# 698                       Fit for a King         United States
# 699                            Old Mervs     Western Australia
# 700                               MARETU                 Japan
# 701                     Daniel Barenboim             Argentina
# 702                      Manuel Carrasco                 Spain
# 703                            The Poles           South Korea
# 704                    twenty one pilots         United States
# 705                                Björk               Iceland
# 706                               Soraya         United States
# 707                      Danza Invisible                 Spain
# 708                Hiss Golden Messenger         United States
# 709                    Nightmares on Wax        United Kingdom
# 710                           John Hiatt         United States
# 711                           Clara Cava             Argentina
# 712                        Pablo Alborán                 Spain
# 713                               Chenoa                 Spain
# 714                       Highly Suspect         United States
# 715                      Portico Quartet        United Kingdom
# 716                            Elefantes                 Spain
# 717                    Dead Poet Society           Los Angeles
# 718                        Andrés Suárez                 Spain
# 719                               Tamara                 Spain
# 720                                 Reik                Mexico
# 721                      La Bien Querida                 Spain
# 722                   Quarters of Change              New York
# 723                              Iration         United States
# 724                               Pixies         United States
# 725                           Brent Cobb         United States
# ...
# 250          Actualidad
# 251          Actualidad
# 252          Actualidad
# 253          Actualidad
# 254          Actualidad
# 255          Actualidad
# 256          Actualidad
# 257          Actualidad
# 258          Actualidad
# 259          Actualidad
# 260          Actualidad
# 261                1968
# 262          Actualidad
# 263          Actualidad
# 264          Actualidad
# 265          Actualidad
# 266          Actualidad
# 267          Actualidad
# 268          Actualidad
# 269           No activo
# 270          Actualidad
# 271          Actualidad
# 272          Actualidad
# 273          Actualidad
# 274          Actualidad
# 275          Actualidad
# 276          Actualidad
# 277          Actualidad
# 278          Actualidad
# 279          Actualidad
# 280          Actualidad
# 281          Actualidad
# 282          Actualidad
# 283          Actualidad
# 284          Actualidad
# 285          2019-09-08
# 286          Actualidad
# 287          Actualidad
# 288          Actualidad
# 289          Actualidad
# 290          Actualidad
# 291          Actualidad
# 292          Actualidad
# 293          Actualidad
# 294          Actualidad
# 295          Actualidad
# 296          1908-09-28
# 297          Actualidad
# 298          Actualidad
# 299          Actualidad
# 300          Actualidad
# 301          Actualidad
# 302          Actualidad
# 303          Actualidad
# 304          Actualidad
# 305          Actualidad
# 306          Actualidad
# 307          Actualidad
# 308          Actualidad
# 309          Actualidad
# 310          Actualidad
# 311          Actualidad
# 312          Actualidad
# 313          Actualidad
# 314          Actualidad
# 315          Actualidad
# 316           No activo
# 317          Actualidad
# 318          Actualidad
# 319          Actualidad
# 320          Actualidad
# 321             2014-11
# 322          Actualidad
# 323          Actualidad
# 324          Actualidad
# 325          Actualidad
# 326          Actualidad
# 327          Actualidad
# 328          Actualidad
# 329          Actualidad
# 330          Actualidad
# 331          1987-06-30
# 332          Actualidad
# 333          Actualidad
# 334          Actualidad
# 335          Actualidad
# 336          Actualidad
# 337          Actualidad
# 338          Actualidad
# 339          Actualidad
# 340          Actualidad
# 341          Actualidad
# 342          Actualidad
# 343          Actualidad
# 344          Actualidad
# 345          Actualidad
# 346                2009
# 347          Actualidad
# 348          2017-06-11
# 349          Actualidad
# 350          Actualidad
# 351          Actualidad
# 352          Actualidad
# 353          Actualidad
# 354          Actualidad
# 355          Actualidad
# 356          Actualidad
# 357          Actualidad
# 358          Actualidad
# 359          Actualidad
# 360                2005
# 361          Actualidad
# 362          Actualidad
# 363          Actualidad
# 364          Actualidad
# 365          Actualidad
# 366          Actualidad
# 367          Actualidad
# 368          Actualidad
# 369          Actualidad
# 370          Actualidad
# 371          Actualidad
# 372          Actualidad
# 373          Actualidad
# 374                2001
# 375          Actualidad
# 376          Actualidad
# 377          1980-09-22
# 378          Actualidad
# 379          Actualidad
# 380          Actualidad
# 381          Actualidad
# 382          Actualidad
# 383          Actualidad
# 384          Actualidad
# 385          Actualidad
# 386          Actualidad
# 387          Actualidad
# 388          Actualidad
# 389          Actualidad
# 390          Actualidad
# 391          Actualidad
# 392                2003
# 393          Actualidad
# 394          Actualidad
# 395          Actualidad
# 396          Actualidad
# 397          Actualidad
# 398          Actualidad
# 399          Actualidad
# 400          Actualidad
# 401          Actualidad
# 402          Actualidad
# 403          Actualidad
# 404          Actualidad
# 405          Actualidad
# 406          Actualidad
# 407          Actualidad
# 408          Actualidad
# 409          Actualidad
# 410          Actualidad
# 411          Actualidad
# 412          Actualidad
# 413          Actualidad
# 414          Actualidad
# 415          Actualidad
# 416                1529
# 417          Actualidad
# 418          Actualidad
# 419          Actualidad
# 420          Actualidad
# 421          Actualidad
# 422          Actualidad
# 423          Actualidad
# 424          Actualidad
# 425          Actualidad
# 426          Actualidad
# 427          1321-09-14
# 428          Actualidad
# 429          Actualidad
# 430          Actualidad
# 431          Actualidad
# 432          Actualidad
# 433          Actualidad
# 434          Actualidad
# 435          1791-12-05
# 436          Actualidad
# 437          Actualidad
# 438          Actualidad
# 439          Actualidad
# 440          Actualidad
# 441          Actualidad
# 442          Actualidad
# 443          Actualidad
# 444          Actualidad
# 445          Actualidad
# 446          Actualidad
# 447          Actualidad
# 448          Actualidad
# 449          Actualidad
# 450          Actualidad
# 451          Actualidad
# 452          Actualidad
# 453          Actualidad
# 454          Actualidad
# 455          Actualidad
# 456          Actualidad
# 457          Actualidad
# 458          Actualidad
# 459          Actualidad
# 460          Actualidad
# 461          Actualidad
# 462          Actualidad
# 463          Actualidad
# 464          Actualidad
# 465          Actualidad
# 466          Actualidad
# 467          Actualidad
# 468          Actualidad
# 469          Actualidad
# 470          Actualidad
# 471          Actualidad
# 472          Actualidad
# 473          Actualidad
# 474          Actualidad
# 475          Actualidad
# 476          Actualidad
# 477          2011-02-02
# 478          Actualidad
# 479          Actualidad
# 480          Actualidad
# 481          Actualidad
# 482          Actualidad
# 483          Actualidad
# 484          Actualidad
# 485          Actualidad
# 486          Actualidad
# 487          Actualidad
# 488          Actualidad
# 489          Actualidad
# 490          Actualidad
# 491          Actualidad
# 492          Actualidad
# 493          Actualidad
# 494          Actualidad
# 495          Actualidad
# 496          Actualidad
# 497          Actualidad
# 498          Actualidad
# 499          Actualidad
# 500          Actualidad
# 501          Actualidad
# 502          Actualidad
# 503          Actualidad
# 504          Actualidad
# 505          Actualidad
# 506          Actualidad
# 507          Actualidad
# 508          Actualidad
# 509          Actualidad
# 510          Actualidad
# 511          Actualidad
# 512          Actualidad
# 513          Actualidad
# 514          Actualidad
# 515          Actualidad
# 516          Actualidad
# 517          Actualidad
# 518          Actualidad
# 519          Actualidad
# 520          Actualidad
# 521          Actualidad
# 522          Actualidad
# 523          Actualidad
# 524                1996
# 525          Actualidad
# 526          Actualidad
# 527          Actualidad
# 528          Actualidad
# 529          Actualidad
# 530          Actualidad
# 531          Actualidad
# 532          Actualidad
# 533          Actualidad
# 534          Actualidad
# 535          2012-09-25
# 536          Actualidad
# 537          1949-01-14
# 538          Actualidad
# 539          Actualidad
# 540          Actualidad
# 541          Actualidad
# 542          Actualidad
# 543          Actualidad
# 544          Actualidad
# 545          Actualidad
# 546          Actualidad
# 547          Actualidad
# 548          Actualidad
# 549          Actualidad
# 550          Actualidad
# 551          Actualidad
# 552          Actualidad
# 553          Actualidad
# 554          1909-12-15
# 555          Actualidad
# 556          Actualidad
# 557          Actualidad
# 558          Actualidad
# 559          Actualidad
# 560          Actualidad
# 561          Actualidad
# 562          Actualidad
# 563          Actualidad
# 564          Actualidad
# 565          Actualidad
# 566          Actualidad
# 567          Actualidad
# 568          Actualidad
# 569          Actualidad
# 570          Actualidad
# 571          Actualidad
# 572          Actualidad
# 573          Actualidad
# 574          Actualidad
# 575          Actualidad
# 576          Actualidad
# 577          Actualidad
# 578          Actualidad
# 579          Actualidad
# 580          Actualidad
# 581          Actualidad
# 582          Actualidad
# 583          Actualidad
# 584          Actualidad
# 585          Actualidad
# 586          Actualidad
# 587          Actualidad
# 588          Actualidad
# 589          Actualidad
# 590          Actualidad
# 591          Actualidad
# 592          Actualidad
# 593          Actualidad
# 594          Actualidad
# 595          Actualidad
# 596          Actualidad
# 597          Actualidad
# 598          Actualidad
# 599          Actualidad
# 600          Actualidad
# 601          Actualidad
# 602          Actualidad
# 603          Actualidad
# 604          Actualidad
# 605          Actualidad
# 606          Actualidad
# 607          Actualidad
# 608          Actualidad
# 609          Actualidad
# 610          Actualidad
# 611          Actualidad
# 612          Actualidad
# 613          Actualidad
# 614          Actualidad
# 615          Actualidad
# 616          Actualidad
# 617          Actualidad
# 618          Actualidad
# 619          Actualidad
# 620          Actualidad
# 621          Actualidad
# 622          Actualidad
# 623          Actualidad
# 624          Actualidad
# 625          Actualidad
# 626          Actualidad
# 627          Actualidad
# 628          2006-12-25
# 629          Actualidad
# 630          Actualidad
# 631          Actualidad
# 632          Actualidad
# 633          Actualidad
# 634          Actualidad
# 635          Actualidad
# 636          Actualidad
# 637          Actualidad
# 638          Actualidad
# 639          Actualidad
# 640          Actualidad
# 641          Actualidad
# 642          Actualidad
# 643          Actualidad
# 644          Actualidad
# 645          Actualidad
# 646          Actualidad
# 647          Actualidad
# 648          Actualidad
# 649          Actualidad
# 650          Actualidad
# 651          Actualidad
# 652          Actualidad
# 653          Actualidad
# 654          Actualidad
# 655          Actualidad
# 656          Actualidad
# 657          Actualidad
# 658          Actualidad
# 659          Actualidad
# 660          Actualidad
# 661          Actualidad
# 662          Actualidad
# 663          Actualidad
# 664          Actualidad
# 665          Actualidad
# 666          Actualidad
# 667          Actualidad
# 668          Actualidad
# 669          Actualidad
# 670          Actualidad
# 671          Actualidad
# 672          Actualidad
# 673          Actualidad
# 674          Actualidad
# 675          Actualidad
# 676          Actualidad
# 677          Actualidad
# 678          Actualidad
# 679          Actualidad
# 680          Actualidad
# 681          Actualidad
# 682          Actualidad
# 683          Actualidad
# 684          1977-08-16
# 685          Actualidad
# 686          Actualidad
# 687          Actualidad
# 688          Actualidad
# 689          Actualidad
# 690          Actualidad
# 691          Actualidad
# 692          Actualidad
# 693          Actualidad
# 694          Actualidad
# 695          Actualidad
# 696          Actualidad
# 697          Actualidad
# 698          Actualidad
# 699          Actualidad
# 700          Actualidad
# 701          Actualidad
# 702          Actualidad
# 703          Actualidad
# 704          Actualidad
# 705          Actualidad
# 706          2006-05-10
# 707          Actualidad
# 708          Actualidad
# 709          Actualidad
# 710          Actualidad
# 711          Actualidad
# 712          Actualidad
# 713          Actualidad
# 714          Actualidad
# 715          Actualidad
# 716          Actualidad
# 717          Actualidad
# 718          Actualidad
# 719          Actualidad
# 720          Actualidad
# 721          Actualidad
# 722          Actualidad
# 723          Actualidad
# 724          Actualidad
# 725          Actualidad
# 726          Actualidad
# 727          Actualidad
# 728          Actualidad
# 729          Actualidad
# 730          Actualidad
# 731          Actualidad
# 732          Actualidad
# 733          Actualidad
# 734          Actualidad
# 735          Actualidad
# 736          Actualidad
# 737          Actualidad
# 738          Actualidad
# 739          Actualidad
# 740          1909-05-18
# 741          Actualidad
# 742          Actualidad
# 743          2022-02-06
# 744          Actualidad
# 745          Actualidad
# 746          Actualidad
# 747          Actualidad
# 748          Actualidad
# 749          Actualidad
# 750          Actualidad
# 751          Actualidad
# 752          Actualidad
# 753          Actualidad
# 754          Actualidad
# 755          Actualidad
# 756          Actualidad
# 757          Actualidad
# 758          Actualidad
# 759          Actualidad
# 760          Actualidad
# 761          Actualidad
# 762          Actualidad
# 763          Actualidad
# 764          Actualidad
# 765          Actualidad
# 766          Actualidad
# 767          Actualidad
# 768          Actualidad
# 769          Actualidad
# 770          Actualidad
# 771          Actualidad
# 772          Actualidad
# 773          Actualidad
# 774          Actualidad
# 775          Actualidad
# 776          Actualidad
# 777          Actualidad
# 778          Actualidad
# 779          Actualidad
# 780          Actualidad
# 781          Actualidad
# 782          Actualidad
# 783          Actualidad
# 784          Actualidad
# 785          Actualidad
# 786          Actualidad
# 787          Actualidad
# 788          Actualidad
# 789          Actualidad
# 790          Actualidad
# 791          1994-04-05
# 792          Actualidad
# 793          Actualidad
# 794          Actualidad
# 795          Actualidad
# 796          Actualidad
# 797          Actualidad
# 798          Actualidad
# 799          Actualidad
# 800          Actualidad
# 801          Actualidad
# 802          Actualidad
# 803          Actualidad
# 804          Actualidad
# 805          Actualidad
# 806          Actualidad
# 807          Actualidad
# 808          Actualidad
# 809          Actualidad
# 810          Actualidad
# 811          Actualidad
# 812          Actualidad
# 813          Actualidad
# 814          Actualidad
# 815          Actualidad
# 816          Actualidad
# 817          Actualidad
# 818          Actualidad
# 819          Actualidad
# 820          Actualidad
# 821          Actualidad
# 822          Actualidad
# 823          Actualidad
# 824          Actualidad
# 825          Actualidad
# 826          Actualidad
# 827          Actualidad
# 828          Actualidad
# 829          Actualidad
# 830          Actualidad
# 831          Actualidad
# 832          Actualidad
# 833          Actualidad
# 834          Actualidad
# 835          Actualidad
# 836          Actualidad
# 837          Actualidad
# 838          Actualidad
# 839          Actualidad
# 840          Actualidad
# 841          Actualidad
# 842          Actualidad
# 843          Actualidad
# 844          Actualidad
# 845          Actualidad
# 846          Actualidad
# 847          Actualidad
# 848          Actualidad
# 849          Actualidad
# 850          Actualidad
# 851          Actualidad
# 852          Actualidad
# 853          Actualidad
# 854          Actualidad
# 855          Actualidad
# 856          Actualidad
# 857          Actualidad
# 858          Actualidad
# 859          Actualidad
# 860          Actualidad
# 861          Actualidad
# 862          Actualidad
# 863          Actualidad
# 864          Actualidad

# %%
dataframe_MB1.to_csv('../data/dataframe_MB1.csv', index=False)

# %%
dict_artistas

# %% [markdown]
# ## Pasar datos a SQL

# %%
## Conección a base de datos: 
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='bd_pruebas') ###Usar esta base de prueba

print(cnx)

mycursor = cnx.cursor()
query = "INSERT INTO Artistas (artista_nombre) VALUES (%s)"
valores = [(artista,) for artista in list_artistas]
try: 
    mycursor.executemany(query, valores) ### execute many!
    cnx.commit()
    print(mycursor.rowcount, "registro insertado.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x0000022093B623D0>
# 899 registro insertado.

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='bd_pruebas')

print(cnx)
cnx.close()
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x00000220938631D0>

# %%
##Creamos zip para luego usarlo como 'val' y poder insertar los datos del diccionario en la tabla de SQL
valores_MB= zip(
    dict_artistas["artista"], dict_artistas["pais_de_origen"],  dict_artistas["area_de_origen"], dict_artistas["fecha_nacimiento"], dict_artistas["fecha_inicio_actividad"], dict_artistas["fecha_fin_actividad"]
)

# %%
## Conección a base de datos: 
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='bd_pruebas') ###Usar esta base de prueba

print(cnx)

mycursor = cnx.cursor()
query = "INSERT INTO musicbrainz (artista_nombre_MB, pais_origen, area_origen, fecha_nacimiento, fecha_inicio_act, fecha_final_act) VALUES (%s, %s, %s, %s, %s, %s)"
val = valores_MB ### aqui inserto ZIP
try: 
    mycursor.executemany(query, val) ### execute many!
    cnx.commit()
    print(mycursor.rowcount, "registro insertado.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x0000022093BEB550>
# 1062 (23000): Duplicate entry 'Santana' for key 'musicbrainz.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'Santana' for key 'musicbrainz.PRIMARY'

# %%
dataframe_MB = pd.DataFrame(dict_artistas) 
dataframe_MB

# %%
#Guardar dataframe como csv: 

dataframe_MB.to_csv('../data/dataframe_MB.csv', index=False)

# %% [markdown]
# Vamos a exportar los datos de Python a SQL utilizando sqlachemy. Importamos los df que hemos creado con las llamadas a las APIS.

# %%
import pandas as pd

# %%
# Abrir dataframe de MB para luego hacer la importacion. 
dataframe_MB_csv = pd.read_csv('../data/dataframe_MB.csv')

# %%
from sqlalchemy import create_engine

# %%
user='root'
password='AlumnaAdalab'
host='127.0.0.1'
database= # PONERLE EL NOMBRE DE LA BASE DE DATOS QUE ELIJAMOS
connection_string = f'mysql+mysqlconnector://{user}:{password}@{host}/{database}'
engine = create_engine(connection_string)

# %%
dataframe_MB_csv.to_sql(name=#NOMBRE DE LA TABLA QUE ELIJAMOS, con=engine, if_exists='append', index=False)
