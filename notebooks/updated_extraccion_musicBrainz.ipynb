# %%
import pandas as pd
import requests
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import os
from dotenv import load_dotenv 

import csv
import json

# %%
import time #para el time sleep

# %%
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# %% [markdown]
# Ejemplo de endpoint: "https://musicbrainz.org/ws/2/artist/?query=artist:XXXXXXXXX&fmt=json"

# %% [markdown]
# Función llamar api

# %%
def llamar_api(url):

    llamada = requests.get(url)  # Realiza una solicitud GET a la URL proporcionada y almacena la respuesta en 'llamada'.
    print(f"La llamada a la API nos ha dado una respuesta de tipo: {llamada.status_code}")  # Imprime el código de estado de la respuesta.
    if llamada.status_code != 200:  # Comprueba si la respuesta no fue exitosa (código de estado distinto de 200).
        print(f"El motivo por el que la llamada falló es {llamada.reason}")  # Imprime la razón de la falla.
    else:
        return llamada.json()  # Si la llamada fue exitosa, devuelve los datos de respuesta en formato JSON.

# %% [markdown]
# Sacar los artistas de Spotify:

# %%
# Paso 1: Leer el archivo CSV
spoti_csv_file = "../data/dataframes_combinados.csv" # nombre de tu archivo Spoti CSV
spoti_json_file = "dataframes_combinados.json"  # nombre del archivo Spoti de salida JSON

# Paso 2: Abrir el CSV y convertir a formato JSON
with open(spoti_csv_file, mode='r', encoding='utf-8') as file:
    # Leer el contenido CSV
    csv_reader = csv.DictReader(file)
    
    # Convertir cada fila a diccionario y agregarla a una lista
    data = [row for row in csv_reader]

# Paso 3: Escribir los datos en un archivo JSON
with open(spoti_json_file, mode='w', encoding='utf-8') as file:
    json.dump(data, file, indent=4)  # Guarda el JSON con formato legible (indent=4)

print(f'Archivo {spoti_json_file} creado con éxito.')
# Out:
# Archivo dataframes_combinados.json creado con éxito.

# %% [markdown]
# #Sacar los artistas de MB:

# %%
# Paso 1: Leer el archivo CSV
MB_csv_file = "../data/dataframe_MB.csv" # nombre de tu archivo Spoti CSV
MB_json_file = "dataframe_MB.json"  # nombre del archivo Spoti de salida JSON

# Paso 2: Abrir el CSV y convertir a formato JSON
with open(MB_csv_file, mode='r', encoding='utf-8') as file:
    # Leer el contenido CSV
    csv_reader = csv.DictReader(file)
    
    # Convertir cada fila a diccionario y agregarla a una lista
    data = [row for row in csv_reader]

# Paso 3: Escribir los datos en un archivo JSON
with open(MB_json_file, mode='w', encoding='utf-8') as file:
    json.dump(data, file, indent=4)  # Guarda el JSON con formato legible (indent=4)

print(f'Archivo {MB_json_file} creado con éxito.')
# Out:
# Archivo dataframe_MB.json creado con éxito.

# %%
#Traemos el archivo a json
with open("dataframe_MB.json","r") as f: 
    result_MB = json.load(f)

# %%
result_MB[0]
# Out:
# {'artista': 'Noah Gundersen',
#  'pais_de_origen': 'United States',
#  'area_de_origen': 'Olympia',
#  'fecha_nacimiento': '1989-05-31',
#  'fecha_inicio_actividad': 'NULL',
#  'fecha_fin_actividad': 'Actualidad'}

# %%
#Creamos lista vacia para que se complete con los artistas
artist = []

for item in result_spoti: 
    artist.append(item['artista'])

# %%
#Convertimos en set para eliminar artistas duplicados (hay artistas con mas de una canción en el mismo año)
set_artist = set(artist)
set_artist
# Out:
# {'AMBKOR',
#  'Abraham Mateo',
#  'Abäk',
#  'Accion Sanchez',
#  'Adam Jensen',
#  'Adventus',
#  'Aimer',
#  'Air',
#  'Aitana',
#  'Ak4:20',
#  'Alberto Dimeo',
#  'Aldo Cadiz',
#  'Alejo',
#  'Aleksander Debicz',
#  'Alex G',
#  'Alex Gargolas',
#  'Alex Rose',
#  'Alex Ubago',
#  'Alice Wonder',
#  'All Time Low',
#  'Almighty',
#  'Alvaro Diaz',
#  'Alvvays',
#  'Amadeüs',
#  'Amarion',
#  'Amenazzy',
#  'Amistades Peligrosas',
#  'Amon Tobin',
#  'Ana Mena',
#  'Andrea Sertori',
#  'Andrés Madariaga',
#  'Andrés Suárez',
#  'Andy & Lucas',
#  'Andy Frasco & The U.N.',
#  'Andy Rivera',
#  'Andy Stott',
#  'Angela Hewitt',
#  'Angelos',
#  'Angelus Apatrida',
#  'Ankhal',
#  'Ankor',
#  'Antonio José',
#  'Antonio Orozco',
#  'Antonio Ruiz Pipó',
#  'Anubiis',
#  'Anuel AA',
#  'Anıl Emre Daldal',
#  'Arcane',
#  'Arce',
#  'Arctic Monkeys',
#  'Arcy Drive',
#  'Arcángel',
#  'Arde Bogotá',
#  'Arnau Griso',
#  'Arrested Youth',
#  'Art Lown',
#  'Artury Pepper',
#  'Austin French',
#  'Aventura',
#  'Axel Boman',
#  'Ayax y Prok',
#  'Azucar Moreno',
#  'BICEP',
#  'BOUE',
#  'BUMP OF CHICKEN',
#  'Babasonicos',
#  'Bad Bunny',
#  'Bad Gyal',
#  'Bad Suns',
#  'Badflower',
#  'Bala',
#  'Band of Horses',
#  'Band&dos',
#  'Barns Courtney',
#  'Basement Jaxx',
#  'Beach House',
#  'Bear McCreary',
#  'Beatriz Luengo',
#  'Becky G',
#  'Bee Gees',
#  'Bejo',
#  'Belén Aguilera',
#  'Ben Rector',
#  'Beret',
#  'Beéle',
#  'Bibio',
#  'Big Thief',
#  'Billy Idol',
#  'Bizarrap',
#  'Björk',
#  'Black Country, New Road',
#  'Black Label Society',
#  'Blake',
#  'Blanco Palamera',
#  'Blas Cantó',
#  'Bleachers',
#  'Blessd',
#  'Blockhead',
#  'Bomba Estéreo',
#  'Bombai',
#  'Bonnie Raitt',
#  'Bonobo',
#  'Booka Shade',
#  'Boza',
#  'Brandi Carlile',
#  'Brandon Heath',
#  'Brantley Gilbert',
#  'Brent Cobb',
#  'Brett Eldredge',
#  'Bring Me The Horizon',
#  'Brittany Howard',
#  'Broken Lip',
#  'Brothers Osborne',
#  'Brray',
#  'Bryant Myers',
#  'Bryce Fox',
#  'Brytiago',
#  'Burial',
#  'CA7RIEL',
#  'CNCO',
#  'Café Quijano',
#  'Calero LDN',
#  'Cali Y El Dandee',
#  'Califato ¾',
#  'Camilo',
#  'Caribou',
#  'Carlos Baute',
#  'Carlos Herrera Music',
#  'Carlos Sadness',
#  'Carolina Durante',
#  'Casper Magico',
#  'Casting Crowns',
#  'Catalyna',
#  'Cazzu',
#  'Cecilia Krull',
#  'Celtian',
#  'Cerebral Effusion',
#  'Chandler Moore',
#  'Chanell',
#  'Chase Rice',
#  'Chencho Corleone',
#  'Chenoa',
#  'Chevelle',
#  'Chris Jedi',
#  'Chris Lane',
#  'Chris Tomlin',
#  'Christian Löffler',
#  'Cidergirl',
#  'City of the Sun',
#  'Clap! Clap!',
#  'Clara Cava',
#  'Clark',
#  'Cody Jinks',
#  'Coheed and Cambria',
#  'Cole Swindell',
#  'Colorblind',
#  'Colton Dixon',
#  'Comandante Twin',
#  'Conchita',
#  'Corina Smith',
#  'Courtney Barnett',
#  'Crazy P',
#  'Cris Mj',
#  'Crisix',
#  'Crowder',
#  'Cyclo',
#  'DARKSIDE',
#  'DECO*27',
#  'DEKKO',
#  'DENM',
#  'DICE',
#  'DJ Koze',
#  'DJ Tennis',
#  'DJs Pareja',
#  'DREAMERS',
#  'Daddy Yankee',
#  'Dalex',
#  'Dan Bremnes',
#  'Dani Fernández',
#  'Dani Martín',
#  'Daniel Avery',
#  'Daniel Barenboim',
#  'Daniel Zueras',
#  'Danny Gokey',
#  'Danny Ocean',
#  'Dante',
#  'Danza Invisible',
#  'Daphni',
#  'Dardust',
#  'Darell',
#  'Dark Moor',
#  'Daughtry',
#  'Dauwd',
#  'David Bisbal',
#  'David Cordero',
#  'David Otero',
#  'Dayglow',
#  'De La Ghetto',
#  'De La Rose',
#  'DePol',
#  'Dead Poet Society',
#  'Death Cab for Cutie',
#  'Decai',
#  'Dei V',
#  'Delaossa',
#  'Delta Sleep',
#  'Denom',
#  'Depeche Mode',
#  'Depresión Sonora',
#  'Diego Martín',
#  'Digitalism',
#  'Dillon Carmichael',
#  'Dirty Heads',
#  'Disney',
#  'Dok & Martin',
#  'Dollar Selmouni',
#  'Dominic Fike',
#  'Don Omar',
#  'Dorothy',
#  'Drake White',
#  'Drew Parker',
#  'Droow',
#  'Drugdealer',
#  'Dua Lipa',
#  'Duki',
#  'Duo Multicorde',
#  'Duran Duran',
#  'Dustin Lynch',
#  'Dvicio',
#  'Dylan Schneider',
#  'Dylan Scott',
#  'Dímelo Flow',
#  'E.VAX',
#  'ELVIS (Original Motion Picture Soundtrack)',
#  'ELYELLA',
#  'Edu Imbernon',
#  'Edu Linares',
#  'Edurne',
#  'Efecto Pasillo',
#  'El Alfa',
#  'El Arrebato',
#  'El Barrio',
#  'El Chojin',
#  'El Clooy',
#  'Eladio Carrion',
#  'Ele A El Dominio',
#  'Elefantes',
#  'Elena Ortega',
#  'Eli Young Band',
#  'Ella Baila Sola',
#  'Elle King',
#  'Elton John',
#  'Elvis Presley',
#  'Emisound',
#  'Esteman',
#  'Estopa',
#  'Eve',
#  'Exxasens',
#  'F.S.Blumm',
#  'FERNANDOCOSTA',
#  'Faithless',
#  'Fallen Roses',
#  'Fangoria',
#  'Fantastic Negrito',
#  'Farruko',
#  'Father John Misty',
#  'Fatima Hajji',
#  'Federico Mompou',
#  'Feid',
#  'Fever Ray',
#  'Fit For A King',
#  'Fito y Fitipaldis',
#  'Fleet Foxes',
#  'Floating Points',
#  'Florence + The Machine',
#  'Florida Georgia Line',
#  'Flying Lotus',
#  'Fondo Flamenco',
#  'Fontaines D.C.',
#  'Foo Fighters',
#  'Foreign Teck',
#  'Fortunate Youth',
#  'Four Tet',
#  'Foyone',
#  'Francesca Battistelli',
#  'Francisco Tárrega',
#  'Friday Pilots Club',
#  'Fruit Bats',
#  'Fuego',
#  'Fuel Fandango',
#  'Funambulista',
#  'Fyahbwoy',
#  'Gabriel Dominguez',
#  'Generación 12',
#  'Genio Producer',
#  'Gente De Zona',
#  'George FitzGerald',
#  'Georgie Dann',
#  'Ghost',
#  'Gidge',
#  'Glass Animals',
#  'Global Underground',
#  'Gold Panda',
#  'Good Morning',
#  'Goodbye June',
#  'Gorillaz',
#  'Gospel of Dance',
#  'Goth Babe',
#  'Greeicy',
#  'Green Valley',
#  'Greta Van Fleet',
#  'Groove Armada',
#  'Guaynaa',
#  'Guitarricadelafuente',
#  "Guns N' Roses",
#  'GusGus',
#  'Guts',
#  'HARRY WAS HERE',
#  'HEALTH',
#  'HVOB',
#  'Hadadanza',
#  'Hades66',
#  'Hannah Murphy',
#  'Hanzel La H',
#  'Hard GZ',
#  'Hector Rios Vnzl',
#  'Heitor Pereira',
#  'Henry Mendez',
#  'Hercules & Love Affair',
#  'Heroes Del Silencio',
#  'Highly Suspect',
#  'Hilary Hahn',
#  'Hippo Campus',
#  'Hiss Golden Messenger',
#  'Hoke',
#  'Hollywood Undead',
#  'Hombres G',
#  'HoneyWorks',
#  'Hooverphonic',
#  'Hot Chip',
#  'Houndmouth',
#  'House Of Pain',
#  'Hozier',
#  'I AM THEY',
#  'IDLES',
#  'IZAL',
#  'Ill Pekeño',
#  'Imagine Dragons',
#  'India Martinez',
#  'Inner Wave',
#  'Insane Clown Posse',
#  'Iration',
#  'Iron Maiden',
#  'Isaac Albéniz',
#  'Israel B',
#  'J Abdiel',
#  'J Alvarez',
#  'J Balvin',
#  'JHAYCO',
#  'JOLLY (PE)',
#  'Jacques Greene',
#  'James McMurtry',
#  'Jameson Rodgers',
#  'Jamie xx',
#  'Jane Remover',
#  'Janine Jansen',
#  'Japanese Breakfast',
#  'Jasmon',
#  'Jason Aldean',
#  'Jason Kolàr',
#  'Javiera Mena',
#  'Javiielo',
#  'Jay Menez',
#  'Jay Wheeler',
#  'Jeff Danna',
#  'Jefferson Airplane',
#  'Jens Buchert',
#  'Jeremy Camp',
#  'Jerry Di',
#  'Jerry Lee Lewis',
#  'Jesse Roper',
#  'Jesús Adrián Romero',
#  'Jimmie Allen',
#  'Jimmix',
#  'Joaquín Sabina',
#  'Joaquín Turina',
#  'Joe Goddard',
#  'Joey Valence & Brae',
#  'John Debney',
#  'John Fulford Music',
#  'John Hiatt',
#  'Jon Hopkins',
#  'Jon Pardi',
#  'Jon Z',
#  'Josiah and the Bonnevilles',
#  'Jossef',
#  'Jotaerre',
#  'Journey',
#  'Jowell & Randy',
#  'Joy Orbison',
#  'Joyce Santana',
#  'Juan Magán',
#  'Juan del Encina',
#  'Juana Molina',
#  'Juhn',
#  'Justice',
#  'Justin Quiles',
#  'K.Flay',
#  'KALEO',
#  'KANA-BOON',
#  'KAROL G',
#  'KHEA',
#  'KLANGSTEIN',
#  'Kairikibear',
#  'Karbeats',
#  'Kase.O',
#  'Kaze',
#  'Khaled',
#  'Kidd Keo',
#  'Kiko y Shara',
#  'King Clave',
#  'Kings of Leon',
#  'Kip Moore',
#  'Kixnare',
#  'Kodak Black',
#  'Korn',
#  'Kovács Beatrix',
#  'LCD Soundsystem',
#  'LEGEND EFFECT',
#  'LIT killah',
#  'LOUTA',
#  'La Bien Querida',
#  'La Casa Azul',
#  'La Culpa',
#  'La La Love You',
#  'La Maravillosa Orquesta del Alcohol',
#  'La Oreja de Van Gogh',
#  'La Paloma',
#  'La Pegatina',
#  'Ladilla Rusa',
#  'Lady Gaga',
#  'Ladytron',
#  'Lake Street Dive',
#  'Lasai',
#  'Lauren Daigle',
#  'Lee Brice',
#  'Leiva',
#  'Lenny Tavárez',
#  'Leon Vynehall',
#  'Lepoka',
#  'Level 42',
#  'Limp Bizkit',
#  'Little Dragon',
#  'Little Stranger',
#  'Locus',
#  'Logan Mize',
#  'Lola Indigo',
#  'Lone Ark',
#  'Lorenzo Soria',
#  'Lori Meyers',
#  'Los Angeles Negros',
#  'Los Bravos',
#  'Los Fabulosos Cadillacs',
#  'Los Rebujitos',
#  'Love of Lesbian',
#  'Luar La L',
#  'Luke Bryan',
#  'Luna Li',
#  'Lunay',
#  'Lyanno',
#  'Lytos',
#  'Lérica',
#  'MAN WITH A MISSION',
#  'MARLENA',
#  'MASS OF THE FERMENTING DREGS',
#  'MJ Lenderman',
#  'MORVN',
#  'Mac Powell',
#  'Maga',
#  'Maki',
#  'Maluma',
#  'Malú',
#  'Mammoth WVH',
#  'Manchester Orchestra',
#  'Mano Le Tough',
#  'Manu Dia',
#  'Manu Manzo',
#  'Manuel Barrueco',
#  'Manuel Carrasco',
#  'Manuel Turizo',
#  'Manybeat',
#  'Maná',
#  'Marc Seguí',
#  'Marco Tegui',
#  'Marcus King',
#  'Marea',
#  'Maretu',
#  'Maria Becerra',
#  'Marlon',
#  'Mastodon',
#  'Maston',
#  'Matt Maher',
#  'Matthew West',
#  'Mau y Ricky',
#  'Max Cooper',
#  'Megadeth',
#  'Melendi',
#  'MercyMe',
#  'Meredith Andrews',
#  'Metallica',
#  'Metronomy',
#  'Micah Tyler',
#  'Michael Ray',
#  'Micro TDH',
#  'Midrift',
#  'Miguel Bastida',
#  'Mihali',
#  'Mike Bahía',
#  'Mikel Erentxun',
#  'Miky Woodz',
#  'Milky Chance',
#  'Milly',
#  'Milo j',
#  'Miranda!',
#  'Miss Kittin',
#  'Mistah Godeh',
#  'Mitchell Tenpenny',
#  'Moby',
#  'Moderat',
#  'Modeselektor',
#  'Mogwai',
#  'Momma',
#  'Monica Naranjo',
#  'Mora',
#  'Morcheeba',
#  'Morphium',
#  'Mother Mother',
#  'Motörhead',
#  'Mount Kimbie',
#  'Mujeres',
#  'Muse',
#  'My Chemical Romance',
#  'Myke Towers',
#  'MËSTIZA',
#  'Mägo de Oz',
#  'Måneskin',
#  'NATTI NATASHA',
#  'NEEDTOBREATHE',
#  'Nach',
#  'Natalia Jiménez',
#  'Natalia Lafourcade',
#  'Natalie Grant',
#  'Nathaniel Rateliff & The Night Sweats',
#  'Natos y Waor',
#  'Neutro Shorty',
#  'Newsboys',
#  'Nickelback',
#  'Nicki Nicole',
#  'Nicky Jam',
#  'Nightmares On Wax',
#  'Nikone',
#  'Nil Moliner',
#  'Nils Frahm',
#  'Nio Garcia',
#  'Nirvana',
#  'Niña Polaca',
#  'Niño de Elche',
#  'No Vacation',
#  'Noah Gundersen',
#  'Noriel',
#  'Nosaj Thing',
#  'Nueen',
#  'Nunatak',
#  'Nylonwings',
#  'Nyno Vargas',
#  'OFFICIAL HIGE DANDISM',
#  'ONE OK ROCK',
#  'OTA El Hipopotamo',
#  'Ocer y Rade',
#  'Of Monsters and Men',
#  'Old Dominion',
#  'Old Mervs',
#  'Olivia Newton-John',
#  'Omar Courtz',
#  'Omy de Oro',
#  'OneRepublic',
#  'Opera Magna',
#  'Orbital',
#  'Original Juan',
#  'Ovi',
#  'Ovy On The Drums',
#  'Ozuna',
#  'Ozzy Osbourne',
#  'P.A.F.F.',
#  'PELICAN FANCLUB',
#  'Pablo Alborán',
#  'Pablo Ferrandez',
#  'Pablo López',
#  'Pablo Say',
#  'Pablo de Sarasate',
#  'Pacho El Antifeka',
#  'Pacific Roots',
#  'Pailita',
#  'Palace',
#  'Palaye Royale',
#  'Papa Roach',
#  'Papi Sousa',
#  'Parmalee',
#  'Passafire',
#  'Paul Kalkbrenner',
#  'Paul McCartney',
#  'Paula Mattheus',
#  'Paulo Londra',
#  'Peces Raros',
#  'Pejzaż',
#  'Pequeño Pez',
#  'Petey',
#  'Phil Wickham',
#  'Phoenix',
#  'Pig&Dan',
#  'PinocchioP',
#  'Piso 21',
#  'Pixies',
#  'Plaid',
#  'Pol 3.14',
#  'Pol Granch',
#  'Pole.',
#  'Polyphia',
#  'Populous',
#  'Porta',
#  'Portico Quartet',
#  'Portugal. The Man',
#  'Prince Royce',
#  'Proyecto Gomez Casa',
#  'Pusho',
#  'Quantic',
#  'Quarters of Change',
#  'Queen',
#  'Quevedo',
#  'RADWIMPS',
#  'ROA',
#  'RYSY',
#  'Rachael Lampa',
#  'Radiohead',
#  'Rafa Espino',
#  'Rammstein',
#  'Randy',
#  'Rapsusklei',
#  'Rata Negra',
#  'Rauw Alejandro',
#  'Rawayana',
#  'Ray MD',
#  'Rayden',
#  'Rebecca St. James',
#  'Rebelution',
#  'Recondite',
#  'Recycled J',
#  'Red Hot Chili Peppers',
#  'RedHook',
#  'Reik',
#  'Rels B',
#  'Rend Collective',
#  'Reykjavik606',
#  'Reykon',
#  'Rhett Walker',
#  'Rhye',
#  'Richy Mitch & The Coal Miners',
#  'Rigoberta Bandini',
#  'Rise Against',
#  'Rival Consoles',
#  'Rob Zombie',
#  'Robert Plant',
#  'Rochy RD',
#  'Rojo',
#  'Rokero',
#  'Romare',
#  'Romeo Santos',
#  'Rone',
#  'Rosalie.',
#  'Rosario',
#  'Ross from Friends',
#  'Royal Blood',
#  'Royel Otis',
#  'Rozalén',
#  'Russell Dickerson',
#  'Rvfv',
#  'Rvssian',
#  'Ryan Castro',
#  'Ryan Hurd',
#  'Ryan Stevenson',
#  'Róisín Murphy',
#  'Röyksopp',
#  'SAIKO',
#  'SBTRKT',
#  'STARSET',
#  'SWIT EME',
#  'Saint Motel',
#  'Salduie',
#  'Sam Fender',
#  'Sam Hunt',
#  'Sanctus Real',
#  'Santana',
#  'Saratoga',
#  'Saurom',
#  'Scotty McCreery',
#  'Sebastian Yatra',
#  'Sech',
#  'Sergio Contreras',
#  'Sergio Dalma',
#  'Sexy Zebras',
#  'Shaila Dúrcal',
#  'Shane & Shane',
#  'Sharif',
#  'Sharon Van Etten',
#  'Shinova',
#  'Shinsei Kamattechan',
#  'Sho-Hai',
#  'Shotta',
#  'Shé',
#  'Siddhartha',
#  'Siggy',
#  'Sigur Rós',
#  'Siloé',
#  'Simple Plan',
#  'Ska-P',
#  'Skalpel',
#  'Skillet',
#  'Skylar Grey',
#  'Slayter',
#  'Slipknot',
#  'Sneaker Pimps',
#  'Sniper Gang',
#  'Soccer Mommy',
#  'Sofia Ellar',
#  'Soge Culebra',
#  'Sohodolls',
#  'Soleá Morente',
#  'Sophie Powers',
#  'Soraya',
#  'Spacey Jane',
#  'Spoon',
#  'St Germain',
#  'Stars Go Dim',
#  'Stephen Bishop',
#  'Stick Figure',
#  'Sufjan Stevens',
#  'SunKissed Lola',
#  'Sunday Noise',
#  'Surfer Girl',
#  'Suso Saiz',
#  'Synlakross',
#  'Sébastien Tellier',
#  'Sôber',
#  'THE DRIVER ERA',
#  'TK from Ling tosite sigure',
#  'TOOL',
#  'Taburete',
#  'Tainy',
#  'Talisto',
#  'Tamara',
#  'Tame Impala',
#  'Tauren Wells',
#  'Tedeschi Trucks Band',
#  'Tempo',
#  'The 1975',
#  'The Beths',
#  'The Black Keys',
#  'The Blue Stones',
#  'The Bones of J.R. Jones',
#  'The Chemical Brothers',
#  'The Crystal Method',
#  'The Del-Vikings',
#  'The Elovaters',
#  'The Ghost Club',
#  'The Goo Goo Dolls',
#  'The Green',
#  'The Happy Fits',
#  'The Hip Abduction',
#  'The Killers',
#  'The Knife',
#  'The Lumineers',
#  'The Movement',
#  'The Neighbourhood',
#  'The Offspring',
#  'The Poles',
#  'The Red Pears',
#  'The Rolling Stones',
#  'The Rudeboyz',
#  'The Score',
#  'The Struts',
#  'The Unlikely Candidates',
#  'The War On Drugs',
#  'The White Stripes',
#  'The Who',
#  'The Wombats',
#  'Thom Yorke',
#  'Thomas Rhett',
#  'Three Days Grace',
#  'Tiago PZK',
#  'Tierra Santa',
#  'Tiga',
#  'TobyMac',
#  'Toda la Vida',
#  'Tom Morello',
#  'Tom Petty and the Heartbreakers',
#  'Tommy James & The Shondells',
#  'Tony Guerra',
#  'Toro',
#  'Tosca',
#  'Totally Enormous Extinct Dinosaurs',
#  'ToteKing',
#  'Toundra',
#  'Travis Denning',
#  'Tregua',
#  'Tricky',
#  'Tropidelic',
#  'Trueno',
#  'Twenty One Pilots',
#  'Two Feet',
#  'Tycho',
#  'Tyler Booth',
#  'Tyler Rich',
#  'Télépopmusik',
#  'UNISON SQUARE GARDEN',
#  'UNKLE',
#  'Ulrich Schnauss',
#  'Underworld',
#  'Valeria Castro',
#  'Vana Liya',
#  'Vance Joy',
#  'Vanesa Martín',
#  'Various Artists',
#  'Veintiuno',
#  'Vendex',
#  'Vetusta Morla',
#  'Victor Porfidio',
#  'Vitalic',
#  'Viuda',
#  'Viva Suecia',
#  'Volbeat',
#  'Vulfpeck',
#  'Walker Hayes',
#  'Warcry',
#  'Warmth',
#  'Warpaint',
#  'Wax Tailor',
#  'We Are Messengers',
#  'We Came As Romans',
#  'Weezer',
#  'Wet Leg',
#  'Weval',
#  'Whiskey Myers',
#  'WhoMadeWho',
#  'Wild Honey',
#  'Will C',
#  'Wine Lips',
#  'Wisin',
#  'Wisin & Yandel',
#  'Wolf Alice',
#  'YONAKA',
#  'YOVNGCHIMI',
#  'YUNGBLUD',
#  'Yakamoto Kotzuga',
#  'Yamila',
#  'Yampi',
#  'Yan Block',
#  'Yandel',
#  'Yeah Yeah Yeahs',
#  'Yeruza',
#  'Young Miko',
#  'Young the Giant',
#  'Yunchan Lim',
#  'Yung Beef',
#  'Zac Brown Band',
#  'Zahara',
#  'Zaidbreak',
#  'Zero 7',
#  'Zetazen',
#  'Zion & Lennox',
#  'Zoé',
#  'alt-J',
#  'black midi',
#  'coldrain',
#  'feeble little horse',
#  'for KING & COUNTRY',
#  'from',
#  'grandson',
#  'if i die in mississippi',
#  'ivri',
#  'lovelytheband',
#  'quannnic',
#  'trentemøller',
#  'vf7',
#  'Álvaro De Luna',
#  'Âme',
#  'Ñejo',
#  'Ñengo Flow',
#  '✝✝✝ (Crosses)',
#  '花冷え。'}

# %%
list_artistas = list(set_artist)
len(list_artistas)
# Out:
# 899

# %%
list_artistas
# Out:
# ['Clara Cava',
#  'KAROL G',
#  'The Black Keys',
#  'Jon Z',
#  'Esteman',
#  'PinocchioP',
#  'MORVN',
#  'Vetusta Morla',
#  'Sigur Rós',
#  'Ozzy Osbourne',
#  'Zion & Lennox',
#  'Accion Sanchez',
#  'if i die in mississippi',
#  'Original Juan',
#  'Carlos Sadness',
#  'Simple Plan',
#  'La Pegatina',
#  'The Elovaters',
#  'Arcy Drive',
#  'Rafa Espino',
#  'Three Days Grace',
#  'The Beths',
#  'Tyler Booth',
#  'PELICAN FANCLUB',
#  'Javiielo',
#  'La La Love You',
#  'Twenty One Pilots',
#  'Recycled J',
#  'Maretu',
#  'lovelytheband',
#  'Darell',
#  'Lone Ark',
#  'Skillet',
#  'Dvicio',
#  'Max Cooper',
#  'Manybeat',
#  'Angela Hewitt',
#  'Recondite',
#  'Fontaines D.C.',
#  'Burial',
#  'Emisound',
#  'Tiago PZK',
#  'Heroes Del Silencio',
#  'Sergio Dalma',
#  'MAN WITH A MISSION',
#  'Andrés Suárez',
#  'Moby',
#  'Efecto Pasillo',
#  'Juan del Encina',
#  'Tom Morello',
#  'Scotty McCreery',
#  'Alex Rose',
#  'Jason Kolàr',
#  'Leiva',
#  'Zoé',
#  'feeble little horse',
#  'Amarion',
#  'Spoon',
#  'The Offspring',
#  'Walker Hayes',
#  'Ray MD',
#  'Alice Wonder',
#  'Iron Maiden',
#  'Eli Young Band',
#  'Rosario',
#  'Shotta',
#  'Wet Leg',
#  'Old Dominion',
#  'Rhye',
#  'Lady Gaga',
#  'Bala',
#  'Insane Clown Posse',
#  'Bear McCreary',
#  'Rhett Walker',
#  'DICE',
#  'Brandon Heath',
#  'Sofia Ellar',
#  'Tosca',
#  'Kaze',
#  'Nathaniel Rateliff & The Night Sweats',
#  'Matthew West',
#  'Pailita',
#  'Danza Invisible',
#  'Suso Saiz',
#  'John Fulford Music',
#  'DECO*27',
#  'Rawayana',
#  'Mogwai',
#  'Duki',
#  'Wild Honey',
#  'Drew Parker',
#  'Jowell & Randy',
#  'The Chemical Brothers',
#  'Hozier',
#  'Nunatak',
#  'Niña Polaca',
#  'Royel Otis',
#  'Rauw Alejandro',
#  'Orbital',
#  'Edurne',
#  'Cody Jinks',
#  'Palace',
#  'MASS OF THE FERMENTING DREGS',
#  'Toda la Vida',
#  'Don Omar',
#  'Basement Jaxx',
#  'Love of Lesbian',
#  'Brray',
#  'Viva Suecia',
#  'Good Morning',
#  'Locus',
#  'Jens Buchert',
#  'Droow',
#  'Imagine Dragons',
#  'Russell Dickerson',
#  'KANA-BOON',
#  'TK from Ling tosite sigure',
#  'La Oreja de Van Gogh',
#  'from',
#  'Quevedo',
#  'Peces Raros',
#  'Edu Imbernon',
#  'Sneaker Pimps',
#  'Lorenzo Soria',
#  'The Killers',
#  'Zahara',
#  'Los Angeles Negros',
#  'Goodbye June',
#  'Manuel Barrueco',
#  'Quantic',
#  'Little Dragon',
#  'Vulfpeck',
#  'P.A.F.F.',
#  'Francisco Tárrega',
#  'Populous',
#  'Salduie',
#  'Lori Meyers',
#  'Blake',
#  'Santana',
#  'Nicky Jam',
#  'Florida Georgia Line',
#  'Delta Sleep',
#  'Bring Me The Horizon',
#  'Âme',
#  'Azucar Moreno',
#  'Japanese Breakfast',
#  'Omy de Oro',
#  'Houndmouth',
#  'Rachael Lampa',
#  'Warpaint',
#  'Joyce Santana',
#  'Pablo de Sarasate',
#  'Maston',
#  'Miranda!',
#  'Mikel Erentxun',
#  'Saratoga',
#  'The Happy Fits',
#  'Alvvays',
#  'Rayden',
#  'Nils Frahm',
#  'Tiga',
#  'The Crystal Method',
#  'coldrain',
#  'Colorblind',
#  'Adam Jensen',
#  'Tauren Wells',
#  'Dirty Heads',
#  'Veintiuno',
#  'David Cordero',
#  'Lake Street Dive',
#  'Sharif',
#  'We Came As Romans',
#  'Daddy Yankee',
#  'Belén Aguilera',
#  'KLANGSTEIN',
#  'ELYELLA',
#  'Juan Magán',
#  'Hades66',
#  'Ayax y Prok',
#  'Miguel Bastida',
#  'Beéle',
#  'Piso 21',
#  'DJ Tennis',
#  'Tricky',
#  'Crisix',
#  'NATTI NATASHA',
#  'Sunday Noise',
#  'Petey',
#  'Modeselektor',
#  'Jossef',
#  'Yan Block',
#  'Chandler Moore',
#  'Various Artists',
#  'Black Label Society',
#  'Gente De Zona',
#  'Motörhead',
#  'Bizarrap',
#  'Tropidelic',
#  'OFFICIAL HIGE DANDISM',
#  'Dylan Scott',
#  'Rosalie.',
#  'Pablo Ferrandez',
#  'Jon Pardi',
#  'Dustin Lynch',
#  'Stephen Bishop',
#  'Floating Points',
#  'Elton John',
#  'Lauren Daigle',
#  'Ryan Hurd',
#  'Dani Martín',
#  'Mujeres',
#  'Hollywood Undead',
#  'Rise Against',
#  'Rvfv',
#  'Babasonicos',
#  'Fever Ray',
#  'Brett Eldredge',
#  'Pol 3.14',
#  'Nickelback',
#  'Tony Guerra',
#  'Joey Valence & Brae',
#  'Bryce Fox',
#  'Sôber',
#  'Metronomy',
#  'El Clooy',
#  'Bonobo',
#  'Becky G',
#  'Paula Mattheus',
#  'Amenazzy',
#  'Kase.O',
#  'Stars Go Dim',
#  'Daniel Avery',
#  'Myke Towers',
#  'Daphni',
#  'FERNANDOCOSTA',
#  'Sophie Powers',
#  'Brittany Howard',
#  'Bryant Myers',
#  'Mau y Ricky',
#  'Andrés Madariaga',
#  'Delaossa',
#  'El Alfa',
#  'Bejo',
#  'Milo j',
#  'The Bones of J.R. Jones',
#  'Broken Lip',
#  'Blanco Palamera',
#  'Sexy Zebras',
#  'Skylar Grey',
#  'IZAL',
#  'Dei V',
#  'Noriel',
#  'Télépopmusik',
#  'La Culpa',
#  'Ghost',
#  'The Wombats',
#  'Shaila Dúrcal',
#  'Papi Sousa',
#  'Father John Misty',
#  'Richy Mitch & The Coal Miners',
#  'Comandante Twin',
#  'Weezer',
#  'Fit For A King',
#  'City of the Sun',
#  'John Hiatt',
#  'Elena Ortega',
#  'Vana Liya',
#  'Jasmon',
#  'Porta',
#  'Yeruza',
#  'Surfer Girl',
#  'Manuel Turizo',
#  'Ankor',
#  'Mike Bahía',
#  'Whiskey Myers',
#  'Alex G',
#  'Glass Animals',
#  'Little Stranger',
#  'HEALTH',
#  'Joaquín Sabina',
#  'Pejzaż',
#  'Soccer Mommy',
#  'Arnau Griso',
#  'TobyMac',
#  'Soleá Morente',
#  'Karbeats',
#  'Air',
#  'Rob Zombie',
#  'Cole Swindell',
#  'Malú',
#  'Zac Brown Band',
#  'J Abdiel',
#  'Elle King',
#  'Jesús Adrián Romero',
#  'Fondo Flamenco',
#  'George FitzGerald',
#  'Dauwd',
#  'Pablo Alborán',
#  'Abraham Mateo',
#  'Hadadanza',
#  'Spacey Jane',
#  'Foo Fighters',
#  'Siloé',
#  'Siddhartha',
#  'K.Flay',
#  'I AM THEY',
#  'Israel B',
#  'alt-J',
#  'Almighty',
#  'Cecilia Krull',
#  'Danny Gokey',
#  'Hooverphonic',
#  'Crowder',
#  'Farruko',
#  'Lérica',
#  'Fallen Roses',
#  'Zero 7',
#  'Ele A El Dominio',
#  'HoneyWorks',
#  'My Chemical Romance',
#  'Chenoa',
#  'Groove Armada',
#  'Ñejo',
#  'Trueno',
#  'Chencho Corleone',
#  'Vanesa Martín',
#  'Anuel AA',
#  'Marlon',
#  'Calero LDN',
#  'Ana Mena',
#  'Dardust',
#  'Rata Negra',
#  'Aitana',
#  'Romeo Santos',
#  'Taburete',
#  'CA7RIEL',
#  'Arrested Youth',
#  'The Who',
#  'Dan Bremnes',
#  'Depeche Mode',
#  'Duo Multicorde',
#  'Pablo López',
#  'Dante',
#  'Andy Rivera',
#  'Caribou',
#  'Nirvana',
#  'Rigoberta Bandini',
#  'Angelus Apatrida',
#  'Travis Denning',
#  'Natalia Jiménez',
#  'Rival Consoles',
#  'Ryan Stevenson',
#  'Denom',
#  'Khaled',
#  'LCD Soundsystem',
#  'Four Tet',
#  'Elvis Presley',
#  'The Neighbourhood',
#  'Sébastien Tellier',
#  'Ocer y Rade',
#  'Guts',
#  'Los Bravos',
#  'Dillon Carmichael',
#  'Papa Roach',
#  'Fyahbwoy',
#  'Heitor Pereira',
#  'Federico Mompou',
#  'James McMurtry',
#  'Ozuna',
#  'Ella Baila Sola',
#  'We Are Messengers',
#  'Thomas Rhett',
#  'DJ Koze',
#  'Dorothy',
#  'Javiera Mena',
#  'KHEA',
#  'Parmalee',
#  'Aldo Cadiz',
#  'Badflower',
#  'HARRY WAS HERE',
#  'Róisín Murphy',
#  'Big Thief',
#  'No Vacation',
#  'Kings of Leon',
#  'Dua Lipa',
#  'Carlos Baute',
#  'Arctic Monkeys',
#  'KALEO',
#  'Antonio José',
#  'Sohodolls',
#  'Tom Petty and the Heartbreakers',
#  'Fantastic Negrito',
#  'Crazy P',
#  'Manu Dia',
#  'Exxasens',
#  'Yakamoto Kotzuga',
#  'La Paloma',
#  'Daniel Zueras',
#  'Dayglow',
#  'ROA',
#  'Mammoth WVH',
#  'Jameson Rodgers',
#  'Maluma',
#  'Maga',
#  'Fortunate Youth',
#  'Midrift',
#  'SWIT EME',
#  'Noah Gundersen',
#  'Cerebral Effusion',
#  'Cyclo',
#  'Highly Suspect',
#  'Thom Yorke',
#  'Jon Hopkins',
#  'Melendi',
#  'Band of Horses',
#  'Bad Suns',
#  'Mitchell Tenpenny',
#  'The Movement',
#  'Gabriel Dominguez',
#  'Niño de Elche',
#  'LIT killah',
#  'Gorillaz',
#  'Funambulista',
#  'Jimmie Allen',
#  'Hercules & Love Affair',
#  'Café Quijano',
#  'Ben Rector',
#  'Pusho',
#  'Leon Vynehall',
#  'Hippo Campus',
#  'Alberto Dimeo',
#  'Paulo Londra',
#  'Anıl Emre Daldal',
#  'NEEDTOBREATHE',
#  'Paul Kalkbrenner',
#  'The Hip Abduction',
#  'Bomba Estéreo',
#  'Digitalism',
#  'Ladilla Rusa',
#  'Rozalén',
#  'Shinova',
#  'Ovi',
#  'Tommy James & The Shondells',
#  'Ak4:20',
#  'Miss Kittin',
#  'Adventus',
#  'YUNGBLUD',
#  'Amistades Peligrosas',
#  'Josiah and the Bonnevilles',
#  'Chris Jedi',
#  'Marc Seguí',
#  'La Maravillosa Orquesta del Alcohol',
#  'UNKLE',
#  'Newsboys',
#  'Ñengo Flow',
#  'Blas Cantó',
#  'BICEP',
#  'Passafire',
#  'Moderat',
#  'black midi',
#  'MJ Lenderman',
#  'The Struts',
#  'Iration',
#  'trentemøller',
#  'The Unlikely Candidates',
#  'Of Monsters and Men',
#  'El Barrio',
#  'Saint Motel',
#  'Kairikibear',
#  'Reik',
#  'Jesse Roper',
#  'Vance Joy',
#  'Guitarricadelafuente',
#  'Pole.',
#  'LOUTA',
#  'MËSTIZA',
#  'Álvaro De Luna',
#  'Bombai',
#  'The Red Pears',
#  'Joy Orbison',
#  'HVOB',
#  'Beret',
#  'Sufjan Stevens',
#  'All Time Low',
#  'Kixnare',
#  'Casting Crowns',
#  'Andy Frasco & The U.N.',
#  'The Knife',
#  'Arce',
#  'Micah Tyler',
#  'Quarters of Change',
#  'GusGus',
#  'J Balvin',
#  'Chanell',
#  'Dominic Fike',
#  'Axel Boman',
#  'The War On Drugs',
#  'Rojo',
#  'Yandel',
#  'Arcane',
#  'ELVIS (Original Motion Picture Soundtrack)',
#  'Foreign Teck',
#  'Celtian',
#  'Reykon',
#  'Totally Enormous Extinct Dinosaurs',
#  'WhoMadeWho',
#  'AMBKOR',
#  'Mac Powell',
#  'Camilo',
#  'Kodak Black',
#  'Paul McCartney',
#  'Metallica',
#  'Jefferson Airplane',
#  'Eve',
#  'Korn',
#  'Courtney Barnett',
#  'Booka Shade',
#  'Carlos Herrera Music',
#  'Alex Gargolas',
#  'Kidd Keo',
#  'Lasai',
#  'Jay Wheeler',
#  'Sam Fender',
#  'Maria Becerra',
#  'CNCO',
#  'Sharon Van Etten',
#  'Soraya',
#  'Sniper Gang',
#  'Romare',
#  'Georgie Dann',
#  'The White Stripes',
#  'Generación 12',
#  'Morcheeba',
#  'Art Lown',
#  'Young the Giant',
#  'Greeicy',
#  'Conchita',
#  'Phil Wickham',
#  'Foyone',
#  'Disney',
#  'Olivia Newton-John',
#  'Gospel of Dance',
#  'Billy Idol',
#  'Synlakross',
#  'Jane Remover',
#  'Matt Maher',
#  'Zetazen',
#  'Janine Jansen',
#  'Maná',
#  'Juhn',
#  'Natos y Waor',
#  'Toundra',
#  'Anubiis',
#  'El Chojin',
#  'Two Feet',
#  'Blockhead',
#  'LEGEND EFFECT',
#  'Hannah Murphy',
#  'The Rolling Stones',
#  'Hard GZ',
#  'House Of Pain',
#  'Pixies',
#  'Catalyna',
#  'Pol Granch',
#  'The Lumineers',
#  'Neutro Shorty',
#  'Aleksander Debicz',
#  'Yung Beef',
#  'Jamie xx',
#  'YOVNGCHIMI',
#  'Slipknot',
#  'Hiss Golden Messenger',
#  'Ross from Friends',
#  'Lytos',
#  'Wisin & Yandel',
#  'Mother Mother',
#  'SBTRKT',
#  'Lepoka',
#  'Luke Bryan',
#  'Austin French',
#  'Califato ¾',
#  'Brandi Carlile',
#  'Lunay',
#  'DePol',
#  'Luna Li',
#  'Tedeschi Trucks Band',
#  'Brent Cobb',
#  'Rone',
#  'Coheed and Cambria',
#  'F.S.Blumm',
#  'Gidge',
#  'Jerry Di',
#  'Muse',
#  'Alex Ubago',
#  'Kovács Beatrix',
#  'Greta Van Fleet',
#  'Tame Impala',
#  'Aventura',
#  'Nach',
#  'OneRepublic',
#  'King Clave',
#  'Logan Mize',
#  'The Rudeboyz',
#  'STARSET',
#  'Tycho',
#  'Old Mervs',
#  'Christian Löffler',
#  'Ankhal',
#  'Jacques Greene',
#  'Arcángel',
#  'Duran Duran',
#  'DREAMERS',
#  'Guaynaa',
#  'Röyksopp',
#  'Marcus King',
#  'Genio Producer',
#  'Bleachers',
#  'MercyMe',
#  "Guns N' Roses",
#  'La Casa Azul',
#  'El Arrebato',
#  'Nylonwings',
#  'TOOL',
#  'Beach House',
#  'Milly',
#  'Jeff Danna',
#  'Florence + The Machine',
#  'Band&dos',
#  'Diego Martín',
#  'Morphium',
#  'Victor Porfidio',
#  'Warcry',
#  'Phoenix',
#  'Alejo',
#  'Dímelo Flow',
#  'Radiohead',
#  'Monica Naranjo',
#  'Rammstein',
#  'Mount Kimbie',
#  'Faithless',
#  'DJs Pareja',
#  'Mastodon',
#  'Dollar Selmouni',
#  'grandson',
#  'Nio Garcia',
#  'Los Fabulosos Cadillacs',
#  'Underworld',
#  'David Bisbal',
#  'Sech',
#  'Pacho El Antifeka',
#  'MARLENA',
#  'Omar Courtz',
#  'Marea',
#  'Los Rebujitos',
#  'Rend Collective',
#  'Bad Bunny',
#  'Tierra Santa',
#  'Inner Wave',
#  'JHAYCO',
#  'Justin Quiles',
#  'Chris Lane',
#  'Yunchan Lim',
#  'Kip Moore',
#  'SunKissed Lola',
#  'Limp Bizkit',
#  'The Score',
#  'Alvaro Diaz',
#  'Nightmares On Wax',
#  'Opera Magna',
#  'Fuego',
#  'Elefantes',
#  'Megadeth',
#  'Jimmix',
#  'Ryan Castro',
#  'Måneskin',
#  'Yeah Yeah Yeahs',
#  'Aimer',
#  'De La Rose',
#  'Sebastian Yatra',
#  'Manuel Carrasco',
#  'Black Country, New Road',
#  'ToteKing',
#  'Toro',
#  'Stick Figure',
#  'Cali Y El Dandee',
#  'Jerry Lee Lewis',
#  'Rokero',
#  'Andy Stott',
#  'Hilary Hahn',
#  'Friday Pilots Club',
#  'IDLES',
#  'Slayter',
#  'Maki',
#  'Portugal. The Man',
#  'David Otero',
#  'Artury Pepper',
#  'JOLLY (PE)',
#  'Eladio Carrion',
#  'Death Cab for Cutie',
#  'Rochy RD',
#  'Skalpel',
#  'Casper Magico',
#  'Valeria Castro',
#  'Yampi',
#  'Daniel Barenboim',
#  'Will C',
#  'Warmth',
#  'Yamila',
#  'Daughtry',
#  'UNISON SQUARE GARDEN',
#  'Sergio Contreras',
#  'Reykjavik606',
#  'Fito y Fitipaldis',
#  'Sanctus Real',
#  'Colton Dixon',
#  'Hanzel La H',
#  'Amon Tobin',
#  'Isaac Albéniz',
#  'Arde Bogotá',
#  'Jason Aldean',
#  'Rebelution',
#  'Antonio Orozco',
#  'Manu Manzo',
#  'Polyphia',
#  'Young Miko',
#  'YONAKA',
#  'Hombres G',
#  'Proyecto Gomez Casa',
#  'Tempo',
#  'Rvssian',
#  'Lenny Tavárez',
#  'Jay Menez',
#  'Nil Moliner',
#  'OTA El Hipopotamo',
#  'Wolf Alice',
#  'Chris Tomlin',
#  'Dark Moor',
#  'De La Ghetto',
#  'Red Hot Chili Peppers',
#  'Abäk',
#  'Tyler Rich',
#  'Ska-P',
#  'THE DRIVER ERA',
#  'Volbeat',
#  'for KING & COUNTRY',
#  'Shane & Shane',
#  'Natalie Grant',
#  'Nueen',
#  'Green Valley',
#  'Edu Linares',
#  'Michael Ray',
#  'ONE OK ROCK',
#  'Rebecca St. James',
#  'DEKKO',
#  'Cidergirl',
#  'Global Underground',
#  'La Bien Querida',
#  'Nikone',
#  'Nyno Vargas',
#  'Talisto',
#  'Rels B',
#  'Justice',
#  'Brytiago',
#  'Andrea Sertori',
#  'Randy',
#  'Miky Woodz',
#  'Fuel Fandango',
#  'Weval',
#  'Gold Panda',
#  'Palaye Royale',
#  'Cris Mj',
#  'Milky Chance',
#  'Queen',
#  'RADWIMPS',
#  'Beatriz Luengo',
#  'Tainy',
#  'Saurom',
#  'Bad Gyal',
#  'Henry Mendez',
#  'Brothers Osborne',
#  'Pacific Roots',
#  'Marco Tegui',
#  'DENM',
#  'Angelos',
#  'Chase Rice',
#  'The Blue Stones',
#  'Andy & Lucas',
#  'Journey',
#  'Carolina Durante',
#  'Ill Pekeño',
#  'Joe Goddard',
#  'Fatima Hajji',
#  'Fleet Foxes',
#  'Bee Gees',
#  '花冷え。',
#  'Robert Plant',
#  'Mano Le Tough',
#  'Shinsei Kamattechan',
#  'Lyanno',
#  'Brantley Gilbert',
#  'Wisin',
#  'Sam Hunt',
#  'Wine Lips',
#  'Feid',
#  'BUMP OF CHICKEN',
#  '✝✝✝ (Crosses)',
#  'Pablo Say',
#  'Clap! Clap!',
#  'Vendex',
#  'Bonnie Raitt',
#  'Sho-Hai',
#  'Ulrich Schnauss',
#  'Momma',
#  'Barns Courtney',
#  'Portico Quartet',
#  'Nicki Nicole',
#  'Hoke',
#  'BOUE',
#  'Dead Poet Society',
#  'Chevelle',
#  'Rapsusklei',
#  'Antonio Ruiz Pipó',
#  'Manchester Orchestra',
#  'John Debney',
#  'Mihali',
#  'Mägo de Oz',
#  'Francesca Battistelli',
#  'Tamara',
#  'Decai',
#  'Flying Lotus',
#  'Estopa',
#  'Shé',
#  'The Goo Goo Dolls',
#  'Plaid',
#  'Level 42',
#  'J Alvarez',
#  'The Del-Vikings',
#  'The 1975',
#  'quannnic',
#  'St Germain',
#  'Mistah Godeh',
#  'Prince Royce',
#  'Siggy',
#  'Soge Culebra',
#  'Corina Smith',
#  'Danny Ocean',
#  'Fangoria',
#  'ivri',
#  'Viuda',
#  'Drugdealer',
#  'Blessd',
#  'Kiko y Shara',
#  'Dalex',
#  'Boza',
#  'E.VAX',
#  'Meredith Andrews',
#  'Cazzu',
#  'The Green',
#  'DARKSIDE',
#  'SAIKO',
#  'The Ghost Club',
#  'Lee Brice',
#  'Lola Indigo',
#  'Jeremy Camp',
#  'Clark',
#  'Björk',
#  'Dok & Martin',
#  'vf7',
#  'Zaidbreak',
#  'Nosaj Thing',
#  'Jotaerre',
#  'Dani Fernández',
#  'Juana Molina',
#  'Ovy On The Drums',
#  'Bibio',
#  'Luar La L',
#  'Hector Rios Vnzl',
#  'Vitalic',
#  'Pequeño Pez',
#  'Fruit Bats',
#  'Tregua',
#  'Dylan Schneider',
#  'Wax Tailor',
#  'Royal Blood',
#  'Drake White',
#  'Micro TDH',
#  'Joaquín Turina',
#  'Depresión Sonora',
#  'Goth Babe',
#  'India Martinez',
#  'Amadeüs',
#  'RYSY',
#  'Mora',
#  'Hot Chip',
#  'RedHook',
#  'Natalia Lafourcade',
#  'The Poles',
#  'Pig&Dan',
#  'Ladytron']

# %%
##Corroborar que no haya duplicados: 

if len(list_artistas) != len(set(list_artistas)):
    print("Hay duplicados")
else:
    print("No hay duplicados")

##Si hubiera duplicados: 

dict_artistas['artista'] 

duplicados = set() 
unicos = set() 

for item in dict_artistas['artista']: 
    if item in unicos: 
        duplicados.add(item) 
    else: 
        unicos.add(item) 
        
print("Duplicados encontrados:", list(duplicados))
# Out:
# No hay duplicados

# %% [markdown]
# ## Diccionario final (llamada a la API aprox 20 min)

# %%
 

# Lista de artistas de spotify despues de eliminar duplicados
list_artistas

# Dict donde se almacenara la info de los artistas de la API musicBrainz
dict_artistas = {"artista" : [], "pais_de_origen" : [], "area_de_origen" : [], "fecha_nacimiento" : [], "fecha_inicio_actividad" : [], "fecha_fin_actividad" :[]}

for artista in list_artistas:
    
    # Protegemos posibles errores al hacer la llamada a la URL para cada artista
    try:
        # Construir la URL con el nombre del artista
        url = f"https://musicbrainz.org/ws/2/artist/?query=artist:{artista}&fmt=json"
        # Petición a la API con funcion llamar_api definida anteriormente -> devuelve resultado en JSON
        result = llamar_api(url)
            
        # Comprobamos que en el dict que nos da la URL por cada artista tiene el key artist y que el nombre del primer artista de la lista no esta vacio  
        if result.get("artists") and result["artists"][0].get("name") is not None:
        
            # Cogemos el primer dict de la lista artists porque hemos hecho la hipotesis de que es el mas correcto
            primer_artista_dict = result["artists"][0]    
            
            # Rellenamos el dict general con toda la info de los artistas
            try:
                dict_artistas["artista"].append(primer_artista_dict["name"])
            except KeyError:
                dict_artistas["artista"].append("NULL")
                
            try:
                dict_artistas["pais_de_origen"].append(primer_artista_dict["area"]["name"])
            except KeyError:
                dict_artistas["pais_de_origen"].append("NULL")  
                
            try:
                dict_artistas["area_de_origen"].append(primer_artista_dict["begin-area"]["name"])
            except KeyError:
                dict_artistas["area_de_origen"].append("NULL")  
        
            # Aqui ponemos un get para los casos en los que falte el life-span (que devuelva un diccionario vacio en caso que no esté presente)
           
            try:
                if primer_artista_dict.get("type") == "Person":
                    fecha_nacimiento = primer_artista_dict.get("life-span", {}).get("begin", "NULL")
                    dict_artistas["fecha_nacimiento"].append(fecha_nacimiento)
                    dict_artistas["fecha_inicio_actividad"].append("NULL")
                elif primer_artista_dict.get("type") == "Group":
                    dict_artistas["fecha_nacimiento"].append("NULL")
                    fecha_inicio = primer_artista_dict.get("life-span", {}).get("begin", "NULL")
                    dict_artistas["fecha_inicio_actividad"].append(fecha_inicio)
                else:
                    dict_artistas["fecha_nacimiento"].append("NULL")
                    dict_artistas["fecha_inicio_actividad"].append("NULL")  # Agregar NULL si es otro tipo
            except KeyError:
                dict_artistas["fecha_nacimiento"].append("NULL")
                dict_artistas["fecha_inicio_actividad"].append("NULL")
            
            try:
                if primer_artista_dict["life-span"].get("ended") is not None: #ver que ended este presente
                    if primer_artista_dict["life-span"]["ended"]: #Verificar si ended es True
                        fecha_fin = primer_artista_dict["life-span"].get("end", "No activo") #creamos variable para luego imprimir fecha fin
                        dict_artistas["fecha_fin_actividad"].append(fecha_fin)     
                    else: 
                        dict_artistas["fecha_fin_actividad"].append("Actualidad") 
                else:
                    dict_artistas["fecha_fin_actividad"].append("Actualidad")
            except KeyError:
                dict_artistas["fecha_fin_actividad"].append("NULL")
                         
    except requests.exceptions.RequestException as e:
        # Capturar errores de red (e.g., problemas con la conexión)
        print(f"Error al hacer la solicitud para {artista}: {e}")
    
    except ValueError as e:
        # Capturar errores de JSON (si la respuesta no es JSON válido)
        print(f"Error al procesar la respuesta JSON para {artista}: {e}")
    
    except Exception as e:
        # Capturar cualquier otro tipo de error no esperado
        print(f"Algo salió mal con {artista}: {e}")

    # Pausar de 1 segundos entre cada solicitud para evitar ser bloqueado por la API
    time.sleep(1)
# Out:
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200

# %%
#Comprobamos que las longitudes sean similares: 

for key, value in dict_artistas.items():
    print(f"{key}: {len(value)}")
# Out:
# artista: 891
# pais_de_origen: 891
# area_de_origen: 891
# fecha_nacimiento: 891
# fecha_inicio_actividad: 891
# fecha_fin_actividad: 891

# %% [markdown]
# ## Pasar datos a SQL

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='bd_pruebas')

print(cnx)
cnx.close()
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x0000022092863D10>

# %%
##Creamos zip para luego usarlo como 'val' y poder insertar los datos del diccionario en la tabla de SQL
valores_MB= zip(
    dict_artistas["artista"], dict_artistas["pais_de_origen"],  dict_artistas["area_de_origen"], dict_artistas["fecha_nacimiento"], dict_artistas["fecha_inicio_actividad"], dict_artistas["fecha_fin_actividad"]
)

# %%
## Conección a base de datos: 
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='bd_pruebas') ###Usar esta base de prueba

print(cnx)

mycursor = cnx.cursor()
query = "INSERT INTO musicbrainz (artista_nombre_MB, pais_origen, area_origen, fecha_nacimiento, fecha_inicio_act, fecha_final_act) VALUES (%s, %s, %s, %s, %s, %s)"
val = valores_MB ### aqui inserto ZIP
try: 
    mycursor.executemany(query, val) ### execute many!
    cnx.commit()
    print(mycursor.rowcount, "registro insertado.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x00000220928F7D90>
# 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`bd_pruebas`.`musicbrainz`, CONSTRAINT `fk_mb_spotify` FOREIGN KEY (`artista_nombre_MB`) REFERENCES `spotify` (`artista_nombre_spotify`) ON DELETE CASCADE ON UPDATE CASCADE)
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`bd_pruebas`.`musicbrainz`, CONSTRAINT `fk_mb_spotify` FOREIGN KEY (`artista_nombre_MB`) REFERENCES `spotify` (`artista_nombre_spotify`) ON DELETE CASCADE ON UPDATE CASCADE)

# %%
##Dejo el error de arriba: supongo que es porque necesita que la tabla de spoti esté creada previamente (para referenciar la foreign key)

# %%
dataframe_MB = pd.DataFrame(dict_artistas) 
dataframe_MB

# %%
#Guardar dataframe como csv: 

dataframe_MB.to_csv('../data/dataframe_MB.csv', index=False)

# %% [markdown]
# #Pasar a tabla SQL:

# %%
result_MB[1]
# Out:
# {'artista': 'Skalpel',
#  'pais_de_origen': 'Poland',
#  'area_de_origen': 'NULL',
#  'fecha_nacimiento': 'NULL',
#  'fecha_inicio_actividad': 'NULL',
#  'fecha_fin_actividad': 'Actualidad'}

# %%
XXXXXXX = [(rock_2021_22["nombre_cancion_album"], rock_2021_22 ["artista"],  rock_2021_22["tipo_album_cancion"], rock_2021_22["año_lanzamiento"], rock_2021_22["género"]), (spanish_2021_22["nombre_cancion_album"], spanish_2021_22 ["artista"],  spanish_2021_22["tipo_album_cancion"], spanish_2021_22["año_lanzamiento"], spanish_2021_22["género"])]

cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='XXXXXXX')


mycursor = cnx.cursor()
query = "INSERT INTO diccionario (nombre, genero, año) VALUES (%s, %s, %s)"
val = XXXXXX ### aqui inserto ZIP
try: 
    mycursor.executemany(query, val) ### execute many!
    cnx.commit()
    print(mycursor.rowcount, "registro insertado.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
