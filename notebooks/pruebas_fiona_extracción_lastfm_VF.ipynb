# %%
import requests
import pandas as pd

# %%
#Probando que la llamada funciona.

API_KEY = '357e10dfd8c3d43a08795cbb92a9cf24'
url_base = 'https://ws.audioscrobbler.com/2.0'
params_info = {
        'method': 'artist.getinfo',
        'artist': 'Shakira',
        'api_key': API_KEY,
        'format': 'json'
        }
artista = requests.get(url_base, params=params_info)

# %%
artista
# Out:
# <Response [200]>

# %%
artista_json = artista.json()

# %%
#Explorando json

artista_json
# Out:
# {'artist': {'name': 'Shakira',
#   'mbid': 'bf24ca37-25f4-4e34-9aec-460b94364cfc',
#   'url': 'https://www.last.fm/music/Shakira',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': ''}],
#   'streamable': '0',
#   'ontour': '1',
#   'stats': {'listeners': '4006849', 'playcount': '130265256'},
# ...

# %% [markdown]
# INFOR QUE NOS PIDEN:
#
# Artista.
#
# Biografía del Artista.
#
# Listeners (cantidad de gente que lo escucha).
#
# Playcount (cantidad de veces reproducido su música)
#
# Artistas Similares.

# %%
# Bucle para sacar solo los nombres de los artistas similares, ya que viene más info. 

artista_similares_nombre = []
for artista in artista_json['artist']['similar']['artist']:
    artista_similares_nombre.append(artista['name'])

print(artista_similares_nombre)
# Out:
# ['Paulina Rubio', 'Karol G', 'Belinda', 'Thalía', 'Julieta Venegas']

# %%
import pandas as pd
import requests
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import os
from dotenv import load_dotenv 

import csv
import json

# %%
# Código de Ariana y Maca de MB para extraer el archivo de spoti.

# Paso 1: Leer el archivo CSV
spoti_csv_file = "../data/dataframes_combinados.csv" # nombre de tu archivo Spoti CSV
spoti_json_file = "dataframes_combinados.json"  # nombre del archivo Spoti de salida JSON

# Paso 2: Abrir el CSV y convertir a formato JSON
with open(spoti_csv_file, mode='r', encoding='utf-8') as file:
    # Leer el contenido CSV
    csv_reader = csv.DictReader(file)
    
    # Convertir cada fila a diccionario y agregarla a una lista
    data = [row for row in csv_reader]

# Paso 3: Escribir los datos en un archivo JSON
with open(spoti_json_file, mode='w', encoding='utf-8') as file:
    json.dump(data, file, indent=4)  # Guarda el JSON con formato legible (indent=4)

print(f'Archivo {spoti_json_file} creado con éxito.')
# Out:
# Archivo dataframes_combinados.json creado con éxito.

# %%
#Traemos el archivo a json
with open("dataframes_combinados.json","r") as f: 
    result_spoti = json.load(f)

# %%
result_spoti
# Out:
# [{'nombre_cancion_album': 'Seventeen',
#   'artista': 'Ladytron',
#   'tipo_album_cancion': 'album',
#   'año_lanzamiento': '2022',
#   'género': 'Electrónica'},
#  {'nombre_cancion_album': 'Crust',
#   'artista': 'Flying Lotus',
#   'tipo_album_cancion': 'album',
#   'año_lanzamiento': '2021',
#   'género': 'Electrónica'},
#  {'nombre_cancion_album': 'Abu Simbel',
#   'artista': 'WhoMadeWho',
#   'tipo_album_cancion': 'single',
#   'año_lanzamiento': '2021',
#   'género': 'Electrónica'},
#  {'nombre_cancion_album': 'Apricots',
#   'artista': 'BICEP',
#   'tipo_album_cancion': 'album',
#   'año_lanzamiento': '2021',
#   'género': 'Electrónica'},
#  {'nombre_cancion_album': 'KILL DEM',
#   'artista': 'Jamie xx',
#   'tipo_album_cancion': 'single',
#   'año_lanzamiento': '2022',
#   'género': 'Electrónica'},
#  {'nombre_cancion_album': 'Water',
#   'artista': 'BICEP',
#   'tipo_album_cancion': 'single',
#   'año_lanzamiento': '2022',
#   'género': 'Electrónica'},
# ...

# %%
#Creamos lista vacia para que se complete con los artistas
artist = []

for item in result_spoti: 
    artist.append(item['artista'])

# %%
#Convertimos en set para eliminar artistas duplicados (hay artistas con mas de una canción en el mismo año)
set_artist = set(artist)
set_artist
# Out:
# {'AMBKOR',
#  'Abraham Mateo',
#  'Abäk',
#  'Accion Sanchez',
#  'Adam Jensen',
#  'Adventus',
#  'Aimer',
#  'Air',
#  'Aitana',
#  'Ak4:20',
#  'Alberto Dimeo',
#  'Aldo Cadiz',
#  'Alejo',
#  'Aleksander Debicz',
#  'Alex G',
#  'Alex Gargolas',
#  'Alex Rose',
#  'Alex Ubago',
#  'Alice Wonder',
#  'All Time Low',
#  'Almighty',
#  'Alvaro Diaz',
#  'Alvvays',
#  'Amadeüs',
#  'Amarion',
#  'Amenazzy',
#  'Amistades Peligrosas',
#  'Amon Tobin',
#  'Ana Mena',
#  'Andrea Sertori',
#  'Andrés Madariaga',
#  'Andrés Suárez',
#  'Andy & Lucas',
#  'Andy Frasco & The U.N.',
#  'Andy Rivera',
#  'Andy Stott',
#  'Angela Hewitt',
#  'Angelos',
#  'Angelus Apatrida',
#  'Ankhal',
#  'Ankor',
#  'Antonio José',
#  'Antonio Orozco',
#  'Antonio Ruiz Pipó',
#  'Anubiis',
#  'Anuel AA',
#  'Anıl Emre Daldal',
#  'Arcane',
#  'Arce',
#  'Arctic Monkeys',
#  'Arcy Drive',
#  'Arcángel',
#  'Arde Bogotá',
#  'Arnau Griso',
#  'Arrested Youth',
#  'Art Lown',
#  'Artury Pepper',
# ...

# %%
# Cogiendo 2, ya que probé con más artistas y la llamada a la API tarda mucho.

set_artist_prueba = ('AMBKOR')

# %%
list_artistas = list(set_artist)
len(list_artistas)
# Out:
# 899

# %% [markdown]
# CÓDIGO HASTA 27 OCT 2024 - NEXT STEP: BUSCAR SOLUCION AL DATA FRAME

# %%
#Probando que la llamada funciona.

API_KEY = '357e10dfd8c3d43a08795cbb92a9cf24'
url_base = 'https://ws.audioscrobbler.com/2.0'
params_info = {
        'method': 'artist.getinfo',
        'artist': 'Shakira',
        'api_key': API_KEY,
        'format': 'json'
        }
artista = requests.get(url_base, params=params_info)

# %%
json_shakira = artista.json()

# %%
dict_shakira = {"artista": [], "biografía": [], "listeners": [], "playcount": [], "artistas similares": []}

try:
    dict_shakira['artista'].append(json_shakira['artist']['name'])
except(ValueError, KeyError):
    dict_shakira['artista'].append("NULL")

try:
    dict_shakira['biografía'].append(json_shakira['artist']['bio']['content'])
except(ValueError, KeyError):
    dict_shakira['biografía'].append("NULL")

try:
    dict_shakira["listeners"].append(int(json_shakira['artist']['stats']['listeners']))
except(ValueError, KeyError):
    dict_shakira['listeners'].append("NULL")

try:
    dict_shakira["playcount"].append(int(json_shakira['artist']['stats']['playcount']))
except(ValueError, KeyError):
    dict_shakira['playcount'].append("NULL")

try:
    for elemento in json_shakira['artist']['similar']['artist']:
        dict_shakira["artistas similares"].append(elemento['name'])
            #for s in elemento:
                
except(ValueError, KeyError):
    dict_shakira['artistas similares'].append("NULL")

dict_shakira['artistas similares'] = [', '.join(dict_shakira['artistas similares'])]

df = pd.DataFrame(dict_shakira)

df
# Out:
#    artista                                          biografía  listeners  \
# 0  Shakira  Shakira Isabel Mebarak Ripoll is a Colombian s...    4006849
#
#    playcount                                 artistas similares
# 0  130265256  Paulina Rubio, Karol G, Belinda, Thalía, Julie...

# %% [markdown]
# 28.10.24 LE DAMOS LISTA CONCRETA PARA QUE BUSQUE EN LA API

# %%
artistas_prueba = ['Shakira', 'Gorillaz', 'Queen', 'Oasis', 'Bonobo']

# %%
# Este sería el código completo. El df da error. No se puede crear porque las columnas no tienen el mismo número de datos.

#list_artistas
#set_artist_prueba

dict_shakira = {"artista": [], "biografía": [], "listeners": [], "playcount": [], "artistas similares": []}

for artista in artistas_prueba:

    API_KEY = '357e10dfd8c3d43a08795cbb92a9cf24'
    url_base = 'https://ws.audioscrobbler.com/2.0'
    params_info = {
        'method': 'artist.getinfo',
        'artist': artista,
        'api_key': API_KEY,
        'format': 'json'
        }
    artista = requests.get(url_base, params=params_info)
    artista_json = artista.json()

    try:
        dict_shakira['artista'].append(artista_json['artist']['name'])
    except(ValueError, KeyError):
        dict_shakira['artista'].append("NULL")

    try:
        dict_shakira['biografía'].append(artista_json['artist']['bio']['content'])
    except(ValueError, KeyError):
        dict_shakira['biografía'].append("NULL")

    try:
        dict_shakira["listeners"].append(int(artista_json['artist']['stats']['listeners']))
    except(ValueError, KeyError):
        dict_shakira['listeners'].append("NULL")

    try:
        dict_shakira["playcount"].append(int(artista_json['artist']['stats']['playcount']))
    except(ValueError, KeyError):
        dict_shakira['playcount'].append("NULL")

    try:
        artistas_similares = []

        for elemento in artista_json['artist']['similar']['artist']:
            artistas_similares.append(elemento['name'])
            if len(artistas_similares) >= 3:
                break

        dict_shakira['artistas similares'].append(", ".join(artistas_similares) if artistas_similares else "NULL")

    except(ValueError, KeyError):
        dict_shakira['artistas similares'].append("NULL")

print(dict_shakira)
df = pd.DataFrame(dict_shakira)

df
# Out:
# {'artista': ['Shakira', 'Gorillaz', 'Queen', 'Oasis', 'Bonobo'], 'biografía': ['Shakira Isabel Mebarak Ripoll is a Colombian singer. Born and raised in Barranquilla, She made her recording debut with Sony Music Colombia at the age of 13. Following the commercial failure of her first two albums, Magia (1991) and Peligro (1993), she rose to prominence in Hispanic countries with her next albums, Pies Descalzos (1995) and Dónde Están los Ladrones? (1998). She entered the English-language market with her fifth album, Laundry Service (2001), which sold over 13 million copies worldwide. Buoyed by the international success of her singles "Whenever, Wherever" and "Underneath Your Clothes", the album propelled her reputation as a leading crossover artist. Broadcast Music, Inc., described Shakira as a "pioneer" who extended the global reach of Latino singers.\n\nHer success was further solidified with the Spanish albums Fijación Oral, Vol. 1 (2005), Sale el Sol (2010) and El Dorado (2017), all 
# ...

# %% [markdown]
# CON SET SPOTIFY

# %%
dict_artistas = {"artista": [], "biografía": [], "listeners": [], "playcount": [], "artistas similares": []}

for artista in set_artist:

    API_KEY = '357e10dfd8c3d43a08795cbb92a9cf24'
    url_base = 'https://ws.audioscrobbler.com/2.0'
    params_info = {
        'method': 'artist.getinfo',
        'artist': artista,
        'api_key': API_KEY,
        'format': 'json'
        }
    artista = requests.get(url_base, params=params_info)
    artista_json = artista.json()

    try:
        dict_artistas['artista'].append(artista_json['artist']['name'])
    except(ValueError, KeyError):
        dict_artistas['artista'].append("NULL")

    try:
        dict_artistas['biografía'].append(artista_json['artist']['bio']['content'])
    except(ValueError, KeyError):
        dict_artistas['biografía'].append("NULL")

    try:
        dict_artistas["listeners"].append(int(artista_json['artist']['stats']['listeners']))
    except(ValueError, KeyError):
        dict_artistas['listeners'].append("NULL")

    try:
        dict_artistas["playcount"].append(int(artista_json['artist']['stats']['playcount']))
    except(ValueError, KeyError):
        dict_artistas['playcount'].append("NULL")

    try:
        artistas_similares = []

        for elemento in artista_json['artist']['similar']['artist']:
            artistas_similares.append(elemento['name'])
            if len(artistas_similares) >= 3:
                break

        dict_artistas['artistas similares'].append(", ".join(artistas_similares) if artistas_similares else "NULL")

    except(ValueError, KeyError):
        dict_artistas['artistas similares'].append("NULL")

df_lastfm = pd.DataFrame(dict_artistas)

df_lastfm
# Out:
#                                         artista  \
# 0                                          CNCO
# 1                                       Celtian
# 2                           Proyecto Gomez Casa
# 3                                   Duran Duran
# 4                               Greta Van Fleet
# 5                               Pablo Ferrandez
# 6                                Paula Mattheus
# 7                           Of Monsters and Men
# 8                 Richy Mitch & The Coal Miners
# 9                       if i die in mississippi
# 10                                 Télépopmusik
# 11                             Andrés Madariaga
# 12                                      Iration
# 13                                   Arcy Drive
# 14                         Bring Me the Horizon
# 15                               SunKissed Lola
# 16                                   DJs Pareja
# 17                               Beatriz Luengo
# ...

# %%
df_lastfm.to_csv('../data/df_lastfm.csv', index=False)

# %%
dict_artistas
# Out:
# {'artista': ['CNCO',
#   'Celtian',
#   'Proyecto Gomez Casa',
#   'Duran Duran',
#   'Greta Van Fleet',
#   'Pablo Ferrandez',
#   'Paula Mattheus',
#   'Of Monsters and Men',
#   'Richy Mitch & The Coal Miners',
#   'if i die in mississippi',
#   'Télépopmusik',
#   'Andrés Madariaga',
#   'Iration',
#   'Arcy Drive',
#   'Bring Me the Horizon',
#   'SunKissed Lola',
#   'DJs Pareja',
#   'Beatriz Luengo',
#   'Saurom',
#   'Sébastien Tellier',
#   'Moby',
#   'Lyanno',
#   'Bibio',
#   'Korn',
#   'Guitarricadelafuente',
#   'El Clooy',
#   'Danny Ocean',
#   'Polyphia',
#   'Califato ¾',
#   'Tiga',
#   'OneRepublic',
#   'Edu Linares',
#   'The Chemical Brothers',
#   'Bombai',
#   'Khaled',
#   'Level 42',
#   'Juan Magán',
#   'Jacques Greene',
#   'Arce',
#   'Juhn',
#   'Pablo de Sarasate',
#   'Limp Bizkit',
#   'Arde Bogotá',
#   'Hooverphonic',
#   'Droow',
#   'Art Lown',
#   'Health',
#   'Old Mervs',
#   'Tom Morello',
#   'La Pegatina',
#   'Florida Georgia Line',
# ...

# %%
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# %%
# Abrir dataframe de MB para luego hacer la importacion. 
df_lastfm_csv = pd.read_csv('../data/df_lastfm.csv')

# %%
from sqlalchemy import create_engine

# %%
user='root'
password='AlumnaAdalab'
host='127.0.0.1'
database= # PONERLE EL NOMBRE DE LA BASE DE DATOS QUE ELIJAMOS
connection_string = f'mysql+mysqlconnector://{user}:{password}@{host}/{database}'
engine = create_engine(connection_string)

# %%
dataframe_MB_csv.to_sql(name=#NOMBRE DE LA TABLA QUE ELIJAMOS, con=engine, if_exists='append', index=False)
