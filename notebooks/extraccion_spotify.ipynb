# %%
import pandas as pd
import requests
import re
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import os
from dotenv import load_dotenv 


#esto para que vuelva a mostrar los dataframe cortados
#pd.reset_option('display.max_rows')
#pd.reset_option('display.max_columns')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import requests
#       3 import re
# ----> 4 import spotipy
#       5 from spotipy.oauth2 import SpotifyClientCredentials
#       6 pd.set_option('display.max_columns', None)
#
# ModuleNotFoundError: No module named 'spotipy'

# %%
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# %%
pip install spotipy
# Out:
# ...
#    ---------------------------------------- 0.0/261.4 kB ? eta -:--:--
#    ----------------------------- ---------- 194.6/261.4 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 261.4/261.4 kB 4.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\Macarena\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Coloca tus credenciales aquí
CLIENT_ID = "fbebe461d0154abf898e3edc195b45a0" # tu identificador de la api
CLIENT_SECRET = "17d5e64384624517b40ebcb28c4ca986"
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
load_dotenv()

print(CLIENT_SECRET)
# Out:
# 17d5e64384624517b40ebcb28c4ca986

# %%
datos = sp.search(q="genre:electronica year:2022", type='track', limit=50, offset=0)

# %%
datos
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=genre%3Aelectronica+year%3A2022&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ucLPotcQNI7AViFytdhBz'},
#        'href': 'https://api.spotify.com/v1/artists/0ucLPotcQNI7AViFytdhBz',
#        'id': '0ucLPotcQNI7AViFytdhBz',
#        'name': 'Ladytron',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ucLPotcQNI7AViFytdhBz'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
# ...

# %%
#Album or Single (TYPE) :
datos["tracks"]["items"][0]['album']['album_type']
# Out:
# 'album'

# %%
#Release_date: (luego split)

fecha_entera = datos["tracks"]["items"][0]['album']["release_date"]
año = fecha_entera.split("-")[0]

fecha_entera
año
# Out:
# '2022'

# %% [markdown]
# ## DICCIONARIO BASE:

# %%
#ELECTRONICA 2021 - 2022: 

electronica_2021_22 = {"nombre_cancion_album": [], "artista": [], "tipo_album_cancion" : [], "año_lanzamiento" : [], "género" : []} ##Falta añadir contador

for ind in range(0,1000,50): #Rango de 1000 canciones de 50 en 50
    
    datos = sp.search(q="genre:electronica year:2021-2022", type='track', limit=50, offset=ind)

    json_sp = datos["tracks"]["items"]

    for elemento in json_sp:
        electronica_2021_22["nombre_cancion_album"].append(elemento["name"]) #Añade nombre cancion
        electronica_2021_22["tipo_album_cancion"].append(elemento["album"]["album_type"]) #Añade si es album o single
        release_date = elemento["album"]["release_date"] #Define fecha de lanzamiento
        año = release_date.split("-")[0] #Divide la fecha
        electronica_2021_22["año_lanzamiento"].append(año) #Append solo el año de lanzamiento
        electronica_2021_22["artista"].append(elemento["album"]["artists"][0]["name"]) #Añade nombre de artista (solo uno por cancion)
        electronica_2021_22["género"].append("Electrónica") #Añade género

# %%
#Dataframe: 
#electronica_2021_22 = pd.DataFrame(electronica_2021_22) 
#electronica_2021_22

# %%
for key, value in electronica_2021_22.items():
    print(f"{key}: {len(value)}")
# Out:
# nombre_cancion_album: 1000
# artista: 1000
# tipo_album_cancion: 1000
# año_lanzamiento: 1000
# género: 1000

# %%
#LATINO 2021 - 2022: 

latino_2021_22 = {"nombre_cancion_album": [], "artista": [], "tipo_album_cancion" : [], "año_lanzamiento" : [], "género" : []} ##Falta añadir contador

for ind in range(0,1000,50): #Rango de 1000 canciones de 50 en 50
    
    datos = sp.search(q="genre:latino year:2021-2022", type='track', limit=50, offset=ind)

    json_sp = datos["tracks"]["items"]

    for elemento in json_sp:
        latino_2021_22["nombre_cancion_album"].append(elemento["name"]) #Añade nombre cancion
        latino_2021_22["tipo_album_cancion"].append(elemento["album"]["album_type"]) #Añade si es album o single
        release_date = elemento["album"]["release_date"] #Define fecha de lanzamiento
        año = release_date.split("-")[0] #Divide la fecha
        latino_2021_22["año_lanzamiento"].append(año) #Append solo el año de lanzamiento
        latino_2021_22["artista"].append(elemento["album"]["artists"][0]["name"]) #Añade nombre de artista (solo uno por cancion)
        latino_2021_22["género"].append("Latino") #Añade género

# %%
for key, value in latino_2021_22.items():
    print(f"{key}: {len(value)}")
# Out:
# nombre_cancion_album: 1000
# artista: 1000
# tipo_album_cancion: 1000
# año_lanzamiento: 1000
# género: 1000

# %%
#Dataframe: 
#latino_2021_22 = pd.DataFrame(latino_2021_22) 
#latino_2021_22

# %%
#MUSICA ESPAÑOLA 2021 - 2022: 

spanish_2021_22 = {"nombre_cancion_album": [], "artista": [], "tipo_album_cancion" : [], "año_lanzamiento" : [], "género" : []} ##Falta añadir contador

for ind in range(0,1000,50): #Rango de 1000 canciones de 50 en 50
    
    datos = sp.search(q="genre:spanish year:2021-2022", type='track', limit=50, offset=ind)

    json_sp = datos["tracks"]["items"]

    for elemento in json_sp:
        spanish_2021_22["nombre_cancion_album"].append(elemento["name"]) #Añade nombre cancion
        spanish_2021_22["tipo_album_cancion"].append(elemento["album"]["album_type"]) #Añade si es album o single
        release_date = elemento["album"]["release_date"] #Define fecha de lanzamiento
        año = release_date.split("-")[0] #Divide la fecha
        spanish_2021_22["año_lanzamiento"].append(año) #Append solo el año de lanzamiento
        spanish_2021_22["artista"].append(elemento["album"]["artists"][0]["name"]) #Añade nombre de artista (solo uno por cancion)
        spanish_2021_22["género"].append("Música Española") #Añade género

# %%
for key, value in spanish_2021_22.items():
    print(f"{key}: {len(value)}")
# Out:
# nombre_cancion_album: 1000
# artista: 1000
# tipo_album_cancion: 1000
# año_lanzamiento: 1000
# género: 1000

# %%
#Dataframe: 
#spanish_2021_22 = pd.DataFrame(spanish_2021_22) 
#spanish_2021_22

# %%
#ROCK 2021 - 2022: 

rock_2021_22 = {"nombre_cancion_album": [], "artista": [], "tipo_album_cancion" : [], "año_lanzamiento" : [], "género" : []} ##Falta añadir contador

for ind in range(0,1000,50): #Rango de 1000 canciones de 50 en 50
    
    datos = sp.search(q="genre:rock year:2021-2022", type='track', limit=50, offset=ind)

    json_sp = datos["tracks"]["items"]

    for elemento in json_sp:
        rock_2021_22["nombre_cancion_album"].append(elemento["name"]) #Añade nombre cancion
        rock_2021_22["tipo_album_cancion"].append(elemento["album"]["album_type"]) #Añade si es album o single
        release_date = elemento["album"]["release_date"] #Define fecha de lanzamiento
        año = release_date.split("-")[0] #Divide la fecha
        rock_2021_22["año_lanzamiento"].append(año) #Append solo el año de lanzamiento
        rock_2021_22["artista"].append(elemento["album"]["artists"][0]["name"]) #Añade nombre de artista (solo uno por cancion)
        rock_2021_22["género"].append("Rock") #Añade género

# %%
#Dataframe: 
#rock_2021_22 = pd.DataFrame(rock_2021_22) 
#rock_2021_22

# %%
#Ver si se puede usar para el contador (preguntar)

for key, value in rock_2021_22.items():
    print(f"{key}: {len(value)}")
# Out:
# nombre_cancion_album: 1000
# artista: 1000
# tipo_album_cancion: 1000
# año_lanzamiento: 1000
# género: 1000

# %%
objs = [electronica_2021_22,latino_2021_22,spanish_2021_22,rock_2021_22]

# %%
objs

# %%
#Concatenamos los dataframes: 
dataframes_combinados = pd.concat(objs, axis=0, join='outer', ignore_index=True)

# %%
dataframes_combinados

# %%
# Guardar el DataFrame como CSV
dataframes_combinados.to_csv('../data/dataframes_combinados.csv', index=False)

# %% [markdown]
# ## Pasar datos a SQL:

# %%
##Creamos zip para luego usarlo como 'val' y poder insertar los datos del diccionario en la tabla de SQL
valores_electronica= zip(
    electronica_2021_22["nombre_cancion_album"], electronica_2021_22["artista"],  electronica_2021_22["tipo_album_cancion"], electronica_2021_22["año_lanzamiento"], electronica_2021_22["género"]
)

valores_latino = zip(
    latino_2021_22["nombre_cancion_album"], latino_2021_22["artista"],  latino_2021_22["tipo_album_cancion"], latino_2021_22["año_lanzamiento"], latino_2021_22["género"]
)

valores_musica_esp = zip(
    spanish_2021_22["nombre_cancion_album"], spanish_2021_22["artista"],  spanish_2021_22["tipo_album_cancion"], spanish_2021_22["año_lanzamiento"], spanish_2021_22["género"]
)

valores_rock = zip(
    rock_2021_22["nombre_cancion_album"], rock_2021_22["artista"],  rock_2021_22["tipo_album_cancion"], rock_2021_22["año_lanzamiento"], rock_2021_22["género"]
)

# %%
## Electronica: (usando zip valores_electronica)
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='bd_pruebas') ###Usar esta base de prueba

print(cnx)

mycursor = cnx.cursor()
query = "INSERT INTO Spotify (nombre_cancion_album, artista_id, tipo_cancion_album, anio_lanzamiento, genero) VALUES (%s, %s, %s, %s, %s)"
val = valores_electronica ### aqui inserto ZIP
try: 
    mycursor.executemany(query, val) ### execute many!
    cnx.commit()
    print(mycursor.rowcount, "registro insertado.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# ...
# 1364 (HY000): Field 'artista_id' doesn't have a default value
# Error Code: 1364
# SQLSTATE HY000
# Message Field 'artista_id' doesn't have a default value

# %%
## Latino 

cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='bd_pruebas') ###Usar esta base de prueba

print(cnx)

mycursor = cnx.cursor()
query = "INSERT INTO spotify (nombre_cancion_album, artista_nombre_spotify, tipo_cancion_album, anio_lanzamiento, genero) VALUES (%s, %s, %s, %s, %s)"
val = valores_latino ### aqui inserto ZIP
try: 
    mycursor.executemany(query, val) ### execute many!
    cnx.commit()
    print(mycursor.rowcount, "registro insertado.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# ...
# 1062 (23000): Duplicate entry 'Bad Bunny' for key 'spotify.artista_nombre_spotify'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'Bad Bunny' for key 'spotify.artista_nombre_spotify'

# %%
## Spanish

cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='bd_pruebas') ###Usar esta base de prueba

print(cnx)

mycursor = cnx.cursor()
query = "INSERT INTO spotify (nombre_cancion_album, artista_nombre_spotify, tipo_cancion_album, anio_lanzamiento, genero) VALUES (%s, %s, %s, %s, %s)"
val = valores_musica_esp ### aqui inserto ZIP
try: 
    mycursor.executemany(query, val) ### execute many!
    cnx.commit()
    print(mycursor.rowcount, "registro insertado.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# ...
# 1062 (23000): Duplicate entry 'Marc Seguí' for key 'spotify.artista_nombre_spotify'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'Marc Seguí' for key 'spotify.artista_nombre_spotify'

# %%
#Rock

cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='bd_pruebas') ###Usar esta base de prueba

print(cnx)

mycursor = cnx.cursor()
query = "INSERT INTO spotify (nombre_cancion_album, artista_nombre_spotify, tipo_cancion_album, anio_lanzamiento, genero) VALUES (%s, %s, %s, %s, %s)"
val = valores_rock ### aqui inserto ZIP
try: 
    mycursor.executemany(query, val) ### execute many!
    cnx.commit()
    print(mycursor.rowcount, "registro insertado.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)

cnx.close()
# Out:
# ...
# 1062 (23000): Duplicate entry 'Imagine Dragons' for key 'spotify.artista_nombre_spotify'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'Imagine Dragons' for key 'spotify.artista_nombre_spotify'

# %%
## Errores: 

#1 Revisar lo de la primary key (al ser compuesta no deberia dar error si hay artistas repetidos, pero quizas con lo que pusimos de UNIQUE es por eso que da error).
